# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, random_split
import matplotlib.pyplot as plt

# CUDA device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# SVHN Transforms
transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# Load SVHN
full_train_data = datasets.SVHN(root='./data', split='train', download=True, transform=transform)
test_data = datasets.SVHN(root='./data', split='test', download=True, transform=transform)
train_size = int(0.9 * len(full_train_data))
val_size = len(full_train_data) - train_size
train_data, val_data = random_split(full_train_data, [train_size, val_size])

train_loader = DataLoader(train_data, batch_size=128, shuffle=True)
val_loader = DataLoader(val_data, batch_size=128, shuffle=False)
test_loader = DataLoader(test_data, batch_size=128, shuffle=False)

# Same 9-layer CNN
class CustomCNN(nn.Module):
    def __init__(self):
        super(CustomCNN, self).__init__()
        self.layers = nn.Sequential(
            nn.Conv2d(3, 64, 3, padding=1), nn.ReLU(),
            nn.Conv2d(64, 64, 3, padding=1), nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, 3, padding=1), nn.ReLU(),
            nn.Conv2d(128, 128, 3, padding=1), nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(128, 256, 3, padding=1), nn.ReLU(),
            nn.Conv2d(256, 256, 3, padding=1), nn.ReLU(),
            nn.AdaptiveAvgPool2d((4, 4))
        )

        self.fc = nn.Sequential(
            nn.Linear(256 * 4 * 4, 512), nn.ReLU(),
            nn.Linear(512, 10)
        )
        self._initialize_weights()

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
                nn.init.orthogonal_(m.weight)
                with torch.no_grad():
                    m.weight *= torch.sqrt(torch.tensor(2.))

    def forward(self, x):
        x = self.layers(x)
        x = torch.flatten(x, 1)
        x = self.fc(x)
        return x

# Training function
def train(model, epochs=50):
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()
    train_loss_list, train_acc_list = [], []
    val_loss_list, val_acc_list = [], []

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        correct_train, total_train = 0, 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

        train_loss = running_loss / len(train_loader)
        train_acc = 100 * correct_train / total_train
        train_loss_list.append(train_loss)
        train_acc_list.append(train_acc)

        model.eval()
        running_val_loss = 0.0
        correct_val, total_val = 0, 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                running_val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()

        val_loss = running_val_loss / len(val_loader)
        val_acc = 100 * correct_val / total_val
        val_loss_list.append(val_loss)
        val_acc_list.append(val_acc)

        print(
            f"Epoch {epoch+1} | Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | "
            f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.2f}%"
        )

    # Plot train loss
    plt.figure(figsize=(6, 4))
    plt.plot(train_loss_list, label='Train Loss')
    plt.title('Train Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.tight_layout()
    plt.show()

    # Plot train accuracy
    plt.figure(figsize=(6, 4))
    plt.plot(train_acc_list, label='Train Accuracy')
    plt.title('Train Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend()
    plt.tight_layout()
    plt.show()

    # Plot validation loss
    plt.figure(figsize=(6, 4))
    plt.plot(val_loss_list, label='Validation Loss')
    plt.title('Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.tight_layout()
    plt.show()

    # Plot validation accuracy
    plt.figure(figsize=(6, 4))
    plt.plot(val_acc_list, label='Validation Accuracy')
    plt.title('Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend()
    plt.tight_layout()
    plt.show()

    correct_test, total_test = 0, 0
    model.eval()
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total_test += labels.size(0)
            correct_test += (predicted == labels).sum().item()

    acc = 100 * correct_test / total_test
    print(f"Test Accuracy: {acc:.2f}%")

# Run it
model = CustomCNN()
train(model)
# Out:
# Epoch 1 | Train Loss: 0.9143 | Train Acc: 69.40% | Val Loss: 0.4062 | Val Acc: 88.53%
# Epoch 2 | Train Loss: 0.2911 | Train Acc: 91.35% | Val Loss: 0.2746 | Val Acc: 92.06%
# Epoch 3 | Train Loss: 0.2101 | Train Acc: 93.91% | Val Loss: 0.2884 | Val Acc: 91.99%
# Epoch 4 | Train Loss: 0.1677 | Train Acc: 95.22% | Val Loss: 0.2416 | Val Acc: 93.38%
# Epoch 5 | Train Loss: 0.1270 | Train Acc: 96.39% | Val Loss: 0.2545 | Val Acc: 93.16%
# Epoch 6 | Train Loss: 0.0990 | Train Acc: 97.02% | Val Loss: 0.2991 | Val Acc: 93.16%
# Epoch 7 | Train Loss: 0.0741 | Train Acc: 97.68% | Val Loss: 0.3284 | Val Acc: 93.65%
# Epoch 8 | Train Loss: 0.0636 | Train Acc: 97.99% | Val Loss: 0.2848 | Val Acc: 92.98%
# Epoch 9 | Train Loss: 0.0517 | Train Acc: 98.29% | Val Loss: 0.3661 | Val Acc: 93.26%
# Epoch 10 | Train Loss: 0.0439 | Train Acc: 98.53% | Val Loss: 0.4245 | Val Acc: 92.93%
# Epoch 11 | Train Loss: 0.0428 | Train Acc: 98.61% | Val Loss: 0.4604 | Val Acc: 93.22%
# Epoch 12 | Train Loss: 0.0358 | Train Acc: 98.83% | Val Loss: 0.4414 | Val Acc: 92.82%
# Epoch 13 | Train Loss: 0.0326 | Train Acc: 98.98% | Val Loss: 0.4443 | Val Acc: 93.41%
# Epoch 14 | Train Loss: 0.0258 | Train Acc: 99.22% | Val Loss: 0.5164 | Val Acc: 93.07%
# Epoch 15 | Train Loss: 0.0344 | Train Acc: 98.87% | Val Loss: 0.5171 | Val Acc: 93.37%
# Epoch 16 | Train Loss: 0.0273 | Train Acc: 99.13% | Val Loss: 0.4941 | Val Acc: 93.26%
# Epoch 17 | Train Loss: 0.0294 | Train Acc: 99.07% | Val Loss: 0.4548 | Val Acc: 93.13%
# Epoch 18 | Train Loss: 0.0254 | Train Acc: 99.20% | Val Loss: 0.5355 | Val Acc: 93.19%
# Epoch 19 | Train Loss: 0.0246 | Train Acc: 99.21% | Val Loss: 0.5397 | Val Acc: 93.22%
# Epoch 20 | Train Loss: 0.0272 | Train Acc: 99.17% | Val Loss: 0.4476 | Val Acc: 93.30%
# Epoch 21 | Train Loss: 0.0176 | Train Acc: 99.45% | Val Loss: 0.5424 | Val Acc: 93.82%
# Epoch 22 | Train Loss: 0.0300 | Train Acc: 99.12% | Val Loss: 0.5120 | Val Acc: 93.11%
# Epoch 23 | Train Loss: 0.0190 | Train Acc: 99.42% | Val Loss: 0.5406 | Val Acc: 93.65%
# Epoch 24 | Train Loss: 0.0187 | Train Acc: 99.43% | Val Loss: 0.6480 | Val Acc: 93.35%
# Epoch 25 | Train Loss: 0.0251 | Train Acc: 99.26% | Val Loss: 0.5146 | Val Acc: 93.22%
