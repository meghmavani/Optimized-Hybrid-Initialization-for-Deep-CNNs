# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.models as models
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

run_name = 'EuroSAT_AlexNet'

num_epochs = 50
batch_size = 128
learning_rate = 0.001

train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# EuroSAT has no official split: 80/10/10 train/val/test with a fixed seed
full_train = torchvision.datasets.EuroSAT(root='./data', transform=train_transform, download=True)
full_eval = torchvision.datasets.EuroSAT(root='./data', transform=test_transform, download=False)

n_total = len(full_train)
n_train = int(0.8 * n_total)
n_val = int(0.1 * n_total)
indices = torch.randperm(n_total, generator=torch.Generator().manual_seed(42)).tolist()

train_dataset = torch.utils.data.Subset(full_train, indices[:n_train])
val_dataset = torch.utils.data.Subset(full_eval, indices[n_train:n_train + n_val])
test_dataset = torch.utils.data.Subset(full_eval, indices[n_train + n_val:])

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# Hybrid Initialization (He for Conv2d, Orthogonal for Linear)
def custom_init(model):
    for module in model.modules():
        if isinstance(module, nn.Conv2d):
            nn.init.kaiming_normal_(module.weight, mode='fan_out', nonlinearity='relu')
        elif isinstance(module, nn.Linear):
            nn.init.orthogonal_(module.weight)
        if hasattr(module, 'bias') and module.bias is not None:
            nn.init.constant_(module.bias, 0)

# AlexNet (torchvision, trained from scratch)
model = models.alexnet(weights=None)
model.classifier[6] = nn.Linear(4096, 10)
model = model.to(device)
custom_init(model)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss_list.append(val_loss / len(val_loader))
    val_acc_list.append(val_acc)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc:.2f}%')

correct = 0
total = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f'Test Accuracy: {test_acc:.2f}%')

# Save metrics to files labelled with dataset + model name
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(num_epochs):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Epoch [1/50], Train Loss: 1.8761, Train Acc: 29.87%, Val Loss: 1.4687, Val Acc: 39.56%
# Epoch [2/50], Train Loss: 1.2937, Train Acc: 50.99%, Val Loss: 1.2627, Val Acc: 49.04%
# Epoch [3/50], Train Loss: 0.9979, Train Acc: 63.00%, Val Loss: 0.9164, Val Acc: 66.19%
# Epoch [4/50], Train Loss: 0.7972, Train Acc: 71.45%, Val Loss: 0.7344, Val Acc: 75.11%
# Epoch [5/50], Train Loss: 0.6607, Train Acc: 77.11%, Val Loss: 0.6282, Val Acc: 78.85%
# Epoch [6/50], Train Loss: 0.6038, Train Acc: 79.25%, Val Loss: 0.5149, Val Acc: 81.78%
# Epoch [7/50], Train Loss: 0.5382, Train Acc: 81.81%, Val Loss: 0.5976, Val Acc: 79.04%
# Epoch [8/50], Train Loss: 0.5359, Train Acc: 81.58%, Val Loss: 0.4764, Val Acc: 83.30%
# Epoch [9/50], Train Loss: 0.4585, Train Acc: 84.60%, Val Loss: 0.4460, Val Acc: 85.48%
# Epoch [10/50], Train Loss: 0.4227, Train Acc: 85.87%, Val Loss: 0.6062, Val Acc: 77.59%
# Epoch [11/50], Train Loss: 0.3997, Train Acc: 86.40%, Val Loss: 0.4071, Val Acc: 86.41%
# Epoch [12/50], Train Loss: 0.3838, Train Acc: 87.16%, Val Loss: 0.4929, Val Acc: 83.15%
# Epoch [13/50], Train Loss: 0.3739, Train Acc: 87.54%, Val Loss: 0.3409, Val Acc: 89.22%
# Epoch [14/50], Train Loss: 0.3373, Train Acc: 88.62%, Val Loss: 0.3774, Val Acc: 87.70%
# Epoch [15/50], Train Loss: 0.3422, Train Acc: 88.37%, Val Loss: 0.4406, Val Acc: 86.07%
# Epoch [16/50], Train Loss: 0.3150, Train Acc: 89.36%, Val Loss: 0.3556, Val Acc: 88.11%
# Epoch [17/50], Train Loss: 0.2932, Train Acc: 90.10%, Val Loss: 0.3805, Val Acc: 86.70%
# Epoch [18/50], Train Loss: 0.2802, Train Acc: 90.50%, Val Loss: 0.3656, Val Acc: 88.44%
# Epoch [19/50], Train Loss: 0.2771, Train Acc: 90.83%, Val Loss: 0.3803, Val Acc: 88.59%
# Epoch [20/50], Train Loss: 0.2651, Train Acc: 91.13%, Val Loss: 0.3172, Val Acc: 90.07%
# Epoch [21/50], Train Loss: 0.2462, Train Acc: 91.77%, Val Loss: 0.3105, Val Acc: 90.41%
# Epoch [22/50], Train Loss: 0.2485, Train Acc: 91.67%, Val Loss: 0.3116, Val Acc: 90.44%
# Epoch [23/50], Train Loss: 0.2473, Train Acc: 91.55%, Val Loss: 0.3385, Val Acc: 90.30%
# Epoch [24/50], Train Loss: 0.2273, Train Acc: 92.51%, Val Loss: 0.2979, Val Acc: 90.26%
# Epoch [25/50], Train Loss: 0.2300, Train Acc: 92.10%, Val Loss: 0.3923, Val Acc: 88.11%
# Epoch [26/50], Train Loss: 0.2420, Train Acc: 91.96%, Val Loss: 0.3308, Val Acc: 90.37%
# Epoch [27/50], Train Loss: 0.2877, Train Acc: 90.64%, Val Loss: 0.3429, Val Acc: 89.85%
# Epoch [28/50], Train Loss: 0.2377, Train Acc: 92.10%, Val Loss: 0.3209, Val Acc: 91.07%
# Epoch [29/50], Train Loss: 0.2111, Train Acc: 93.05%, Val Loss: 0.3646, Val Acc: 89.63%
# Epoch [30/50], Train Loss: 0.1913, Train Acc: 93.52%, Val Loss: 0.2968, Val Acc: 90.89%
# Epoch [31/50], Train Loss: 0.1909, Train Acc: 93.58%, Val Loss: 0.3320, Val Acc: 90.56%
# Epoch [32/50], Train Loss: 0.1974, Train Acc: 93.50%, Val Loss: 0.3588, Val Acc: 89.81%
# Epoch [33/50], Train Loss: 0.1777, Train Acc: 94.06%, Val Loss: 0.2934, Val Acc: 92.15%
# Epoch [34/50], Train Loss: 0.1652, Train Acc: 94.43%, Val Loss: 0.3235, Val Acc: 90.96%
# Epoch [35/50], Train Loss: 0.1844, Train Acc: 93.79%, Val Loss: 0.3054, Val Acc: 91.63%
# Epoch [36/50], Train Loss: 0.1894, Train Acc: 93.80%, Val Loss: 0.3284, Val Acc: 90.15%
# Epoch [37/50], Train Loss: 0.1922, Train Acc: 93.76%, Val Loss: 0.3224, Val Acc: 91.37%
# Epoch [38/50], Train Loss: 0.1728, Train Acc: 94.31%, Val Loss: 0.3090, Val Acc: 89.89%
# Epoch [39/50], Train Loss: 0.2088, Train Acc: 93.27%, Val Loss: 0.3204, Val Acc: 91.41%
# Epoch [40/50], Train Loss: 0.1721, Train Acc: 94.52%, Val Loss: 0.2956, Val Acc: 91.70%
# Epoch [41/50], Train Loss: 0.1797, Train Acc: 94.20%, Val Loss: 0.2907, Val Acc: 91.81%
# Epoch [42/50], Train Loss: 0.1509, Train Acc: 94.99%, Val Loss: 0.2891, Val Acc: 92.67%
# Epoch [43/50], Train Loss: 0.1439, Train Acc: 95.20%, Val Loss: 0.3128, Val Acc: 91.74%
# Epoch [44/50], Train Loss: 0.2054, Train Acc: 93.34%, Val Loss: 0.3134, Val Acc: 90.78%
# Epoch [45/50], Train Loss: 0.1822, Train Acc: 94.15%, Val Loss: 0.2998, Val Acc: 91.30%
# Epoch [46/50], Train Loss: 0.1612, Train Acc: 94.94%, Val Loss: 0.3277, Val Acc: 91.22%
# Epoch [47/50], Train Loss: 0.1674, Train Acc: 94.43%, Val Loss: 0.2880, Val Acc: 92.19%
# Epoch [48/50], Train Loss: 0.1429, Train Acc: 95.28%, Val Loss: 0.2714, Val Acc: 92.81%
# Epoch [49/50], Train Loss: 0.1353, Train Acc: 95.54%, Val Loss: 0.4189, Val Acc: 90.26%
# Epoch [50/50], Train Loss: 0.1631, Train Acc: 94.70%, Val Loss: 0.3745, Val Acc: 90.15%
# Test Accuracy: 91.56%
