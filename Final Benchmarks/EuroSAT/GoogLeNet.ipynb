# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.models as models
import torchvision.transforms as transforms
from torchvision.models import googlenet
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

run_name = 'EuroSAT_GoogLeNet'

num_epochs = 50
batch_size = 128
learning_rate = 0.001

train_transform = transforms.Compose([
    transforms.RandomCrop(64, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# EuroSAT has no official split: 80/10/10 train/val/test with a fixed seed
full_train = torchvision.datasets.EuroSAT(root='./data', transform=train_transform, download=True)
full_eval = torchvision.datasets.EuroSAT(root='./data', transform=test_transform, download=False)

n_total = len(full_train)
n_train = int(0.8 * n_total)
n_val = int(0.1 * n_total)
indices = torch.randperm(n_total, generator=torch.Generator().manual_seed(42)).tolist()

train_dataset = torch.utils.data.Subset(full_train, indices[:n_train])
val_dataset = torch.utils.data.Subset(full_eval, indices[n_train:n_train + n_val])
test_dataset = torch.utils.data.Subset(full_eval, indices[n_train + n_val:])

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# Hybrid Initialization (He for Conv2d, Orthogonal for Linear)
def custom_init(model):
    for module in model.modules():
        if isinstance(module, nn.Conv2d):
            nn.init.kaiming_normal_(module.weight, mode='fan_out', nonlinearity='relu')
        elif isinstance(module, nn.Linear):
            nn.init.orthogonal_(module.weight)
        if hasattr(module, 'bias') and module.bias is not None:
            nn.init.constant_(module.bias, 0)

# GoogLeNet (torchvision, trained from scratch)
model = googlenet(num_classes=10, aux_logits=False)
model = model.to(device)
custom_init(model)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss_list.append(val_loss / len(val_loader))
    val_acc_list.append(val_acc)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc:.2f}%')

correct = 0
total = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f'Test Accuracy: {test_acc:.2f}%')

# Save metrics to files labelled with dataset + model name
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(num_epochs):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# /home/aadit/Projects/Optimized-Hybrid-Initialization-for-Deep-CNNs/.venv/lib/python3.13/site-packages/torchvision/models/googlenet.py:47: FutureWarning: The default weight initialization of GoogleNet will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(
# Epoch [1/50], Train Loss: 0.9126, Train Acc: 67.58%, Val Loss: 1.2351, Val Acc: 58.00%
# Epoch [2/50], Train Loss: 0.6346, Train Acc: 77.81%, Val Loss: 2.4271, Val Acc: 63.22%
# Epoch [3/50], Train Loss: 0.5394, Train Acc: 81.41%, Val Loss: 0.9030, Val Acc: 74.63%
# Epoch [4/50], Train Loss: 0.4607, Train Acc: 84.08%, Val Loss: 1.4913, Val Acc: 64.81%
# Epoch [5/50], Train Loss: 0.4016, Train Acc: 86.24%, Val Loss: 0.5261, Val Acc: 83.00%
# Epoch [6/50], Train Loss: 0.3664, Train Acc: 87.59%, Val Loss: 0.8030, Val Acc: 77.15%
# Epoch [7/50], Train Loss: 0.3221, Train Acc: 88.82%, Val Loss: 0.7265, Val Acc: 78.00%
# Epoch [8/50], Train Loss: 0.2915, Train Acc: 89.77%, Val Loss: 0.4445, Val Acc: 85.26%
# Epoch [9/50], Train Loss: 0.2689, Train Acc: 90.94%, Val Loss: 0.5512, Val Acc: 81.93%
# Epoch [10/50], Train Loss: 0.2455, Train Acc: 91.66%, Val Loss: 0.4195, Val Acc: 88.22%
# Epoch [11/50], Train Loss: 0.2312, Train Acc: 91.87%, Val Loss: 0.5830, Val Acc: 83.96%
# Epoch [12/50], Train Loss: 0.2071, Train Acc: 92.89%, Val Loss: 1.5341, Val Acc: 77.19%
# Epoch [13/50], Train Loss: 0.2147, Train Acc: 92.84%, Val Loss: 0.8473, Val Acc: 82.59%
# Epoch [14/50], Train Loss: 0.1979, Train Acc: 93.36%, Val Loss: 0.2510, Val Acc: 92.26%
# Epoch [15/50], Train Loss: 0.1829, Train Acc: 93.69%, Val Loss: 0.6262, Val Acc: 80.89%
# Epoch [16/50], Train Loss: 0.1842, Train Acc: 93.75%, Val Loss: 0.2713, Val Acc: 91.11%
# Epoch [17/50], Train Loss: 0.1680, Train Acc: 94.43%, Val Loss: 1.0358, Val Acc: 80.44%
# Epoch [18/50], Train Loss: 0.1586, Train Acc: 94.42%, Val Loss: 0.3777, Val Acc: 87.93%
# Epoch [19/50], Train Loss: 0.1602, Train Acc: 94.63%, Val Loss: 0.2075, Val Acc: 93.00%
# Epoch [20/50], Train Loss: 0.1371, Train Acc: 95.25%, Val Loss: 0.2168, Val Acc: 92.93%
# Epoch [21/50], Train Loss: 0.1345, Train Acc: 95.27%, Val Loss: 0.3993, Val Acc: 88.78%
# Epoch [22/50], Train Loss: 0.1308, Train Acc: 95.62%, Val Loss: 0.3644, Val Acc: 88.96%
# Epoch [23/50], Train Loss: 0.1283, Train Acc: 95.75%, Val Loss: 3.1149, Val Acc: 73.85%
# Epoch [24/50], Train Loss: 0.1404, Train Acc: 95.17%, Val Loss: 0.2002, Val Acc: 93.56%
# Epoch [25/50], Train Loss: 0.1271, Train Acc: 95.62%, Val Loss: 0.5662, Val Acc: 86.85%
# Epoch [26/50], Train Loss: 0.1144, Train Acc: 96.13%, Val Loss: 0.8331, Val Acc: 80.22%
# Epoch [27/50], Train Loss: 0.1144, Train Acc: 96.01%, Val Loss: 0.2841, Val Acc: 91.04%
# Epoch [28/50], Train Loss: 0.0989, Train Acc: 96.45%, Val Loss: 0.4861, Val Acc: 87.59%
# Epoch [29/50], Train Loss: 0.1180, Train Acc: 96.16%, Val Loss: 0.2053, Val Acc: 93.89%
# Epoch [30/50], Train Loss: 0.1127, Train Acc: 96.15%, Val Loss: 0.5073, Val Acc: 87.48%
# Epoch [31/50], Train Loss: 0.1111, Train Acc: 96.21%, Val Loss: 0.4082, Val Acc: 87.56%
# Epoch [32/50], Train Loss: 0.0984, Train Acc: 96.70%, Val Loss: 0.7535, Val Acc: 84.78%
# Epoch [33/50], Train Loss: 0.1018, Train Acc: 96.38%, Val Loss: 0.5705, Val Acc: 87.30%
# Epoch [34/50], Train Loss: 0.0950, Train Acc: 96.68%, Val Loss: 0.3284, Val Acc: 91.11%
# Epoch [35/50], Train Loss: 0.0938, Train Acc: 96.80%, Val Loss: 1.2808, Val Acc: 82.07%
# Epoch [36/50], Train Loss: 0.0772, Train Acc: 97.36%, Val Loss: 0.1762, Val Acc: 94.37%
# Epoch [37/50], Train Loss: 0.0961, Train Acc: 96.81%, Val Loss: 0.1651, Val Acc: 95.19%
# Epoch [38/50], Train Loss: 0.0890, Train Acc: 97.06%, Val Loss: 0.1814, Val Acc: 94.81%
# Epoch [39/50], Train Loss: 0.0871, Train Acc: 97.01%, Val Loss: 0.1732, Val Acc: 94.89%
# Epoch [40/50], Train Loss: 0.0830, Train Acc: 97.33%, Val Loss: 0.1989, Val Acc: 93.81%
# Epoch [41/50], Train Loss: 0.0780, Train Acc: 97.34%, Val Loss: 1.5156, Val Acc: 81.81%
# Epoch [42/50], Train Loss: 0.0750, Train Acc: 97.44%, Val Loss: 1.6814, Val Acc: 80.26%
# Epoch [43/50], Train Loss: 0.0762, Train Acc: 97.56%, Val Loss: 0.5462, Val Acc: 89.26%
# Epoch [44/50], Train Loss: 0.0805, Train Acc: 97.33%, Val Loss: 0.5738, Val Acc: 87.30%
# Epoch [45/50], Train Loss: 0.0713, Train Acc: 97.64%, Val Loss: 0.3970, Val Acc: 91.33%
# Epoch [46/50], Train Loss: 0.0568, Train Acc: 98.08%, Val Loss: 0.1726, Val Acc: 94.96%
# Epoch [47/50], Train Loss: 0.0657, Train Acc: 97.78%, Val Loss: 0.1948, Val Acc: 94.63%
# Epoch [48/50], Train Loss: 0.0666, Train Acc: 97.85%, Val Loss: 0.1491, Val Acc: 95.48%
# Epoch [49/50], Train Loss: 0.0680, Train Acc: 97.61%, Val Loss: 0.3892, Val Acc: 89.22%
# Epoch [50/50], Train Loss: 0.0574, Train Acc: 98.21%, Val Loss: 1.9792, Val Acc: 77.11%
# Test Accuracy: 78.19%
