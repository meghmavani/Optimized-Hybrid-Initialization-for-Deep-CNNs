# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

num_epochs = 50
batch_size = 128
learning_rate = 0.001
run_name = 'EuroSAT_Custom_CNN'

train_transform = transforms.Compose([
    transforms.RandomCrop(64, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# EuroSAT has no official split: 80/10/10 train/val/test with a fixed seed
full_train = torchvision.datasets.EuroSAT(root='./data', transform=train_transform, download=True)
full_eval = torchvision.datasets.EuroSAT(root='./data', transform=test_transform, download=False)

n_total = len(full_train)
n_train = int(0.8 * n_total)
n_val = int(0.1 * n_total)
indices = torch.randperm(n_total, generator=torch.Generator().manual_seed(42)).tolist()

train_dataset = torch.utils.data.Subset(full_train, indices[:n_train])
val_dataset = torch.utils.data.Subset(full_eval, indices[n_train:n_train + n_val])
test_dataset = torch.utils.data.Subset(full_eval, indices[n_train + n_val:])

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    layer_idx = 0
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            if layer_idx < 6:
                nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
            else:
                nn.init.orthogonal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
            layer_idx += 1

# 9-layer CNN Model
class NineLayerCNN(nn.Module):
    def __init__(self):
        super(NineLayerCNN, self).__init__()

        # Conv block 1
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)

        # Conv block 2
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)

        # Conv block 3
        self.conv5 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.conv7 = nn.Conv2d(256, 128, kernel_size=3, padding=1)

        # FC layers
        # Image size:
        # 64 -> pool ->32 -> pool ->16 -> pool ->8
        self.fc1 = nn.Linear(128 * 8 * 8, 1024)
        self.fc2 = nn.Linear(1024, 10)


    def forward(self, x):

        # block 1
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)

        # block 2
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2)

        # block 3
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = F.relu(self.conv7(x))
        x = F.max_pool2d(x, 2)

        x = torch.flatten(x, 1)

        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        return x

# Instantiate model, apply custom initialization
model = NineLayerCNN().to(device)
custom_init(model)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss_list.append(val_loss / len(val_loader))
    val_acc_list.append(val_acc)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc:.2f}%')

correct = 0
total = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f'Test Accuracy: {test_acc:.2f}%')

# Save metrics to files labelled with dataset + model name
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(num_epochs):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Epoch [1/50], Train Loss: 2.1224, Train Acc: 38.56%, Val Loss: 1.3805, Val Acc: 46.81%
# Epoch [2/50], Train Loss: 0.9223, Train Acc: 66.72%, Val Loss: 1.0823, Val Acc: 65.81%
# Epoch [3/50], Train Loss: 0.6902, Train Acc: 75.22%, Val Loss: 0.7550, Val Acc: 72.52%
# Epoch [4/50], Train Loss: 0.5696, Train Acc: 79.94%, Val Loss: 0.8672, Val Acc: 70.41%
# Epoch [5/50], Train Loss: 0.4821, Train Acc: 83.18%, Val Loss: 0.4921, Val Acc: 83.04%
# Epoch [6/50], Train Loss: 0.3943, Train Acc: 86.35%, Val Loss: 0.3949, Val Acc: 85.67%
# Epoch [7/50], Train Loss: 0.3419, Train Acc: 88.31%, Val Loss: 0.4015, Val Acc: 85.81%
# Epoch [8/50], Train Loss: 0.2963, Train Acc: 89.90%, Val Loss: 0.3313, Val Acc: 88.89%
# Epoch [9/50], Train Loss: 0.2531, Train Acc: 91.28%, Val Loss: 0.3243, Val Acc: 89.26%
# Epoch [10/50], Train Loss: 0.2292, Train Acc: 92.44%, Val Loss: 0.3034, Val Acc: 89.11%
# Epoch [11/50], Train Loss: 0.2086, Train Acc: 92.90%, Val Loss: 0.2301, Val Acc: 92.07%
# Epoch [12/50], Train Loss: 0.1892, Train Acc: 93.64%, Val Loss: 0.2574, Val Acc: 91.78%
# Epoch [13/50], Train Loss: 0.1868, Train Acc: 93.52%, Val Loss: 0.2603, Val Acc: 91.85%
# Epoch [14/50], Train Loss: 0.1503, Train Acc: 94.85%, Val Loss: 0.2140, Val Acc: 92.41%
# Epoch [15/50], Train Loss: 0.1407, Train Acc: 95.19%, Val Loss: 0.2035, Val Acc: 93.48%
# Epoch [16/50], Train Loss: 0.1336, Train Acc: 95.44%, Val Loss: 0.1910, Val Acc: 93.96%
# Epoch [17/50], Train Loss: 0.1292, Train Acc: 95.60%, Val Loss: 0.1817, Val Acc: 94.41%
# Epoch [18/50], Train Loss: 0.1208, Train Acc: 95.79%, Val Loss: 0.1916, Val Acc: 93.89%
# Epoch [19/50], Train Loss: 0.1188, Train Acc: 95.85%, Val Loss: 0.1936, Val Acc: 93.48%
# Epoch [20/50], Train Loss: 0.1222, Train Acc: 95.85%, Val Loss: 0.2292, Val Acc: 92.74%
# Epoch [21/50], Train Loss: 0.1128, Train Acc: 96.20%, Val Loss: 0.1960, Val Acc: 94.56%
# Epoch [22/50], Train Loss: 0.1046, Train Acc: 96.41%, Val Loss: 0.2781, Val Acc: 92.33%
# Epoch [23/50], Train Loss: 0.1067, Train Acc: 96.38%, Val Loss: 0.1650, Val Acc: 95.26%
# Epoch [24/50], Train Loss: 0.0887, Train Acc: 97.03%, Val Loss: 0.1882, Val Acc: 95.04%
# Epoch [25/50], Train Loss: 0.0890, Train Acc: 97.14%, Val Loss: 0.1711, Val Acc: 95.33%
# Epoch [26/50], Train Loss: 0.0879, Train Acc: 97.07%, Val Loss: 0.1978, Val Acc: 94.37%
# Epoch [27/50], Train Loss: 0.0888, Train Acc: 97.00%, Val Loss: 0.1698, Val Acc: 95.19%
# Epoch [28/50], Train Loss: 0.0797, Train Acc: 97.26%, Val Loss: 0.1564, Val Acc: 95.74%
# Epoch [29/50], Train Loss: 0.0979, Train Acc: 96.76%, Val Loss: 0.1608, Val Acc: 95.52%
# Epoch [30/50], Train Loss: 0.0844, Train Acc: 97.18%, Val Loss: 0.1932, Val Acc: 94.74%
# Epoch [31/50], Train Loss: 0.0886, Train Acc: 97.11%, Val Loss: 0.1923, Val Acc: 94.00%
# Epoch [32/50], Train Loss: 0.0942, Train Acc: 96.90%, Val Loss: 0.1832, Val Acc: 95.07%
# Epoch [33/50], Train Loss: 0.0750, Train Acc: 97.47%, Val Loss: 0.1838, Val Acc: 95.00%
# Epoch [34/50], Train Loss: 0.0672, Train Acc: 97.76%, Val Loss: 0.1625, Val Acc: 95.70%
# Epoch [35/50], Train Loss: 0.0723, Train Acc: 97.56%, Val Loss: 0.2195, Val Acc: 94.52%
# Epoch [36/50], Train Loss: 0.0699, Train Acc: 97.60%, Val Loss: 0.1495, Val Acc: 95.44%
# Epoch [37/50], Train Loss: 0.0618, Train Acc: 97.94%, Val Loss: 0.2180, Val Acc: 94.70%
# Epoch [38/50], Train Loss: 0.0686, Train Acc: 97.72%, Val Loss: 0.1590, Val Acc: 95.78%
# Epoch [39/50], Train Loss: 0.0686, Train Acc: 97.77%, Val Loss: 0.1625, Val Acc: 95.56%
# Epoch [40/50], Train Loss: 0.0747, Train Acc: 97.53%, Val Loss: 0.1413, Val Acc: 96.33%
# Epoch [41/50], Train Loss: 0.0551, Train Acc: 98.30%, Val Loss: 0.2295, Val Acc: 94.63%
# Epoch [42/50], Train Loss: 0.0823, Train Acc: 97.20%, Val Loss: 0.1985, Val Acc: 94.33%
# Epoch [43/50], Train Loss: 0.0683, Train Acc: 97.69%, Val Loss: 0.2139, Val Acc: 93.96%
# Epoch [44/50], Train Loss: 0.0665, Train Acc: 97.83%, Val Loss: 0.1802, Val Acc: 95.89%
# Epoch [45/50], Train Loss: 0.0684, Train Acc: 97.74%, Val Loss: 0.1495, Val Acc: 95.93%
# Epoch [46/50], Train Loss: 0.0405, Train Acc: 98.72%, Val Loss: 0.2072, Val Acc: 95.33%
# Epoch [47/50], Train Loss: 0.0550, Train Acc: 98.09%, Val Loss: 0.1724, Val Acc: 95.56%
# Epoch [48/50], Train Loss: 0.0544, Train Acc: 98.19%, Val Loss: 0.2007, Val Acc: 94.89%
# Epoch [49/50], Train Loss: 0.0541, Train Acc: 98.18%, Val Loss: 0.1620, Val Acc: 95.26%
# Epoch [50/50], Train Loss: 0.0568, Train Acc: 98.16%, Val Loss: 0.2012, Val Acc: 95.33%
# Test Accuracy: 95.15%
