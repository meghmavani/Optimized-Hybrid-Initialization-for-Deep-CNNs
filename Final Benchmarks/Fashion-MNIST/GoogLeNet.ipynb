# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.models as models
import torchvision.transforms as transforms
from torchvision.models import googlenet
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

run_name = 'Fashion-MNIST_GoogLeNet'

num_epochs = 50
batch_size = 128
learning_rate = 0.001

# Fashion-MNIST is grayscale: convert to 3-channel RGB (QMNIST notebook pattern)
train_transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.RandomHorizontalFlip(),
    transforms.Lambda(lambda img: img.convert("RGB")),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.Lambda(lambda img: img.convert("RGB")),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = torchvision.datasets.FashionMNIST(root='./data', train=True, transform=train_transform, download=True)
train_size = int(0.9 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

test_dataset = torchvision.datasets.FashionMNIST(root='./data', train=False, transform=test_transform, download=True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# Hybrid Initialization (He for Conv2d, Orthogonal for Linear)
def custom_init(model):
    for module in model.modules():
        if isinstance(module, nn.Conv2d):
            nn.init.kaiming_normal_(module.weight, mode='fan_out', nonlinearity='relu')
        elif isinstance(module, nn.Linear):
            nn.init.orthogonal_(module.weight)
        if hasattr(module, 'bias') and module.bias is not None:
            nn.init.constant_(module.bias, 0)

# GoogLeNet (torchvision, trained from scratch)
model = googlenet(num_classes=10, aux_logits=False)
model = model.to(device)
custom_init(model)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss_list.append(val_loss / len(val_loader))
    val_acc_list.append(val_acc)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc:.2f}%')

correct = 0
total = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f'Test Accuracy: {test_acc:.2f}%')

# Save metrics to files labelled with dataset + model name
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(num_epochs):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# /home/aadit/Projects/Optimized-Hybrid-Initialization-for-Deep-CNNs/.venv/lib/python3.13/site-packages/torchvision/models/googlenet.py:47: FutureWarning: The default weight initialization of GoogleNet will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(
# Epoch [1/50], Train Loss: 0.5931, Train Acc: 78.38%, Val Loss: 0.4083, Val Acc: 85.10%
# Epoch [2/50], Train Loss: 0.3794, Train Acc: 86.29%, Val Loss: 0.3722, Val Acc: 87.30%
# Epoch [3/50], Train Loss: 0.3262, Train Acc: 88.01%, Val Loss: 0.3232, Val Acc: 87.68%
# Epoch [4/50], Train Loss: 0.2990, Train Acc: 89.08%, Val Loss: 0.3321, Val Acc: 87.57%
# Epoch [5/50], Train Loss: 0.2799, Train Acc: 89.73%, Val Loss: 0.2920, Val Acc: 89.67%
# Epoch [6/50], Train Loss: 0.2598, Train Acc: 90.60%, Val Loss: 0.2747, Val Acc: 90.20%
# Epoch [7/50], Train Loss: 0.2465, Train Acc: 91.10%, Val Loss: 0.2533, Val Acc: 90.67%
# Epoch [8/50], Train Loss: 0.2332, Train Acc: 91.46%, Val Loss: 0.2562, Val Acc: 90.33%
# Epoch [9/50], Train Loss: 0.2266, Train Acc: 91.76%, Val Loss: 0.2835, Val Acc: 90.20%
# Epoch [10/50], Train Loss: 0.2161, Train Acc: 92.20%, Val Loss: 0.2366, Val Acc: 91.52%
# Epoch [11/50], Train Loss: 0.2080, Train Acc: 92.42%, Val Loss: 0.2293, Val Acc: 91.85%
# Epoch [12/50], Train Loss: 0.1974, Train Acc: 92.80%, Val Loss: 0.2246, Val Acc: 91.85%
# Epoch [13/50], Train Loss: 0.1917, Train Acc: 92.87%, Val Loss: 0.2612, Val Acc: 90.43%
# Epoch [14/50], Train Loss: 0.1845, Train Acc: 93.24%, Val Loss: 0.2710, Val Acc: 90.70%
# Epoch [15/50], Train Loss: 0.1752, Train Acc: 93.51%, Val Loss: 0.2212, Val Acc: 92.35%
# Epoch [16/50], Train Loss: 0.1711, Train Acc: 93.74%, Val Loss: 0.2351, Val Acc: 91.60%
# Epoch [17/50], Train Loss: 0.1614, Train Acc: 94.14%, Val Loss: 0.2446, Val Acc: 91.73%
# Epoch [18/50], Train Loss: 0.1553, Train Acc: 94.29%, Val Loss: 0.2384, Val Acc: 91.87%
# Epoch [19/50], Train Loss: 0.1491, Train Acc: 94.51%, Val Loss: 0.2484, Val Acc: 91.47%
# Epoch [20/50], Train Loss: 0.1424, Train Acc: 94.82%, Val Loss: 0.2302, Val Acc: 92.20%
# Epoch [21/50], Train Loss: 0.1340, Train Acc: 95.12%, Val Loss: 0.2397, Val Acc: 92.07%
# Epoch [22/50], Train Loss: 0.1296, Train Acc: 95.19%, Val Loss: 0.2228, Val Acc: 92.77%
# Epoch [23/50], Train Loss: 0.1202, Train Acc: 95.52%, Val Loss: 0.2505, Val Acc: 92.42%
# Epoch [24/50], Train Loss: 0.1205, Train Acc: 95.56%, Val Loss: 0.2318, Val Acc: 92.77%
# Epoch [25/50], Train Loss: 0.1102, Train Acc: 95.91%, Val Loss: 0.2360, Val Acc: 92.78%
# Epoch [26/50], Train Loss: 0.1063, Train Acc: 96.04%, Val Loss: 0.2208, Val Acc: 93.30%
# Epoch [27/50], Train Loss: 0.1001, Train Acc: 96.27%, Val Loss: 0.2499, Val Acc: 92.32%
# Epoch [28/50], Train Loss: 0.0993, Train Acc: 96.40%, Val Loss: 0.2655, Val Acc: 92.32%
# Epoch [29/50], Train Loss: 0.0900, Train Acc: 96.62%, Val Loss: 0.2732, Val Acc: 92.30%
# Epoch [30/50], Train Loss: 0.0879, Train Acc: 96.77%, Val Loss: 0.2845, Val Acc: 92.78%
# Epoch [31/50], Train Loss: 0.0850, Train Acc: 96.85%, Val Loss: 0.2956, Val Acc: 92.07%
# Epoch [32/50], Train Loss: 0.0811, Train Acc: 97.00%, Val Loss: 0.2679, Val Acc: 92.68%
# Epoch [33/50], Train Loss: 0.0745, Train Acc: 97.24%, Val Loss: 0.3072, Val Acc: 91.50%
# Epoch [34/50], Train Loss: 0.0740, Train Acc: 97.26%, Val Loss: 0.2665, Val Acc: 92.37%
# Epoch [35/50], Train Loss: 0.0699, Train Acc: 97.47%, Val Loss: 0.2711, Val Acc: 92.45%
# Epoch [36/50], Train Loss: 0.0657, Train Acc: 97.63%, Val Loss: 0.2886, Val Acc: 92.32%
# Epoch [37/50], Train Loss: 0.0652, Train Acc: 97.61%, Val Loss: 0.3253, Val Acc: 91.57%
# Epoch [38/50], Train Loss: 0.0622, Train Acc: 97.75%, Val Loss: 0.3170, Val Acc: 92.73%
# Epoch [39/50], Train Loss: 0.0590, Train Acc: 97.84%, Val Loss: 0.2817, Val Acc: 92.87%
# Epoch [40/50], Train Loss: 0.0558, Train Acc: 98.01%, Val Loss: 0.3016, Val Acc: 92.07%
# Epoch [41/50], Train Loss: 0.0546, Train Acc: 98.01%, Val Loss: 0.2785, Val Acc: 92.60%
# Epoch [42/50], Train Loss: 0.0527, Train Acc: 98.08%, Val Loss: 0.2860, Val Acc: 92.62%
# Epoch [43/50], Train Loss: 0.0527, Train Acc: 98.08%, Val Loss: 0.2805, Val Acc: 92.95%
# Epoch [44/50], Train Loss: 0.0491, Train Acc: 98.22%, Val Loss: 0.3152, Val Acc: 92.50%
# Epoch [45/50], Train Loss: 0.0511, Train Acc: 98.12%, Val Loss: 0.2872, Val Acc: 92.87%
# Epoch [46/50], Train Loss: 0.0451, Train Acc: 98.36%, Val Loss: 0.3131, Val Acc: 92.53%
# Epoch [47/50], Train Loss: 0.0460, Train Acc: 98.31%, Val Loss: 0.3289, Val Acc: 91.87%
# Epoch [48/50], Train Loss: 0.0424, Train Acc: 98.45%, Val Loss: 0.3403, Val Acc: 92.05%
# Epoch [49/50], Train Loss: 0.0395, Train Acc: 98.56%, Val Loss: 0.3151, Val Acc: 93.03%
# Epoch [50/50], Train Loss: 0.0430, Train Acc: 98.43%, Val Loss: 0.3413, Val Acc: 92.70%
# Test Accuracy: 91.96%
