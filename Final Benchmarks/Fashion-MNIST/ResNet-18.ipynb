# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.models as models
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

run_name = 'Fashion-MNIST_ResNet-18'

num_epochs = 50
batch_size = 128
learning_rate = 0.001

# Fashion-MNIST is grayscale: convert to 3-channel RGB (QMNIST notebook pattern)
train_transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.RandomHorizontalFlip(),
    transforms.Lambda(lambda img: img.convert("RGB")),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.Lambda(lambda img: img.convert("RGB")),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = torchvision.datasets.FashionMNIST(root='./data', train=True, transform=train_transform, download=True)
train_size = int(0.9 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

test_dataset = torchvision.datasets.FashionMNIST(root='./data', train=False, transform=test_transform, download=True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# Hybrid Initialization (He for Conv2d, Orthogonal for Linear)
def custom_init(model):
    for module in model.modules():
        if isinstance(module, nn.Conv2d):
            nn.init.kaiming_normal_(module.weight, mode='fan_out', nonlinearity='relu')
        elif isinstance(module, nn.Linear):
            nn.init.orthogonal_(module.weight)
        if hasattr(module, 'bias') and module.bias is not None:
            nn.init.constant_(module.bias, 0)

# ResNet-18 (torchvision, trained from scratch)
class ResNet18(nn.Module):
    def __init__(self):
        super(ResNet18, self).__init__()

        self.resnet = models.resnet18(weights=None)

        self.resnet.fc = nn.Linear(self.resnet.fc.in_features, 10)

    def forward(self, x):
        return self.resnet(x)

model = ResNet18().to(device)
custom_init(model)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss_list.append(val_loss / len(val_loader))
    val_acc_list.append(val_acc)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc:.2f}%')

correct = 0
total = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f'Test Accuracy: {test_acc:.2f}%')

# Save metrics to files labelled with dataset + model name
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(num_epochs):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Epoch [1/50], Train Loss: 0.4678, Train Acc: 83.21%, Val Loss: 0.3991, Val Acc: 85.52%
# Epoch [2/50], Train Loss: 0.3260, Train Acc: 87.87%, Val Loss: 0.3303, Val Acc: 87.83%
# Epoch [3/50], Train Loss: 0.2832, Train Acc: 89.47%, Val Loss: 0.2920, Val Acc: 88.98%
# Epoch [4/50], Train Loss: 0.2557, Train Acc: 90.47%, Val Loss: 0.2850, Val Acc: 89.45%
# Epoch [5/50], Train Loss: 0.2398, Train Acc: 91.04%, Val Loss: 0.2619, Val Acc: 90.53%
# Epoch [6/50], Train Loss: 0.2254, Train Acc: 91.67%, Val Loss: 0.2874, Val Acc: 88.73%
# Epoch [7/50], Train Loss: 0.2129, Train Acc: 91.80%, Val Loss: 0.2544, Val Acc: 90.78%
# Epoch [8/50], Train Loss: 0.2061, Train Acc: 92.35%, Val Loss: 0.2582, Val Acc: 90.33%
# Epoch [9/50], Train Loss: 0.1950, Train Acc: 92.61%, Val Loss: 0.2221, Val Acc: 91.65%
# Epoch [10/50], Train Loss: 0.1844, Train Acc: 93.12%, Val Loss: 0.2616, Val Acc: 90.68%
# Epoch [11/50], Train Loss: 0.1781, Train Acc: 93.26%, Val Loss: 0.2515, Val Acc: 91.28%
# Epoch [12/50], Train Loss: 0.1678, Train Acc: 93.61%, Val Loss: 0.2459, Val Acc: 90.95%
# Epoch [13/50], Train Loss: 0.1595, Train Acc: 93.93%, Val Loss: 0.2360, Val Acc: 91.78%
# Epoch [14/50], Train Loss: 0.1496, Train Acc: 94.34%, Val Loss: 0.2367, Val Acc: 91.30%
# Epoch [15/50], Train Loss: 0.1424, Train Acc: 94.60%, Val Loss: 0.2256, Val Acc: 92.18%
# Epoch [16/50], Train Loss: 0.1369, Train Acc: 94.71%, Val Loss: 0.2363, Val Acc: 91.83%
# Epoch [17/50], Train Loss: 0.1256, Train Acc: 95.12%, Val Loss: 0.2432, Val Acc: 91.67%
# Epoch [18/50], Train Loss: 0.1216, Train Acc: 95.34%, Val Loss: 0.2566, Val Acc: 91.78%
# Epoch [19/50], Train Loss: 0.1120, Train Acc: 95.70%, Val Loss: 0.2443, Val Acc: 91.97%
# Epoch [20/50], Train Loss: 0.1083, Train Acc: 95.92%, Val Loss: 0.2626, Val Acc: 91.45%
# Epoch [21/50], Train Loss: 0.0977, Train Acc: 96.28%, Val Loss: 0.2481, Val Acc: 92.25%
# Epoch [22/50], Train Loss: 0.0927, Train Acc: 96.47%, Val Loss: 0.2636, Val Acc: 91.62%
# Epoch [23/50], Train Loss: 0.0831, Train Acc: 96.80%, Val Loss: 0.2678, Val Acc: 91.98%
# Epoch [24/50], Train Loss: 0.0803, Train Acc: 97.02%, Val Loss: 0.2765, Val Acc: 92.08%
# Epoch [25/50], Train Loss: 0.0776, Train Acc: 97.05%, Val Loss: 0.2777, Val Acc: 92.43%
# Epoch [26/50], Train Loss: 0.0710, Train Acc: 97.29%, Val Loss: 0.3115, Val Acc: 91.90%
# Epoch [27/50], Train Loss: 0.0679, Train Acc: 97.41%, Val Loss: 0.2768, Val Acc: 92.15%
# Epoch [28/50], Train Loss: 0.0641, Train Acc: 97.53%, Val Loss: 0.2972, Val Acc: 92.53%
# Epoch [29/50], Train Loss: 0.0597, Train Acc: 97.71%, Val Loss: 0.3187, Val Acc: 91.92%
# Epoch [30/50], Train Loss: 0.0561, Train Acc: 97.88%, Val Loss: 0.3156, Val Acc: 92.37%
# Epoch [31/50], Train Loss: 0.0515, Train Acc: 98.02%, Val Loss: 0.3021, Val Acc: 92.47%
# Epoch [32/50], Train Loss: 0.0514, Train Acc: 98.11%, Val Loss: 0.3100, Val Acc: 92.53%
# Epoch [33/50], Train Loss: 0.0487, Train Acc: 98.14%, Val Loss: 0.3269, Val Acc: 91.93%
# Epoch [34/50], Train Loss: 0.0457, Train Acc: 98.27%, Val Loss: 0.3184, Val Acc: 92.42%
# Epoch [35/50], Train Loss: 0.0471, Train Acc: 98.26%, Val Loss: 0.3176, Val Acc: 92.18%
# Epoch [36/50], Train Loss: 0.0405, Train Acc: 98.53%, Val Loss: 0.3592, Val Acc: 92.05%
# Epoch [37/50], Train Loss: 0.0378, Train Acc: 98.56%, Val Loss: 0.3452, Val Acc: 91.98%
# Epoch [38/50], Train Loss: 0.0370, Train Acc: 98.65%, Val Loss: 0.3369, Val Acc: 92.40%
# Epoch [39/50], Train Loss: 0.0362, Train Acc: 98.69%, Val Loss: 0.3492, Val Acc: 92.65%
# Epoch [40/50], Train Loss: 0.0340, Train Acc: 98.79%, Val Loss: 0.3319, Val Acc: 92.55%
# Epoch [41/50], Train Loss: 0.0344, Train Acc: 98.74%, Val Loss: 0.3613, Val Acc: 92.73%
# Epoch [42/50], Train Loss: 0.0309, Train Acc: 98.88%, Val Loss: 0.3824, Val Acc: 91.97%
# Epoch [43/50], Train Loss: 0.0336, Train Acc: 98.81%, Val Loss: 0.3655, Val Acc: 92.23%
# Epoch [44/50], Train Loss: 0.0281, Train Acc: 98.99%, Val Loss: 0.3691, Val Acc: 92.05%
# Epoch [45/50], Train Loss: 0.0294, Train Acc: 98.95%, Val Loss: 0.3432, Val Acc: 92.55%
# Epoch [46/50], Train Loss: 0.0255, Train Acc: 99.08%, Val Loss: 0.3779, Val Acc: 92.38%
# Epoch [47/50], Train Loss: 0.0253, Train Acc: 99.06%, Val Loss: 0.3726, Val Acc: 92.72%
# Epoch [48/50], Train Loss: 0.0271, Train Acc: 99.01%, Val Loss: 0.4128, Val Acc: 92.22%
# Epoch [49/50], Train Loss: 0.0326, Train Acc: 98.90%, Val Loss: 0.3721, Val Acc: 92.52%
# Epoch [50/50], Train Loss: 0.0252, Train Acc: 99.09%, Val Loss: 0.3717, Val Acc: 92.35%
# Test Accuracy: 91.99%
