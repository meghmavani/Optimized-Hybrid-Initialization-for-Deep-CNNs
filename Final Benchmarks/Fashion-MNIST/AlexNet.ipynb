# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.models as models
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

run_name = 'Fashion-MNIST_AlexNet'

num_epochs = 50
batch_size = 128
learning_rate = 0.001

# Fashion-MNIST is grayscale: convert to 3-channel RGB (QMNIST notebook pattern)
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.Lambda(lambda img: img.convert("RGB")),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.Lambda(lambda img: img.convert("RGB")),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = torchvision.datasets.FashionMNIST(root='./data', train=True, transform=train_transform, download=True)
train_size = int(0.9 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

test_dataset = torchvision.datasets.FashionMNIST(root='./data', train=False, transform=test_transform, download=True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# Hybrid Initialization (He for Conv2d, Orthogonal for Linear)
def custom_init(model):
    for module in model.modules():
        if isinstance(module, nn.Conv2d):
            nn.init.kaiming_normal_(module.weight, mode='fan_out', nonlinearity='relu')
        elif isinstance(module, nn.Linear):
            nn.init.orthogonal_(module.weight)
        if hasattr(module, 'bias') and module.bias is not None:
            nn.init.constant_(module.bias, 0)

# AlexNet (torchvision, trained from scratch)
model = models.alexnet(weights=None)
model.classifier[6] = nn.Linear(4096, 10)
model = model.to(device)
custom_init(model)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss_list.append(val_loss / len(val_loader))
    val_acc_list.append(val_acc)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc:.2f}%')

correct = 0
total = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f'Test Accuracy: {test_acc:.2f}%')

# Save metrics to files labelled with dataset + model name
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(num_epochs):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Epoch [1/50], Train Loss: 0.6524, Train Acc: 76.98%, Val Loss: 0.3277, Val Acc: 87.70%
# Epoch [2/50], Train Loss: 0.3850, Train Acc: 85.62%, Val Loss: 0.2847, Val Acc: 89.10%
# Epoch [3/50], Train Loss: 0.3359, Train Acc: 87.72%, Val Loss: 0.3100, Val Acc: 89.07%
# Epoch [4/50], Train Loss: 0.3145, Train Acc: 88.42%, Val Loss: 0.2726, Val Acc: 90.23%
# Epoch [5/50], Train Loss: 0.3076, Train Acc: 88.60%, Val Loss: 0.2847, Val Acc: 90.18%
# Epoch [6/50], Train Loss: 0.2796, Train Acc: 89.62%, Val Loss: 0.2557, Val Acc: 91.02%
# Epoch [7/50], Train Loss: 0.2694, Train Acc: 90.08%, Val Loss: 0.2674, Val Acc: 90.35%
# Epoch [8/50], Train Loss: 0.2837, Train Acc: 89.76%, Val Loss: 0.2437, Val Acc: 90.72%
# Epoch [9/50], Train Loss: 0.2566, Train Acc: 90.54%, Val Loss: 0.2434, Val Acc: 91.33%
# Epoch [10/50], Train Loss: 0.2504, Train Acc: 90.81%, Val Loss: 0.2468, Val Acc: 91.08%
# Epoch [11/50], Train Loss: 0.2399, Train Acc: 91.12%, Val Loss: 0.2606, Val Acc: 90.97%
# Epoch [12/50], Train Loss: 0.2477, Train Acc: 90.84%, Val Loss: 0.2269, Val Acc: 91.68%
# Epoch [13/50], Train Loss: 0.2293, Train Acc: 91.55%, Val Loss: 0.2387, Val Acc: 91.72%
# Epoch [14/50], Train Loss: 0.2233, Train Acc: 91.68%, Val Loss: 0.2360, Val Acc: 91.70%
# Epoch [15/50], Train Loss: 0.2183, Train Acc: 91.82%, Val Loss: 0.2408, Val Acc: 91.27%
# Epoch [16/50], Train Loss: 0.2184, Train Acc: 91.95%, Val Loss: 0.2234, Val Acc: 91.83%
# Epoch [17/50], Train Loss: 0.2082, Train Acc: 92.27%, Val Loss: 0.2295, Val Acc: 91.68%
# Epoch [18/50], Train Loss: 0.2095, Train Acc: 92.22%, Val Loss: 0.2255, Val Acc: 91.97%
# Epoch [19/50], Train Loss: 0.1999, Train Acc: 92.64%, Val Loss: 0.2333, Val Acc: 91.88%
# Epoch [20/50], Train Loss: 0.2048, Train Acc: 92.53%, Val Loss: 0.2570, Val Acc: 90.52%
# Epoch [21/50], Train Loss: 0.1960, Train Acc: 92.76%, Val Loss: 0.2449, Val Acc: 91.97%
# Epoch [22/50], Train Loss: 0.1945, Train Acc: 92.77%, Val Loss: 0.2422, Val Acc: 91.67%
# Epoch [23/50], Train Loss: 0.1977, Train Acc: 92.78%, Val Loss: 0.2321, Val Acc: 91.63%
# Epoch [24/50], Train Loss: 0.1899, Train Acc: 93.08%, Val Loss: 0.2206, Val Acc: 92.35%
# Epoch [25/50], Train Loss: 0.1897, Train Acc: 92.97%, Val Loss: 0.2362, Val Acc: 91.73%
# Epoch [26/50], Train Loss: 0.1830, Train Acc: 93.27%, Val Loss: 0.2276, Val Acc: 92.33%
# Epoch [27/50], Train Loss: 0.1739, Train Acc: 93.54%, Val Loss: 0.2263, Val Acc: 92.17%
# Epoch [28/50], Train Loss: 0.1732, Train Acc: 93.54%, Val Loss: 0.2326, Val Acc: 92.17%
# Epoch [29/50], Train Loss: 0.1758, Train Acc: 93.32%, Val Loss: 0.2339, Val Acc: 92.35%
# Epoch [30/50], Train Loss: 0.1756, Train Acc: 93.54%, Val Loss: 0.2374, Val Acc: 91.90%
# Epoch [31/50], Train Loss: 0.1742, Train Acc: 93.59%, Val Loss: 0.2244, Val Acc: 91.92%
# Epoch [32/50], Train Loss: 0.1917, Train Acc: 93.04%, Val Loss: 0.2396, Val Acc: 91.43%
# Epoch [33/50], Train Loss: 0.1785, Train Acc: 93.38%, Val Loss: 0.2223, Val Acc: 92.15%
# Epoch [34/50], Train Loss: 0.1618, Train Acc: 94.04%, Val Loss: 0.2227, Val Acc: 92.53%
# Epoch [35/50], Train Loss: 0.1611, Train Acc: 94.03%, Val Loss: 0.2185, Val Acc: 92.47%
# Epoch [36/50], Train Loss: 0.1720, Train Acc: 93.78%, Val Loss: 0.2236, Val Acc: 92.43%
# Epoch [37/50], Train Loss: 0.1598, Train Acc: 94.09%, Val Loss: 0.2351, Val Acc: 92.13%
# Epoch [38/50], Train Loss: 0.1584, Train Acc: 94.09%, Val Loss: 0.2339, Val Acc: 92.47%
# Epoch [39/50], Train Loss: 0.1549, Train Acc: 94.40%, Val Loss: 0.2407, Val Acc: 91.90%
# Epoch [40/50], Train Loss: 0.1483, Train Acc: 94.50%, Val Loss: 0.2164, Val Acc: 92.72%
# Epoch [41/50], Train Loss: 0.1495, Train Acc: 94.52%, Val Loss: 0.2296, Val Acc: 92.43%
# Epoch [42/50], Train Loss: 0.2178, Train Acc: 92.32%, Val Loss: 0.2165, Val Acc: 92.50%
# Epoch [43/50], Train Loss: 0.1513, Train Acc: 94.57%, Val Loss: 0.2111, Val Acc: 92.43%
# Epoch [44/50], Train Loss: 0.1390, Train Acc: 94.83%, Val Loss: 0.2078, Val Acc: 92.88%
# Epoch [45/50], Train Loss: 0.1353, Train Acc: 95.05%, Val Loss: 0.2175, Val Acc: 92.88%
# Epoch [46/50], Train Loss: 0.1315, Train Acc: 95.09%, Val Loss: 0.2142, Val Acc: 92.73%
# Epoch [47/50], Train Loss: 0.1379, Train Acc: 94.94%, Val Loss: 0.2344, Val Acc: 92.20%
# Epoch [48/50], Train Loss: 0.1459, Train Acc: 94.74%, Val Loss: 0.2300, Val Acc: 92.35%
# Epoch [49/50], Train Loss: 0.1327, Train Acc: 95.07%, Val Loss: 0.2317, Val Acc: 92.67%
# Epoch [50/50], Train Loss: 0.1373, Train Acc: 95.01%, Val Loss: 0.2288, Val Acc: 92.58%
# Test Accuracy: 92.38%
