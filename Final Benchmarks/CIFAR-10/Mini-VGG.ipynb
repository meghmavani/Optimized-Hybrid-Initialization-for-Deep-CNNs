# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

num_epochs = 50
batch_size = 128
learning_rate = 0.001

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, transform=train_transform, download=True)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, transform=test_transform, download=True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    layer_idx = 0
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            if layer_idx < 6:
                nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
            else:
                nn.init.orthogonal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
            layer_idx += 1

class VGGLike(nn.Module):
    def __init__(self):
        super(VGGLike, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, 3, padding=1), nn.ReLU(), nn.BatchNorm2d(64),
            nn.Conv2d(64, 64, 3, padding=1), nn.ReLU(), nn.BatchNorm2d(64),
            nn.MaxPool2d(2, 2),

            nn.Conv2d(64, 128, 3, padding=1), nn.ReLU(), nn.BatchNorm2d(128),
            nn.Conv2d(128, 128, 3, padding=1), nn.ReLU(), nn.BatchNorm2d(128),
            nn.MaxPool2d(2, 2)
        )
        self.classifier = nn.Sequential(
            nn.Linear(8*8*128, 256), nn.ReLU(),
            nn.Linear(256, 10)
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        return self.classifier(x)

def train_model(model):
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)

    train_acc_list, val_acc_list = [], []
    train_loss_list, val_loss_list = [], []

    start_time = time.time()

    for epoch in range(num_epochs):
        model.train()
        correct, total, train_loss = 0, 0, 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_acc = 100 * correct / total
        train_acc_list.append(train_acc)
        train_loss_list.append(train_loss / len(train_loader))

        model.eval()
        correct, total, val_loss = 0, 0, 0
        with torch.no_grad():
            for images, labels in test_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        val_acc = 100 * correct / total
        val_acc_list.append(val_acc)
        val_loss_list.append(val_loss / len(test_loader))

        scheduler.step()

        print(f"Epoch [{epoch+1}/{num_epochs}] Train Acc: {train_acc:.2f}% Val Acc: {val_acc:.2f}% Train Loss: {train_loss_list[-1]:.4f} Val Loss: {val_loss_list[-1]:.4f}")

    duration = time.time() - start_time
    return train_acc_list, val_acc_list, train_loss_list, val_loss_list, duration

model = VGGLike()
custom_init(model)
train_acc, val_acc, train_loss, val_loss, time_taken = train_model(model)

plt.figure(figsize=(6, 4))
plt.plot(train_loss, label='Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train Loss')
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(val_loss, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Validation Loss')
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(train_acc, label='Train Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Train Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(val_acc, label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Validation Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

print(f"\nTraining completed in {time_taken:.2f} seconds.")
# Out:
# Epoch [1/50] Train Acc: 44.38% Val Acc: 59.38% Train Loss: 1.7084 Val Loss: 1.1553
# Epoch [2/50] Train Acc: 61.06% Val Acc: 68.23% Train Loss: 1.0919 Val Loss: 0.9003
# Epoch [3/50] Train Acc: 68.72% Val Acc: 73.97% Train Loss: 0.8885 Val Loss: 0.7535
# Epoch [4/50] Train Acc: 73.25% Val Acc: 76.42% Train Loss: 0.7694 Val Loss: 0.6959
# Epoch [5/50] Train Acc: 76.06% Val Acc: 78.46% Train Loss: 0.6794 Val Loss: 0.6263
# Epoch [6/50] Train Acc: 78.52% Val Acc: 80.22% Train Loss: 0.6171 Val Loss: 0.5771
# Epoch [7/50] Train Acc: 80.21% Val Acc: 80.98% Train Loss: 0.5678 Val Loss: 0.5616
# Epoch [8/50] Train Acc: 81.85% Val Acc: 81.07% Train Loss: 0.5246 Val Loss: 0.5706
# Epoch [9/50] Train Acc: 82.83% Val Acc: 83.04% Train Loss: 0.4950 Val Loss: 0.5189
# Epoch [10/50] Train Acc: 84.01% Val Acc: 83.82% Train Loss: 0.4607 Val Loss: 0.4924
# Epoch [11/50] Train Acc: 85.10% Val Acc: 84.44% Train Loss: 0.4316 Val Loss: 0.4774
# Epoch [12/50] Train Acc: 85.63% Val Acc: 84.51% Train Loss: 0.4146 Val Loss: 0.4850
# Epoch [13/50] Train Acc: 86.69% Val Acc: 85.16% Train Loss: 0.3875 Val Loss: 0.4582
# Epoch [14/50] Train Acc: 87.16% Val Acc: 84.84% Train Loss: 0.3686 Val Loss: 0.4593
# Epoch [15/50] Train Acc: 87.94% Val Acc: 85.43% Train Loss: 0.3495 Val Loss: 0.4637
# Epoch [16/50] Train Acc: 88.60% Val Acc: 85.39% Train Loss: 0.3327 Val Loss: 0.4663
# Epoch [17/50] Train Acc: 88.78% Val Acc: 86.21% Train Loss: 0.3237 Val Loss: 0.4295
# Epoch [18/50] Train Acc: 89.55% Val Acc: 86.01% Train Loss: 0.3022 Val Loss: 0.4341
# Epoch [19/50] Train Acc: 89.98% Val Acc: 86.37% Train Loss: 0.2910 Val Loss: 0.4301
# Epoch [20/50] Train Acc: 90.40% Val Acc: 86.95% Train Loss: 0.2764 Val Loss: 0.4271
# Epoch [21/50] Train Acc: 91.02% Val Acc: 86.67% Train Loss: 0.2585 Val Loss: 0.4437
# Epoch [22/50] Train Acc: 91.43% Val Acc: 86.83% Train Loss: 0.2491 Val Loss: 0.4389
# Epoch [23/50] Train Acc: 91.75% Val Acc: 87.22% Train Loss: 0.2358 Val Loss: 0.4336
# Epoch [24/50] Train Acc: 92.24% Val Acc: 87.05% Train Loss: 0.2230 Val Loss: 0.4261
# Epoch [25/50] Train Acc: 92.59% Val Acc: 87.32% Train Loss: 0.2136 Val Loss: 0.4412
# Epoch [26/50] Train Acc: 93.20% Val Acc: 87.45% Train Loss: 0.1984 Val Loss: 0.4397
# Epoch [27/50] Train Acc: 93.31% Val Acc: 87.83% Train Loss: 0.1939 Val Loss: 0.4438
# Epoch [28/50] Train Acc: 93.75% Val Acc: 88.10% Train Loss: 0.1789 Val Loss: 0.4400
# Epoch [29/50] Train Acc: 93.86% Val Acc: 87.72% Train Loss: 0.1772 Val Loss: 0.4499
# Epoch [30/50] Train Acc: 94.34% Val Acc: 87.52% Train Loss: 0.1643 Val Loss: 0.4351
# Epoch [31/50] Train Acc: 94.64% Val Acc: 88.04% Train Loss: 0.1562 Val Loss: 0.4427
# Epoch [32/50] Train Acc: 94.80% Val Acc: 87.81% Train Loss: 0.1492 Val Loss: 0.4401
# Epoch [33/50] Train Acc: 95.31% Val Acc: 87.81% Train Loss: 0.1384 Val Loss: 0.4520
# Epoch [34/50] Train Acc: 95.56% Val Acc: 88.15% Train Loss: 0.1271 Val Loss: 0.4543
# Epoch [35/50] Train Acc: 95.73% Val Acc: 88.33% Train Loss: 0.1229 Val Loss: 0.4471
# Epoch [36/50] Train Acc: 95.89% Val Acc: 88.36% Train Loss: 0.1173 Val Loss: 0.4551
# Epoch [37/50] Train Acc: 96.11% Val Acc: 88.32% Train Loss: 0.1125 Val Loss: 0.4579
# Epoch [38/50] Train Acc: 96.44% Val Acc: 88.54% Train Loss: 0.1053 Val Loss: 0.4606
# Epoch [39/50] Train Acc: 96.42% Val Acc: 88.75% Train Loss: 0.1021 Val Loss: 0.4551
# Epoch [40/50] Train Acc: 96.62% Val Acc: 88.56% Train Loss: 0.0981 Val Loss: 0.4598
# Epoch [41/50] Train Acc: 96.80% Val Acc: 88.55% Train Loss: 0.0942 Val Loss: 0.4588
# Epoch [42/50] Train Acc: 97.08% Val Acc: 88.66% Train Loss: 0.0874 Val Loss: 0.4632
# Epoch [43/50] Train Acc: 97.01% Val Acc: 88.69% Train Loss: 0.0886 Val Loss: 0.4584
# Epoch [44/50] Train Acc: 97.14% Val Acc: 88.75% Train Loss: 0.0828 Val Loss: 0.4621
# Epoch [45/50] Train Acc: 97.05% Val Acc: 88.69% Train Loss: 0.0855 Val Loss: 0.4630
# Epoch [46/50] Train Acc: 97.26% Val Acc: 88.82% Train Loss: 0.0812 Val Loss: 0.4605
# Epoch [47/50] Train Acc: 97.32% Val Acc: 88.79% Train Loss: 0.0790 Val Loss: 0.4646
# Epoch [48/50] Train Acc: 97.38% Val Acc: 88.90% Train Loss: 0.0788 Val Loss: 0.4629
# Epoch [49/50] Train Acc: 97.30% Val Acc: 88.93% Train Loss: 0.0805 Val Loss: 0.4646
# Epoch [50/50] Train Acc: 97.36% Val Acc: 88.87% Train Loss: 0.0768 Val Loss: 0.4642
# Training completed in 1279.84 seconds.
