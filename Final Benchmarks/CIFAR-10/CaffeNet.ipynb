# %%
import ssl
import urllib.request
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time

ssl._create_default_https_context = ssl._create_unverified_context
urllib.request.install_opener(
    urllib.request.build_opener(
        urllib.request.HTTPSHandler(context=ssl._create_unverified_context())
    )
)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

num_epochs = 50
batch_size = 128
learning_rate = 0.001

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, transform=train_transform, download=True)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, transform=test_transform, download=True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    layer_idx = 0
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            if layer_idx < 6:
                nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
            else:
                nn.init.orthogonal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
            layer_idx += 1

class CaffeNet(nn.Module):
    def __init__(self):
        super(CaffeNet, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=5, stride=1, padding=2)
        self.pool1 = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 192, kernel_size=5, stride=1, padding=2)
        self.pool2 = nn.MaxPool2d(2, 2)
        self.conv3 = nn.Conv2d(192, 384, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(384, 256, kernel_size=3, padding=1)
        self.conv5 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.pool3 = nn.MaxPool2d(2, 2)

        self.fc1 = nn.Linear(4*4*256, 4096)
        self.fc2 = nn.Linear(4096, 4096)
        self.fc3 = nn.Linear(4096, 10)
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool1(x)
        x = F.relu(self.conv2(x))
        x = self.pool2(x)
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.relu(self.conv5(x))
        x = self.pool3(x)
        x = x.view(x.size(0), -1)
        x = self.dropout(F.relu(self.fc1(x)))
        x = self.dropout(F.relu(self.fc2(x)))
        return self.fc3(x)

def train_model(model):
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)

    train_acc_list, val_acc_list = [], []
    train_loss_list, val_loss_list = [], []

    start_time = time.time()

    for epoch in range(num_epochs):
        model.train()
        correct, total, train_loss = 0, 0, 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_acc = 100 * correct / total
        train_acc_list.append(train_acc)
        train_loss_list.append(train_loss / len(train_loader))

        model.eval()
        correct, total, val_loss = 0, 0, 0
        with torch.no_grad():
            for images, labels in test_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        val_acc = 100 * correct / total
        val_acc_list.append(val_acc)
        val_loss_list.append(val_loss / len(test_loader))

        scheduler.step()

        print(f"Epoch [{epoch+1}/{num_epochs}] Train Acc: {train_acc:.2f}% Val Acc: {val_acc:.2f}% Train Loss: {train_loss_list[-1]:.4f} Val Loss: {val_loss_list[-1]:.4f}")

    duration = time.time() - start_time
    return train_acc_list, val_acc_list, train_loss_list, val_loss_list, duration

model = CaffeNet()
custom_init(model)
train_acc, val_acc, train_loss, val_loss, time_taken = train_model(model)

plt.figure(figsize=(6, 4))
plt.plot(train_loss, label='Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train Loss')
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(val_loss, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Validation Loss')
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(train_acc, label='Train Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Train Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(val_acc, label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Validation Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

print(f"\nTraining completed in {time_taken:.2f} seconds.")
# Out:
# Epoch [1/50] Train Acc: 35.05% Val Acc: 46.86% Train Loss: 1.8250 Val Loss: 1.4308
# Epoch [2/50] Train Acc: 50.39% Val Acc: 58.75% Train Loss: 1.3690 Val Loss: 1.1385
# Epoch [3/50] Train Acc: 57.88% Val Acc: 64.58% Train Loss: 1.1782 Val Loss: 1.0057
# Epoch [4/50] Train Acc: 62.29% Val Acc: 67.17% Train Loss: 1.0693 Val Loss: 0.9401
# Epoch [5/50] Train Acc: 66.35% Val Acc: 69.35% Train Loss: 0.9659 Val Loss: 0.8741
# Epoch [6/50] Train Acc: 68.58% Val Acc: 71.65% Train Loss: 0.9014 Val Loss: 0.8230
# Epoch [7/50] Train Acc: 70.55% Val Acc: 73.58% Train Loss: 0.8448 Val Loss: 0.7602
# Epoch [8/50] Train Acc: 72.43% Val Acc: 74.62% Train Loss: 0.7930 Val Loss: 0.7571
# Epoch [9/50] Train Acc: 73.62% Val Acc: 74.04% Train Loss: 0.7675 Val Loss: 0.7644
# Epoch [10/50] Train Acc: 74.99% Val Acc: 76.06% Train Loss: 0.7261 Val Loss: 0.7004
# Epoch [11/50] Train Acc: 75.91% Val Acc: 74.46% Train Loss: 0.7013 Val Loss: 0.7420
# Epoch [12/50] Train Acc: 76.71% Val Acc: 76.85% Train Loss: 0.6803 Val Loss: 0.6622
# Epoch [13/50] Train Acc: 77.43% Val Acc: 77.51% Train Loss: 0.6562 Val Loss: 0.6644
# Epoch [14/50] Train Acc: 78.40% Val Acc: 79.33% Train Loss: 0.6276 Val Loss: 0.6223
# Epoch [15/50] Train Acc: 79.02% Val Acc: 78.73% Train Loss: 0.6147 Val Loss: 0.6279
# Epoch [16/50] Train Acc: 79.65% Val Acc: 78.58% Train Loss: 0.5979 Val Loss: 0.6219
# Epoch [17/50] Train Acc: 80.35% Val Acc: 80.16% Train Loss: 0.5784 Val Loss: 0.5921
# Epoch [18/50] Train Acc: 80.86% Val Acc: 80.25% Train Loss: 0.5593 Val Loss: 0.5872
# Epoch [19/50] Train Acc: 81.73% Val Acc: 80.72% Train Loss: 0.5334 Val Loss: 0.5796
# Epoch [20/50] Train Acc: 81.98% Val Acc: 81.18% Train Loss: 0.5258 Val Loss: 0.5590
# Epoch [21/50] Train Acc: 82.65% Val Acc: 80.82% Train Loss: 0.5077 Val Loss: 0.5766
# Epoch [22/50] Train Acc: 83.38% Val Acc: 81.10% Train Loss: 0.4900 Val Loss: 0.5665
# Epoch [23/50] Train Acc: 83.68% Val Acc: 80.97% Train Loss: 0.4758 Val Loss: 0.5603
# Epoch [24/50] Train Acc: 84.31% Val Acc: 82.83% Train Loss: 0.4528 Val Loss: 0.5181
# Epoch [25/50] Train Acc: 84.90% Val Acc: 82.28% Train Loss: 0.4395 Val Loss: 0.5373
# Epoch [26/50] Train Acc: 85.42% Val Acc: 82.03% Train Loss: 0.4270 Val Loss: 0.5396
# Epoch [27/50] Train Acc: 85.66% Val Acc: 83.05% Train Loss: 0.4061 Val Loss: 0.5252
# Epoch [28/50] Train Acc: 86.43% Val Acc: 82.07% Train Loss: 0.3891 Val Loss: 0.5571
# Epoch [29/50] Train Acc: 87.20% Val Acc: 83.39% Train Loss: 0.3711 Val Loss: 0.5171
# Epoch [30/50] Train Acc: 87.50% Val Acc: 83.04% Train Loss: 0.3618 Val Loss: 0.5248
# Epoch [31/50] Train Acc: 87.90% Val Acc: 83.03% Train Loss: 0.3485 Val Loss: 0.5205
# Epoch [32/50] Train Acc: 88.47% Val Acc: 83.44% Train Loss: 0.3339 Val Loss: 0.5214
# Epoch [33/50] Train Acc: 88.96% Val Acc: 83.95% Train Loss: 0.3170 Val Loss: 0.5007
# Epoch [34/50] Train Acc: 89.57% Val Acc: 83.86% Train Loss: 0.3017 Val Loss: 0.5064
# Epoch [35/50] Train Acc: 89.95% Val Acc: 84.07% Train Loss: 0.2902 Val Loss: 0.5121
# Epoch [36/50] Train Acc: 90.24% Val Acc: 84.52% Train Loss: 0.2779 Val Loss: 0.4937
# Epoch [37/50] Train Acc: 90.49% Val Acc: 84.33% Train Loss: 0.2673 Val Loss: 0.5153
# Epoch [38/50] Train Acc: 90.92% Val Acc: 84.38% Train Loss: 0.2559 Val Loss: 0.5118
# Epoch [39/50] Train Acc: 91.35% Val Acc: 84.92% Train Loss: 0.2467 Val Loss: 0.5108
# Epoch [40/50] Train Acc: 91.56% Val Acc: 84.70% Train Loss: 0.2404 Val Loss: 0.5111
# Epoch [41/50] Train Acc: 91.90% Val Acc: 84.92% Train Loss: 0.2301 Val Loss: 0.5163
# Epoch [42/50] Train Acc: 92.05% Val Acc: 84.85% Train Loss: 0.2256 Val Loss: 0.5184
# Epoch [43/50] Train Acc: 92.40% Val Acc: 85.07% Train Loss: 0.2139 Val Loss: 0.5165
# Epoch [44/50] Train Acc: 92.41% Val Acc: 85.02% Train Loss: 0.2119 Val Loss: 0.5203
# Epoch [45/50] Train Acc: 92.57% Val Acc: 85.10% Train Loss: 0.2079 Val Loss: 0.5200
# Epoch [46/50] Train Acc: 92.95% Val Acc: 85.20% Train Loss: 0.2011 Val Loss: 0.5142
# Epoch [47/50] Train Acc: 92.74% Val Acc: 85.08% Train Loss: 0.2054 Val Loss: 0.5185
# Epoch [48/50] Train Acc: 93.04% Val Acc: 85.13% Train Loss: 0.1990 Val Loss: 0.5218
# Epoch [49/50] Train Acc: 92.95% Val Acc: 85.25% Train Loss: 0.2017 Val Loss: 0.5206
# Epoch [50/50] Train Acc: 92.92% Val Acc: 85.20% Train Loss: 0.2008 Val Loss: 0.5204
# Training completed in 2286.82 seconds.
