# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

num_epochs = 50
batch_size = 128
learning_rate = 0.001

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, transform=train_transform, download=True)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, transform=test_transform, download=True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    layer_idx = 0
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            if layer_idx < 6:
                nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
            else:
                nn.init.orthogonal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
            layer_idx += 1

class Inception(nn.Module):
    def __init__(self, in_channels, ch1x1, ch3x3red, ch3x3, ch5x5red, ch5x5, pool_proj):
        super(Inception, self).__init__()
        self.branch1 = nn.Conv2d(in_channels, ch1x1, kernel_size=1)

        self.branch2 = nn.Sequential(
            nn.Conv2d(in_channels, ch3x3red, kernel_size=1),
            nn.ReLU(),
            nn.Conv2d(ch3x3red, ch3x3, kernel_size=3, padding=1)
        )

        self.branch3 = nn.Sequential(
            nn.Conv2d(in_channels, ch5x5red, kernel_size=1),
            nn.ReLU(),
            nn.Conv2d(ch5x5red, ch5x5, kernel_size=3, padding=1)
        )

        self.branch4 = nn.Sequential(
            nn.MaxPool2d(kernel_size=3, stride=1, padding=1),
            nn.Conv2d(in_channels, pool_proj, kernel_size=1)
        )

    def forward(self, x):
        return torch.cat([
            self.branch1(x),
            self.branch2(x),
            self.branch3(x),
            self.branch4(x)
        ], 1)

class GoogLeNetSmall(nn.Module):
    def __init__(self, num_classes=10):
        super(GoogLeNetSmall, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.inception1 = Inception(64, 32, 48, 64, 8, 16, 16)
        self.inception2 = Inception(128, 64, 64, 96, 16, 32, 32)
        self.pool = nn.AdaptiveAvgPool2d((1, 1))
        self.dropout = nn.Dropout(0.4)
        self.linear = nn.Linear(224, num_classes)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.inception1(x)
        x = self.inception2(x)
        x = self.pool(x)
        x = x.view(x.size(0), -1)
        x = self.dropout(x)
        return self.linear(x)

def train_model(model):
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)

    train_acc_list, val_acc_list = [], []
    train_loss_list, val_loss_list = [], []

    start_time = time.time()

    for epoch in range(num_epochs):
        model.train()
        correct, total, train_loss = 0, 0, 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_acc = 100 * correct / total
        train_acc_list.append(train_acc)
        train_loss_list.append(train_loss / len(train_loader))

        model.eval()
        correct, total, val_loss = 0, 0, 0
        with torch.no_grad():
            for images, labels in test_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        val_acc = 100 * correct / total
        val_acc_list.append(val_acc)
        val_loss_list.append(val_loss / len(test_loader))

        scheduler.step()

        print(f"Epoch [{epoch+1}/{num_epochs}] Train Acc: {train_acc:.2f}% Val Acc: {val_acc:.2f}% Train Loss: {train_loss_list[-1]:.4f} Val Loss: {val_loss_list[-1]:.4f}")

    duration = time.time() - start_time
    return train_acc_list, val_acc_list, train_loss_list, val_loss_list, duration

model = GoogLeNetSmall()
custom_init(model)
train_acc, val_acc, train_loss, val_loss, time_taken = train_model(model)

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_acc, label='Train Acc')
plt.plot(val_acc, label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy Curve')
plt.legend()

plt.tight_layout()
plt.show()

print(f"\nTraining completed in {time_taken:.2f} seconds.")
# Out:
# Epoch [1/50] Train Acc: 29.69% Val Acc: 35.91% Train Loss: 1.8900 Val Loss: 1.7111
# Epoch [2/50] Train Acc: 40.58% Val Acc: 46.62% Train Loss: 1.5935 Val Loss: 1.4748
# Epoch [3/50] Train Acc: 47.08% Val Acc: 48.96% Train Loss: 1.4418 Val Loss: 1.3927
# Epoch [4/50] Train Acc: 50.73% Val Acc: 52.21% Train Loss: 1.3573 Val Loss: 1.3379
# Epoch [5/50] Train Acc: 52.80% Val Acc: 53.24% Train Loss: 1.3076 Val Loss: 1.3000
# Epoch [6/50] Train Acc: 54.70% Val Acc: 53.93% Train Loss: 1.2603 Val Loss: 1.2862
# Epoch [7/50] Train Acc: 56.08% Val Acc: 53.67% Train Loss: 1.2257 Val Loss: 1.2792
# Epoch [8/50] Train Acc: 57.41% Val Acc: 58.77% Train Loss: 1.1935 Val Loss: 1.1633
# Epoch [9/50] Train Acc: 58.41% Val Acc: 58.78% Train Loss: 1.1645 Val Loss: 1.1625
# Epoch [10/50] Train Acc: 59.11% Val Acc: 59.76% Train Loss: 1.1434 Val Loss: 1.1299
# Epoch [11/50] Train Acc: 60.13% Val Acc: 60.15% Train Loss: 1.1224 Val Loss: 1.1249
# Epoch [12/50] Train Acc: 61.25% Val Acc: 61.46% Train Loss: 1.0899 Val Loss: 1.0797
# Epoch [13/50] Train Acc: 62.14% Val Acc: 61.94% Train Loss: 1.0694 Val Loss: 1.0826
# Epoch [14/50] Train Acc: 62.69% Val Acc: 62.85% Train Loss: 1.0536 Val Loss: 1.0538
# Epoch [15/50] Train Acc: 63.78% Val Acc: 63.45% Train Loss: 1.0293 Val Loss: 1.0430
# Epoch [16/50] Train Acc: 64.26% Val Acc: 63.38% Train Loss: 1.0124 Val Loss: 1.0274
# Epoch [17/50] Train Acc: 64.92% Val Acc: 64.61% Train Loss: 0.9992 Val Loss: 0.9986
# Epoch [18/50] Train Acc: 65.52% Val Acc: 65.65% Train Loss: 0.9848 Val Loss: 0.9889
# Epoch [19/50] Train Acc: 65.95% Val Acc: 64.55% Train Loss: 0.9691 Val Loss: 1.0013
# Epoch [20/50] Train Acc: 66.53% Val Acc: 66.34% Train Loss: 0.9538 Val Loss: 0.9581
# Epoch [21/50] Train Acc: 67.04% Val Acc: 67.31% Train Loss: 0.9416 Val Loss: 0.9295
# Epoch [22/50] Train Acc: 67.45% Val Acc: 66.18% Train Loss: 0.9292 Val Loss: 0.9838
# Epoch [23/50] Train Acc: 67.72% Val Acc: 67.97% Train Loss: 0.9159 Val Loss: 0.9214
# Epoch [24/50] Train Acc: 68.58% Val Acc: 67.43% Train Loss: 0.9040 Val Loss: 0.9207
# Epoch [25/50] Train Acc: 68.48% Val Acc: 68.48% Train Loss: 0.8976 Val Loss: 0.9002
# Epoch [26/50] Train Acc: 69.16% Val Acc: 67.22% Train Loss: 0.8814 Val Loss: 0.9406
# Epoch [27/50] Train Acc: 69.47% Val Acc: 68.59% Train Loss: 0.8754 Val Loss: 0.8966
# Epoch [28/50] Train Acc: 69.75% Val Acc: 68.84% Train Loss: 0.8666 Val Loss: 0.8888
# Epoch [29/50] Train Acc: 69.96% Val Acc: 68.56% Train Loss: 0.8575 Val Loss: 0.9138
# Epoch [30/50] Train Acc: 70.38% Val Acc: 68.49% Train Loss: 0.8501 Val Loss: 0.9052
# Epoch [31/50] Train Acc: 70.76% Val Acc: 69.59% Train Loss: 0.8413 Val Loss: 0.8808
# Epoch [32/50] Train Acc: 71.01% Val Acc: 70.23% Train Loss: 0.8336 Val Loss: 0.8612
# Epoch [33/50] Train Acc: 71.19% Val Acc: 69.56% Train Loss: 0.8247 Val Loss: 0.8713
# Epoch [34/50] Train Acc: 71.44% Val Acc: 69.93% Train Loss: 0.8190 Val Loss: 0.8566
# Epoch [35/50] Train Acc: 71.71% Val Acc: 70.58% Train Loss: 0.8109 Val Loss: 0.8473
# Epoch [36/50] Train Acc: 72.12% Val Acc: 70.65% Train Loss: 0.8049 Val Loss: 0.8464
# Epoch [37/50] Train Acc: 72.27% Val Acc: 70.63% Train Loss: 0.7979 Val Loss: 0.8391
# Epoch [38/50] Train Acc: 72.51% Val Acc: 70.78% Train Loss: 0.7916 Val Loss: 0.8420
# Epoch [39/50] Train Acc: 72.67% Val Acc: 71.22% Train Loss: 0.7883 Val Loss: 0.8275
# Epoch [40/50] Train Acc: 72.54% Val Acc: 71.38% Train Loss: 0.7852 Val Loss: 0.8262
# Epoch [41/50] Train Acc: 72.83% Val Acc: 71.07% Train Loss: 0.7802 Val Loss: 0.8282
# Epoch [42/50] Train Acc: 72.95% Val Acc: 71.30% Train Loss: 0.7780 Val Loss: 0.8311
# Epoch [43/50] Train Acc: 72.92% Val Acc: 71.33% Train Loss: 0.7742 Val Loss: 0.8295
# Epoch [44/50] Train Acc: 73.26% Val Acc: 71.24% Train Loss: 0.7684 Val Loss: 0.8309
# Epoch [45/50] Train Acc: 73.24% Val Acc: 71.51% Train Loss: 0.7673 Val Loss: 0.8247
# Epoch [46/50] Train Acc: 73.48% Val Acc: 71.47% Train Loss: 0.7674 Val Loss: 0.8206
# Epoch [47/50] Train Acc: 73.30% Val Acc: 71.74% Train Loss: 0.7638 Val Loss: 0.8200
# Epoch [48/50] Train Acc: 73.48% Val Acc: 71.61% Train Loss: 0.7641 Val Loss: 0.8205
# Epoch [49/50] Train Acc: 73.36% Val Acc: 71.64% Train Loss: 0.7611 Val Loss: 0.8203
# Epoch [50/50] Train Acc: 73.35% Val Acc: 71.69% Train Loss: 0.7635 Val Loss: 0.8199
# Training completed in 2280.35 seconds.
