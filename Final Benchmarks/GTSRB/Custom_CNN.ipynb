# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

num_epochs = 50
batch_size = 128
learning_rate = 0.001
run_name = 'GTSRB_Custom_CNN'

# No horizontal flip: traffic signs are direction-sensitive
train_transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = torchvision.datasets.GTSRB(root='./data', split='train', transform=train_transform, download=True)
train_size = int(0.9 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

test_dataset = torchvision.datasets.GTSRB(root='./data', split='test', transform=test_transform, download=True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    layer_idx = 0
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            if layer_idx < 6:
                nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
            else:
                nn.init.orthogonal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
            layer_idx += 1

# 9-layer CNN Model
class NineLayerCNN(nn.Module):
    def __init__(self):
        super(NineLayerCNN, self).__init__()

        # Conv block 1
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)

        # Conv block 2
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)

        # Conv block 3
        self.conv5 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.conv7 = nn.Conv2d(256, 128, kernel_size=3, padding=1)

        # FC layers
        # Image size:
        # 32 -> pool ->16 -> pool ->8 -> pool ->4
        self.fc1 = nn.Linear(128 * 4 * 4, 1024)
        self.fc2 = nn.Linear(1024, 43)


    def forward(self, x):

        # block 1
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)

        # block 2
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2)

        # block 3
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = F.relu(self.conv7(x))
        x = F.max_pool2d(x, 2)

        x = torch.flatten(x, 1)

        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        return x

# Instantiate model, apply custom initialization
model = NineLayerCNN().to(device)
custom_init(model)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss_list.append(val_loss / len(val_loader))
    val_acc_list.append(val_acc)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc:.2f}%')

correct = 0
total = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f'Test Accuracy: {test_acc:.2f}%')

# Save metrics to files labelled with dataset + model name
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(num_epochs):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Epoch [1/50], Train Loss: 2.8862, Train Acc: 19.48%, Val Loss: 1.8002, Val Acc: 41.48%
# Epoch [2/50], Train Loss: 0.9970, Train Acc: 66.60%, Val Loss: 0.4947, Val Acc: 83.93%
# Epoch [3/50], Train Loss: 0.2152, Train Acc: 93.08%, Val Loss: 0.1052, Val Acc: 97.00%
# Epoch [4/50], Train Loss: 0.0855, Train Acc: 97.46%, Val Loss: 0.0905, Val Acc: 97.03%
# Epoch [5/50], Train Loss: 0.0579, Train Acc: 98.28%, Val Loss: 0.0754, Val Acc: 98.12%
# Epoch [6/50], Train Loss: 0.0499, Train Acc: 98.57%, Val Loss: 0.0386, Val Acc: 98.69%
# Epoch [7/50], Train Loss: 0.0277, Train Acc: 99.25%, Val Loss: 0.0561, Val Acc: 98.50%
# Epoch [8/50], Train Loss: 0.0366, Train Acc: 98.99%, Val Loss: 0.0438, Val Acc: 98.91%
# Epoch [9/50], Train Loss: 0.0245, Train Acc: 99.30%, Val Loss: 0.0157, Val Acc: 99.62%
# Epoch [10/50], Train Loss: 0.0313, Train Acc: 99.09%, Val Loss: 0.0437, Val Acc: 98.87%
# Epoch [11/50], Train Loss: 0.0252, Train Acc: 99.32%, Val Loss: 0.0535, Val Acc: 98.69%
# Epoch [12/50], Train Loss: 0.0282, Train Acc: 99.28%, Val Loss: 0.0248, Val Acc: 99.29%
# Epoch [13/50], Train Loss: 0.0381, Train Acc: 99.00%, Val Loss: 0.0354, Val Acc: 99.06%
# Epoch [14/50], Train Loss: 0.0137, Train Acc: 99.66%, Val Loss: 0.0105, Val Acc: 99.77%
# Epoch [15/50], Train Loss: 0.0114, Train Acc: 99.64%, Val Loss: 0.0364, Val Acc: 99.10%
# Epoch [16/50], Train Loss: 0.0439, Train Acc: 98.94%, Val Loss: 0.0529, Val Acc: 98.80%
# Epoch [17/50], Train Loss: 0.0184, Train Acc: 99.52%, Val Loss: 0.0258, Val Acc: 99.51%
# Epoch [18/50], Train Loss: 0.0256, Train Acc: 99.37%, Val Loss: 0.0350, Val Acc: 99.02%
# Epoch [19/50], Train Loss: 0.0418, Train Acc: 99.08%, Val Loss: 0.0297, Val Acc: 99.14%
# Epoch [20/50], Train Loss: 0.0163, Train Acc: 99.59%, Val Loss: 0.0196, Val Acc: 99.44%
# Epoch [21/50], Train Loss: 0.0210, Train Acc: 99.56%, Val Loss: 0.0146, Val Acc: 99.66%
# Epoch [22/50], Train Loss: 0.0080, Train Acc: 99.81%, Val Loss: 0.0130, Val Acc: 99.55%
# Epoch [23/50], Train Loss: 0.0099, Train Acc: 99.82%, Val Loss: 0.0106, Val Acc: 99.70%
# Epoch [24/50], Train Loss: 0.0055, Train Acc: 99.85%, Val Loss: 0.0094, Val Acc: 99.70%
# Epoch [25/50], Train Loss: 0.0577, Train Acc: 98.84%, Val Loss: 0.0650, Val Acc: 98.20%
# Epoch [26/50], Train Loss: 0.0310, Train Acc: 99.32%, Val Loss: 0.0202, Val Acc: 99.36%
# Epoch [27/50], Train Loss: 0.0105, Train Acc: 99.70%, Val Loss: 0.0162, Val Acc: 99.66%
# Epoch [28/50], Train Loss: 0.0217, Train Acc: 99.50%, Val Loss: 0.0278, Val Acc: 99.36%
# Epoch [29/50], Train Loss: 0.0359, Train Acc: 99.34%, Val Loss: 0.0083, Val Acc: 99.77%
# Epoch [30/50], Train Loss: 0.0131, Train Acc: 99.72%, Val Loss: 0.0129, Val Acc: 99.55%
# Epoch [31/50], Train Loss: 0.0182, Train Acc: 99.62%, Val Loss: 0.0270, Val Acc: 99.44%
# Epoch [32/50], Train Loss: 0.0405, Train Acc: 99.37%, Val Loss: 0.0526, Val Acc: 98.99%
# Epoch [33/50], Train Loss: 0.0557, Train Acc: 98.90%, Val Loss: 0.0743, Val Acc: 98.69%
# Epoch [34/50], Train Loss: 0.0308, Train Acc: 99.49%, Val Loss: 0.0180, Val Acc: 99.51%
# Epoch [35/50], Train Loss: 0.0060, Train Acc: 99.86%, Val Loss: 0.0395, Val Acc: 99.36%
# Epoch [36/50], Train Loss: 0.0043, Train Acc: 99.90%, Val Loss: 0.0242, Val Acc: 99.47%
# Epoch [37/50], Train Loss: 0.0026, Train Acc: 99.92%, Val Loss: 0.0169, Val Acc: 99.59%
# Epoch [38/50], Train Loss: 0.0106, Train Acc: 99.79%, Val Loss: 0.0181, Val Acc: 99.66%
# Epoch [39/50], Train Loss: 0.0070, Train Acc: 99.83%, Val Loss: 0.0251, Val Acc: 99.59%
# Epoch [40/50], Train Loss: 0.0072, Train Acc: 99.85%, Val Loss: 0.0571, Val Acc: 99.02%
# Epoch [41/50], Train Loss: 0.0372, Train Acc: 99.22%, Val Loss: 0.0288, Val Acc: 99.29%
# Epoch [42/50], Train Loss: 0.0372, Train Acc: 99.34%, Val Loss: 0.0556, Val Acc: 99.17%
# Epoch [43/50], Train Loss: 0.0296, Train Acc: 99.52%, Val Loss: 0.0147, Val Acc: 99.44%
# Epoch [44/50], Train Loss: 0.0207, Train Acc: 99.61%, Val Loss: 0.0104, Val Acc: 99.70%
# Epoch [45/50], Train Loss: 0.0078, Train Acc: 99.82%, Val Loss: 0.0194, Val Acc: 99.55%
# Epoch [46/50], Train Loss: 0.0288, Train Acc: 99.61%, Val Loss: 0.0416, Val Acc: 99.32%
# Epoch [47/50], Train Loss: 0.0081, Train Acc: 99.79%, Val Loss: 0.0075, Val Acc: 99.77%
# Epoch [48/50], Train Loss: 0.0030, Train Acc: 99.95%, Val Loss: 0.0225, Val Acc: 99.66%
# Epoch [49/50], Train Loss: 0.0312, Train Acc: 99.68%, Val Loss: 0.0293, Val Acc: 99.25%
# Epoch [50/50], Train Loss: 0.0253, Train Acc: 99.46%, Val Loss: 0.0264, Val Acc: 99.40%
# Test Accuracy: 96.15%
