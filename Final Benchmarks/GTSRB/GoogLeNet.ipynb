# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.models as models
import torchvision.transforms as transforms
from torchvision.models import googlenet
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

run_name = 'GTSRB_GoogLeNet'

num_epochs = 50
batch_size = 128
learning_rate = 0.001

# No horizontal flip: traffic signs are direction-sensitive
train_transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = torchvision.datasets.GTSRB(root='./data', split='train', transform=train_transform, download=True)
train_size = int(0.9 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

test_dataset = torchvision.datasets.GTSRB(root='./data', split='test', transform=test_transform, download=True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# Hybrid Initialization (He for Conv2d, Orthogonal for Linear)
def custom_init(model):
    for module in model.modules():
        if isinstance(module, nn.Conv2d):
            nn.init.kaiming_normal_(module.weight, mode='fan_out', nonlinearity='relu')
        elif isinstance(module, nn.Linear):
            nn.init.orthogonal_(module.weight)
        if hasattr(module, 'bias') and module.bias is not None:
            nn.init.constant_(module.bias, 0)

# GoogLeNet (torchvision, trained from scratch)
model = googlenet(num_classes=43, aux_logits=False)
model = model.to(device)
custom_init(model)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss_list.append(val_loss / len(val_loader))
    val_acc_list.append(val_acc)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc:.2f}%')

correct = 0
total = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f'Test Accuracy: {test_acc:.2f}%')

# Save metrics to files labelled with dataset + model name
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(num_epochs):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# /home/aadit/Projects/Optimized-Hybrid-Initialization-for-Deep-CNNs/.venv/lib/python3.13/site-packages/torchvision/models/googlenet.py:47: FutureWarning: The default weight initialization of GoogleNet will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(
# Epoch [1/50], Train Loss: 2.6314, Train Acc: 25.71%, Val Loss: 2.4715, Val Acc: 32.17%
# Epoch [2/50], Train Loss: 1.2810, Train Acc: 57.57%, Val Loss: 1.2142, Val Acc: 61.64%
# Epoch [3/50], Train Loss: 0.6899, Train Acc: 76.63%, Val Loss: 0.7996, Val Acc: 75.11%
# Epoch [4/50], Train Loss: 0.4455, Train Acc: 85.08%, Val Loss: 0.7867, Val Acc: 78.38%
# Epoch [5/50], Train Loss: 0.3019, Train Acc: 89.94%, Val Loss: 0.5179, Val Acc: 84.35%
# Epoch [6/50], Train Loss: 0.2149, Train Acc: 92.78%, Val Loss: 0.3928, Val Acc: 88.18%
# Epoch [7/50], Train Loss: 0.1697, Train Acc: 94.39%, Val Loss: 0.3860, Val Acc: 87.88%
# Epoch [8/50], Train Loss: 0.1525, Train Acc: 95.05%, Val Loss: 0.9091, Val Acc: 79.77%
# Epoch [9/50], Train Loss: 0.1407, Train Acc: 95.56%, Val Loss: 0.3069, Val Acc: 92.42%
# Epoch [10/50], Train Loss: 0.1216, Train Acc: 96.32%, Val Loss: 0.2924, Val Acc: 91.44%
# Epoch [11/50], Train Loss: 0.0986, Train Acc: 96.99%, Val Loss: 0.1900, Val Acc: 93.58%
# Epoch [12/50], Train Loss: 0.0916, Train Acc: 97.08%, Val Loss: 0.2193, Val Acc: 93.92%
# Epoch [13/50], Train Loss: 0.0769, Train Acc: 97.57%, Val Loss: 0.2066, Val Acc: 94.78%
# Epoch [14/50], Train Loss: 0.0857, Train Acc: 97.34%, Val Loss: 0.1755, Val Acc: 94.07%
# Epoch [15/50], Train Loss: 0.0741, Train Acc: 97.66%, Val Loss: 0.2194, Val Acc: 93.73%
# Epoch [16/50], Train Loss: 0.0764, Train Acc: 97.60%, Val Loss: 0.0739, Val Acc: 97.64%
# Epoch [17/50], Train Loss: 0.0607, Train Acc: 98.16%, Val Loss: 0.1943, Val Acc: 94.59%
# Epoch [18/50], Train Loss: 0.0671, Train Acc: 97.92%, Val Loss: 0.1526, Val Acc: 95.20%
# Epoch [19/50], Train Loss: 0.0766, Train Acc: 97.63%, Val Loss: 0.1704, Val Acc: 95.38%
# Epoch [20/50], Train Loss: 0.0581, Train Acc: 98.23%, Val Loss: 0.0920, Val Acc: 97.33%
# Epoch [21/50], Train Loss: 0.0477, Train Acc: 98.50%, Val Loss: 0.2172, Val Acc: 93.54%
# Epoch [22/50], Train Loss: 0.0584, Train Acc: 98.23%, Val Loss: 0.1545, Val Acc: 95.38%
# Epoch [23/50], Train Loss: 0.0567, Train Acc: 98.24%, Val Loss: 0.0839, Val Acc: 97.33%
# Epoch [24/50], Train Loss: 0.0430, Train Acc: 98.73%, Val Loss: 0.0933, Val Acc: 96.96%
# Epoch [25/50], Train Loss: 0.0489, Train Acc: 98.54%, Val Loss: 0.1269, Val Acc: 96.55%
# Epoch [26/50], Train Loss: 0.0620, Train Acc: 98.15%, Val Loss: 0.1623, Val Acc: 95.57%
# Epoch [27/50], Train Loss: 0.0482, Train Acc: 98.57%, Val Loss: 0.0735, Val Acc: 98.31%
# Epoch [28/50], Train Loss: 0.0518, Train Acc: 98.47%, Val Loss: 0.0883, Val Acc: 97.79%
# Epoch [29/50], Train Loss: 0.0517, Train Acc: 98.46%, Val Loss: 0.1387, Val Acc: 95.76%
# Epoch [30/50], Train Loss: 0.0284, Train Acc: 99.17%, Val Loss: 0.0437, Val Acc: 98.80%
# Epoch [31/50], Train Loss: 0.0446, Train Acc: 98.70%, Val Loss: 0.0659, Val Acc: 98.09%
# Epoch [32/50], Train Loss: 0.0501, Train Acc: 98.43%, Val Loss: 0.0383, Val Acc: 99.02%
# Epoch [33/50], Train Loss: 0.0324, Train Acc: 99.03%, Val Loss: 0.3292, Val Acc: 93.13%
# Epoch [34/50], Train Loss: 0.0424, Train Acc: 98.84%, Val Loss: 0.1364, Val Acc: 96.17%
# Epoch [35/50], Train Loss: 0.0436, Train Acc: 98.73%, Val Loss: 0.0419, Val Acc: 98.65%
# Epoch [36/50], Train Loss: 0.0270, Train Acc: 99.13%, Val Loss: 0.0710, Val Acc: 98.20%
# Epoch [37/50], Train Loss: 0.0407, Train Acc: 98.89%, Val Loss: 0.2036, Val Acc: 95.08%
# Epoch [38/50], Train Loss: 0.0418, Train Acc: 98.83%, Val Loss: 0.0431, Val Acc: 98.76%
# Epoch [39/50], Train Loss: 0.0350, Train Acc: 99.01%, Val Loss: 0.0465, Val Acc: 98.46%
# Epoch [40/50], Train Loss: 0.0231, Train Acc: 99.25%, Val Loss: 0.0505, Val Acc: 98.39%
# Epoch [41/50], Train Loss: 0.0357, Train Acc: 98.93%, Val Loss: 0.0600, Val Acc: 98.12%
# Epoch [42/50], Train Loss: 0.0229, Train Acc: 99.31%, Val Loss: 0.0402, Val Acc: 98.95%
# Epoch [43/50], Train Loss: 0.0226, Train Acc: 99.32%, Val Loss: 0.0175, Val Acc: 99.32%
# Epoch [44/50], Train Loss: 0.0309, Train Acc: 99.14%, Val Loss: 0.0999, Val Acc: 97.22%
# Epoch [45/50], Train Loss: 0.0249, Train Acc: 99.25%, Val Loss: 0.1049, Val Acc: 97.11%
# Epoch [46/50], Train Loss: 0.0322, Train Acc: 99.00%, Val Loss: 0.1357, Val Acc: 96.66%
# Epoch [47/50], Train Loss: 0.0197, Train Acc: 99.44%, Val Loss: 0.0198, Val Acc: 99.47%
# Epoch [48/50], Train Loss: 0.0353, Train Acc: 99.01%, Val Loss: 0.1581, Val Acc: 95.50%
# Epoch [49/50], Train Loss: 0.0234, Train Acc: 99.29%, Val Loss: 0.0202, Val Acc: 99.40%
# Epoch [50/50], Train Loss: 0.0188, Train Acc: 99.45%, Val Loss: 0.0280, Val Acc: 99.29%
# Test Accuracy: 90.77%
