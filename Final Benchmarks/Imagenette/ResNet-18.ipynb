# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.models as models
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

run_name = 'Imagenette_ResNet-18'

num_epochs = 50
batch_size = 128
learning_rate = 0.001

import os

train_transform = transforms.Compose([
    transforms.Resize((72, 72)),
    transforms.RandomCrop(64),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Imagenette raises an error if download=True and the data already exists
download_needed = not os.path.exists('./data/imagenette2-160')
train_dataset = torchvision.datasets.Imagenette(root='./data', split='train', size='160px', download=download_needed, transform=train_transform)
train_size = int(0.9 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

test_dataset = torchvision.datasets.Imagenette(root='./data', split='val', size='160px', download=False, transform=test_transform)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# Hybrid Initialization (He for Conv2d, Orthogonal for Linear)
def custom_init(model):
    for module in model.modules():
        if isinstance(module, nn.Conv2d):
            nn.init.kaiming_normal_(module.weight, mode='fan_out', nonlinearity='relu')
        elif isinstance(module, nn.Linear):
            nn.init.orthogonal_(module.weight)
        if hasattr(module, 'bias') and module.bias is not None:
            nn.init.constant_(module.bias, 0)

# ResNet-18 (torchvision, trained from scratch)
class ResNet18(nn.Module):
    def __init__(self):
        super(ResNet18, self).__init__()

        self.resnet = models.resnet18(weights=None)

        self.resnet.fc = nn.Linear(self.resnet.fc.in_features, 10)

    def forward(self, x):
        return self.resnet(x)

model = ResNet18().to(device)
custom_init(model)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss_list.append(val_loss / len(val_loader))
    val_acc_list.append(val_acc)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc:.2f}%')

correct = 0
total = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f'Test Accuracy: {test_acc:.2f}%')

# Save metrics to files labelled with dataset + model name
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(num_epochs):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Epoch [1/50], Train Loss: 1.6488, Train Acc: 44.64%, Val Loss: 1.6637, Val Acc: 47.41%
# Epoch [2/50], Train Loss: 1.2376, Train Acc: 59.27%, Val Loss: 1.3381, Val Acc: 53.33%
# Epoch [3/50], Train Loss: 1.0499, Train Acc: 65.04%, Val Loss: 1.2476, Val Acc: 57.87%
# Epoch [4/50], Train Loss: 0.9554, Train Acc: 68.00%, Val Loss: 1.3074, Val Acc: 58.82%
# Epoch [5/50], Train Loss: 0.8715, Train Acc: 71.15%, Val Loss: 1.0264, Val Acc: 64.41%
# Epoch [6/50], Train Loss: 0.7903, Train Acc: 73.94%, Val Loss: 1.2282, Val Acc: 62.51%
# Epoch [7/50], Train Loss: 0.7586, Train Acc: 74.79%, Val Loss: 1.0844, Val Acc: 66.74%
# Epoch [8/50], Train Loss: 0.6948, Train Acc: 77.13%, Val Loss: 0.9490, Val Acc: 68.11%
# Epoch [9/50], Train Loss: 0.6276, Train Acc: 78.75%, Val Loss: 1.2235, Val Acc: 64.94%
# Epoch [10/50], Train Loss: 0.5740, Train Acc: 80.94%, Val Loss: 1.3781, Val Acc: 61.56%
# Epoch [11/50], Train Loss: 0.5652, Train Acc: 80.90%, Val Loss: 1.1810, Val Acc: 66.63%
# Epoch [12/50], Train Loss: 0.5023, Train Acc: 83.36%, Val Loss: 0.9998, Val Acc: 69.48%
# Epoch [13/50], Train Loss: 0.4772, Train Acc: 84.09%, Val Loss: 0.8954, Val Acc: 71.49%
# Epoch [14/50], Train Loss: 0.4209, Train Acc: 86.01%, Val Loss: 1.0413, Val Acc: 69.80%
# Epoch [15/50], Train Loss: 0.4122, Train Acc: 86.00%, Val Loss: 1.0736, Val Acc: 68.11%
# Epoch [16/50], Train Loss: 0.3544, Train Acc: 87.82%, Val Loss: 1.0189, Val Acc: 70.75%
# Epoch [17/50], Train Loss: 0.3378, Train Acc: 88.69%, Val Loss: 0.9814, Val Acc: 72.86%
# Epoch [18/50], Train Loss: 0.3034, Train Acc: 90.05%, Val Loss: 1.0252, Val Acc: 71.59%
# Epoch [19/50], Train Loss: 0.3121, Train Acc: 88.95%, Val Loss: 1.2067, Val Acc: 68.43%
# Epoch [20/50], Train Loss: 0.2667, Train Acc: 90.94%, Val Loss: 1.2109, Val Acc: 67.79%
# Epoch [21/50], Train Loss: 0.2407, Train Acc: 91.79%, Val Loss: 1.0586, Val Acc: 71.59%
# Epoch [22/50], Train Loss: 0.2254, Train Acc: 92.29%, Val Loss: 1.2059, Val Acc: 70.12%
# Epoch [23/50], Train Loss: 0.1957, Train Acc: 93.37%, Val Loss: 1.3263, Val Acc: 69.69%
# Epoch [24/50], Train Loss: 0.1904, Train Acc: 93.56%, Val Loss: 1.1693, Val Acc: 72.23%
# Epoch [25/50], Train Loss: 0.1913, Train Acc: 93.16%, Val Loss: 1.3331, Val Acc: 71.07%
# Epoch [26/50], Train Loss: 0.1646, Train Acc: 94.53%, Val Loss: 1.2756, Val Acc: 70.64%
# Epoch [27/50], Train Loss: 0.1566, Train Acc: 94.78%, Val Loss: 1.2986, Val Acc: 68.85%
# Epoch [28/50], Train Loss: 0.1537, Train Acc: 94.75%, Val Loss: 1.2734, Val Acc: 71.49%
# Epoch [29/50], Train Loss: 0.1519, Train Acc: 94.58%, Val Loss: 1.2703, Val Acc: 72.76%
# Epoch [30/50], Train Loss: 0.1403, Train Acc: 95.21%, Val Loss: 1.3225, Val Acc: 69.90%
# Epoch [31/50], Train Loss: 0.1277, Train Acc: 95.67%, Val Loss: 1.2973, Val Acc: 70.43%
# Epoch [32/50], Train Loss: 0.1138, Train Acc: 96.35%, Val Loss: 1.3872, Val Acc: 70.54%
# Epoch [33/50], Train Loss: 0.1386, Train Acc: 95.26%, Val Loss: 1.3819, Val Acc: 70.12%
# Epoch [34/50], Train Loss: 0.1286, Train Acc: 95.65%, Val Loss: 1.1914, Val Acc: 73.39%
# Epoch [35/50], Train Loss: 0.1143, Train Acc: 96.27%, Val Loss: 1.1130, Val Acc: 75.08%
# Epoch [36/50], Train Loss: 0.0988, Train Acc: 96.62%, Val Loss: 1.3730, Val Acc: 71.70%
# Epoch [37/50], Train Loss: 0.1012, Train Acc: 96.26%, Val Loss: 1.3849, Val Acc: 72.44%
# Epoch [38/50], Train Loss: 0.0891, Train Acc: 97.03%, Val Loss: 1.2487, Val Acc: 74.34%
# Epoch [39/50], Train Loss: 0.1006, Train Acc: 96.67%, Val Loss: 1.5072, Val Acc: 71.17%
# Epoch [40/50], Train Loss: 0.0893, Train Acc: 96.93%, Val Loss: 1.3750, Val Acc: 72.76%
# Epoch [41/50], Train Loss: 0.0828, Train Acc: 97.35%, Val Loss: 1.2732, Val Acc: 73.18%
# Epoch [42/50], Train Loss: 0.0826, Train Acc: 97.39%, Val Loss: 1.2928, Val Acc: 72.86%
# Epoch [43/50], Train Loss: 0.0660, Train Acc: 97.81%, Val Loss: 1.3893, Val Acc: 73.71%
# Epoch [44/50], Train Loss: 0.0907, Train Acc: 97.21%, Val Loss: 1.4877, Val Acc: 72.33%
# Epoch [45/50], Train Loss: 0.0704, Train Acc: 97.75%, Val Loss: 1.2674, Val Acc: 73.18%
# Epoch [46/50], Train Loss: 0.0756, Train Acc: 97.49%, Val Loss: 1.3564, Val Acc: 74.13%
# Epoch [47/50], Train Loss: 0.0622, Train Acc: 97.95%, Val Loss: 1.4672, Val Acc: 72.54%
# Epoch [48/50], Train Loss: 0.0665, Train Acc: 97.74%, Val Loss: 1.6400, Val Acc: 68.64%
# Epoch [49/50], Train Loss: 0.0700, Train Acc: 97.62%, Val Loss: 1.6868, Val Acc: 68.95%
# Epoch [50/50], Train Loss: 0.0879, Train Acc: 97.01%, Val Loss: 1.4656, Val Acc: 71.38%
# Test Accuracy: 73.76%
