# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

num_epochs = 50
batch_size = 128
learning_rate = 0.001
run_name = 'Imagenette_Custom_CNN'

import os

train_transform = transforms.Compose([
    transforms.Resize((72, 72)),
    transforms.RandomCrop(64),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Imagenette raises an error if download=True and the data already exists
download_needed = not os.path.exists('./data/imagenette2-160')
train_dataset = torchvision.datasets.Imagenette(root='./data', split='train', size='160px', download=download_needed, transform=train_transform)
train_size = int(0.9 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

test_dataset = torchvision.datasets.Imagenette(root='./data', split='val', size='160px', download=False, transform=test_transform)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    layer_idx = 0
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            if layer_idx < 6:
                nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
            else:
                nn.init.orthogonal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
            layer_idx += 1

# 9-layer CNN Model
class NineLayerCNN(nn.Module):
    def __init__(self):
        super(NineLayerCNN, self).__init__()

        # Conv block 1
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)

        # Conv block 2
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)

        # Conv block 3
        self.conv5 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.conv7 = nn.Conv2d(256, 128, kernel_size=3, padding=1)

        # FC layers
        # Image size:
        # 64 -> pool ->32 -> pool ->16 -> pool ->8
        self.fc1 = nn.Linear(128 * 8 * 8, 1024)
        self.fc2 = nn.Linear(1024, 10)


    def forward(self, x):

        # block 1
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)

        # block 2
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2)

        # block 3
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = F.relu(self.conv7(x))
        x = F.max_pool2d(x, 2)

        x = torch.flatten(x, 1)

        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        return x

# Instantiate model, apply custom initialization
model = NineLayerCNN().to(device)
custom_init(model)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss_list.append(val_loss / len(val_loader))
    val_acc_list.append(val_acc)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc:.2f}%')

correct = 0
total = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f'Test Accuracy: {test_acc:.2f}%')

# Save metrics to files labelled with dataset + model name
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(num_epochs):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Epoch [1/50], Train Loss: 3.3782, Train Acc: 23.53%, Val Loss: 1.9991, Val Acc: 29.36%
# Epoch [2/50], Train Loss: 1.8488, Train Acc: 35.65%, Val Loss: 1.7530, Val Acc: 39.39%
# Epoch [3/50], Train Loss: 1.5825, Train Acc: 46.35%, Val Loss: 1.5638, Val Acc: 46.15%
# Epoch [4/50], Train Loss: 1.3878, Train Acc: 53.18%, Val Loss: 1.3907, Val Acc: 55.54%
# Epoch [5/50], Train Loss: 1.2196, Train Acc: 59.00%, Val Loss: 1.4060, Val Acc: 55.44%
# Epoch [6/50], Train Loss: 1.1146, Train Acc: 62.92%, Val Loss: 1.2170, Val Acc: 57.87%
# Epoch [7/50], Train Loss: 1.0407, Train Acc: 65.50%, Val Loss: 1.0911, Val Acc: 64.84%
# Epoch [8/50], Train Loss: 0.9309, Train Acc: 69.66%, Val Loss: 1.2278, Val Acc: 62.83%
# Epoch [9/50], Train Loss: 0.8781, Train Acc: 70.72%, Val Loss: 1.0279, Val Acc: 65.79%
# Epoch [10/50], Train Loss: 0.7922, Train Acc: 73.93%, Val Loss: 1.0530, Val Acc: 66.63%
# Epoch [11/50], Train Loss: 0.7177, Train Acc: 75.97%, Val Loss: 1.0062, Val Acc: 66.74%
# Epoch [12/50], Train Loss: 0.6680, Train Acc: 77.68%, Val Loss: 0.9686, Val Acc: 69.59%
# Epoch [13/50], Train Loss: 0.6099, Train Acc: 79.81%, Val Loss: 1.0150, Val Acc: 69.17%
# Epoch [14/50], Train Loss: 0.5478, Train Acc: 82.06%, Val Loss: 1.0475, Val Acc: 66.10%
# Epoch [15/50], Train Loss: 0.5025, Train Acc: 83.26%, Val Loss: 1.1403, Val Acc: 67.16%
# Epoch [16/50], Train Loss: 0.4395, Train Acc: 85.79%, Val Loss: 1.0825, Val Acc: 68.64%
# Epoch [17/50], Train Loss: 0.4308, Train Acc: 85.90%, Val Loss: 1.1260, Val Acc: 68.32%
# Epoch [18/50], Train Loss: 0.4054, Train Acc: 86.70%, Val Loss: 1.1524, Val Acc: 67.05%
# Epoch [19/50], Train Loss: 0.3468, Train Acc: 88.36%, Val Loss: 1.2212, Val Acc: 66.42%
# Epoch [20/50], Train Loss: 0.3166, Train Acc: 89.87%, Val Loss: 1.2175, Val Acc: 70.43%
# Epoch [21/50], Train Loss: 0.3149, Train Acc: 89.47%, Val Loss: 1.2810, Val Acc: 69.17%
# Epoch [22/50], Train Loss: 0.2798, Train Acc: 90.93%, Val Loss: 1.4840, Val Acc: 68.85%
# Epoch [23/50], Train Loss: 0.2467, Train Acc: 91.83%, Val Loss: 1.3431, Val Acc: 67.69%
# Epoch [24/50], Train Loss: 0.2509, Train Acc: 91.69%, Val Loss: 1.4045, Val Acc: 68.00%
# Epoch [25/50], Train Loss: 0.2224, Train Acc: 92.95%, Val Loss: 1.5370, Val Acc: 67.79%
# Epoch [26/50], Train Loss: 0.2133, Train Acc: 93.21%, Val Loss: 1.4956, Val Acc: 69.27%
# Epoch [27/50], Train Loss: 0.1888, Train Acc: 93.84%, Val Loss: 1.3436, Val Acc: 69.06%
# Epoch [28/50], Train Loss: 0.1798, Train Acc: 94.00%, Val Loss: 1.4828, Val Acc: 69.06%
# Epoch [29/50], Train Loss: 0.1839, Train Acc: 94.17%, Val Loss: 1.5508, Val Acc: 68.95%
# Epoch [30/50], Train Loss: 0.1807, Train Acc: 94.17%, Val Loss: 1.3834, Val Acc: 70.01%
# Epoch [31/50], Train Loss: 0.1797, Train Acc: 93.86%, Val Loss: 1.4336, Val Acc: 69.69%
# Epoch [32/50], Train Loss: 0.1396, Train Acc: 95.42%, Val Loss: 1.4192, Val Acc: 70.43%
# Epoch [33/50], Train Loss: 0.1482, Train Acc: 95.18%, Val Loss: 1.6056, Val Acc: 69.80%
# Epoch [34/50], Train Loss: 0.1678, Train Acc: 94.63%, Val Loss: 1.4995, Val Acc: 69.06%
# Epoch [35/50], Train Loss: 0.1345, Train Acc: 95.90%, Val Loss: 1.6127, Val Acc: 71.07%
# Epoch [36/50], Train Loss: 0.1189, Train Acc: 96.21%, Val Loss: 1.7882, Val Acc: 69.90%
# Epoch [37/50], Train Loss: 0.1316, Train Acc: 95.79%, Val Loss: 1.9589, Val Acc: 67.69%
# Epoch [38/50], Train Loss: 0.1254, Train Acc: 96.08%, Val Loss: 1.6476, Val Acc: 70.64%
# Epoch [39/50], Train Loss: 0.1329, Train Acc: 95.63%, Val Loss: 1.6216, Val Acc: 69.38%
# Epoch [40/50], Train Loss: 0.0890, Train Acc: 97.03%, Val Loss: 1.8970, Val Acc: 71.07%
# Epoch [41/50], Train Loss: 0.1133, Train Acc: 96.40%, Val Loss: 1.8049, Val Acc: 69.17%
# Epoch [42/50], Train Loss: 0.1179, Train Acc: 96.08%, Val Loss: 1.7505, Val Acc: 69.80%
# Epoch [43/50], Train Loss: 0.0862, Train Acc: 97.30%, Val Loss: 1.8195, Val Acc: 71.07%
# Epoch [44/50], Train Loss: 0.0951, Train Acc: 96.87%, Val Loss: 1.7401, Val Acc: 70.22%
# Epoch [45/50], Train Loss: 0.0977, Train Acc: 97.08%, Val Loss: 1.6268, Val Acc: 71.91%
# Epoch [46/50], Train Loss: 0.1165, Train Acc: 96.09%, Val Loss: 1.7304, Val Acc: 69.80%
# Epoch [47/50], Train Loss: 0.1126, Train Acc: 96.33%, Val Loss: 1.6973, Val Acc: 70.12%
# Epoch [48/50], Train Loss: 0.0911, Train Acc: 97.02%, Val Loss: 1.7852, Val Acc: 70.12%
# Epoch [49/50], Train Loss: 0.1066, Train Acc: 96.86%, Val Loss: 1.4318, Val Acc: 72.86%
# Epoch [50/50], Train Loss: 0.0831, Train Acc: 97.37%, Val Loss: 1.6135, Val Acc: 72.86%
# Test Accuracy: 72.25%
