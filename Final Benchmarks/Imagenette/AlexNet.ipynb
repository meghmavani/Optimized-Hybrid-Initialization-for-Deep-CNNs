# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.models as models
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

run_name = 'Imagenette_AlexNet'

num_epochs = 50
batch_size = 128
learning_rate = 0.001

import os

train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Imagenette raises an error if download=True and the data already exists
download_needed = not os.path.exists('./data/imagenette2-160')
train_dataset = torchvision.datasets.Imagenette(root='./data', split='train', size='160px', download=download_needed, transform=train_transform)
train_size = int(0.9 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

test_dataset = torchvision.datasets.Imagenette(root='./data', split='val', size='160px', download=False, transform=test_transform)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# Hybrid Initialization (He for Conv2d, Orthogonal for Linear)
def custom_init(model):
    for module in model.modules():
        if isinstance(module, nn.Conv2d):
            nn.init.kaiming_normal_(module.weight, mode='fan_out', nonlinearity='relu')
        elif isinstance(module, nn.Linear):
            nn.init.orthogonal_(module.weight)
        if hasattr(module, 'bias') and module.bias is not None:
            nn.init.constant_(module.bias, 0)

# AlexNet (torchvision, trained from scratch)
model = models.alexnet(weights=None)
model.classifier[6] = nn.Linear(4096, 10)
model = model.to(device)
custom_init(model)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss_list.append(val_loss / len(val_loader))
    val_acc_list.append(val_acc)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc:.2f}%')

correct = 0
total = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f'Test Accuracy: {test_acc:.2f}%')

# Save metrics to files labelled with dataset + model name
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(num_epochs):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Epoch [1/50], Train Loss: 2.3654, Train Acc: 20.35%, Val Loss: 1.8561, Val Acc: 36.22%
# Epoch [2/50], Train Loss: 1.8354, Train Acc: 37.03%, Val Loss: 1.6367, Val Acc: 43.61%
# Epoch [3/50], Train Loss: 1.6687, Train Acc: 43.22%, Val Loss: 1.5176, Val Acc: 50.26%
# Epoch [4/50], Train Loss: 1.5148, Train Acc: 49.18%, Val Loss: 1.5235, Val Acc: 46.15%
# Epoch [5/50], Train Loss: 1.3977, Train Acc: 53.12%, Val Loss: 1.2517, Val Acc: 57.97%
# Epoch [6/50], Train Loss: 1.2912, Train Acc: 57.04%, Val Loss: 1.1524, Val Acc: 61.77%
# Epoch [7/50], Train Loss: 1.1931, Train Acc: 59.73%, Val Loss: 1.1660, Val Acc: 60.82%
# Epoch [8/50], Train Loss: 1.1569, Train Acc: 61.26%, Val Loss: 1.1974, Val Acc: 58.82%
# Epoch [9/50], Train Loss: 1.0760, Train Acc: 64.25%, Val Loss: 1.0598, Val Acc: 67.27%
# Epoch [10/50], Train Loss: 1.0142, Train Acc: 66.38%, Val Loss: 1.0416, Val Acc: 64.52%
# Epoch [11/50], Train Loss: 0.9534, Train Acc: 67.92%, Val Loss: 1.0549, Val Acc: 66.63%
# Epoch [12/50], Train Loss: 0.8903, Train Acc: 70.00%, Val Loss: 0.9978, Val Acc: 67.37%
# Epoch [13/50], Train Loss: 0.8452, Train Acc: 71.83%, Val Loss: 0.9750, Val Acc: 68.11%
# Epoch [14/50], Train Loss: 0.8067, Train Acc: 72.93%, Val Loss: 0.9560, Val Acc: 69.48%
# Epoch [15/50], Train Loss: 0.7448, Train Acc: 75.40%, Val Loss: 1.0006, Val Acc: 69.48%
# Epoch [16/50], Train Loss: 0.7017, Train Acc: 76.63%, Val Loss: 0.9371, Val Acc: 70.22%
# Epoch [17/50], Train Loss: 0.6351, Train Acc: 78.77%, Val Loss: 0.9425, Val Acc: 70.86%
# Epoch [18/50], Train Loss: 0.6289, Train Acc: 78.81%, Val Loss: 0.9332, Val Acc: 69.80%
# Epoch [19/50], Train Loss: 0.5879, Train Acc: 80.02%, Val Loss: 1.0589, Val Acc: 68.43%
# Epoch [20/50], Train Loss: 0.5781, Train Acc: 80.91%, Val Loss: 0.9591, Val Acc: 71.49%
# Epoch [21/50], Train Loss: 0.5187, Train Acc: 82.95%, Val Loss: 0.9470, Val Acc: 71.49%
# Epoch [22/50], Train Loss: 0.5252, Train Acc: 82.36%, Val Loss: 0.9445, Val Acc: 70.96%
# Epoch [23/50], Train Loss: 0.4810, Train Acc: 83.96%, Val Loss: 0.9969, Val Acc: 70.33%
# Epoch [24/50], Train Loss: 0.4576, Train Acc: 84.39%, Val Loss: 0.9476, Val Acc: 71.28%
# Epoch [25/50], Train Loss: 0.4562, Train Acc: 85.12%, Val Loss: 0.9392, Val Acc: 71.59%
# Epoch [26/50], Train Loss: 0.4345, Train Acc: 85.50%, Val Loss: 0.9206, Val Acc: 71.38%
# Epoch [27/50], Train Loss: 0.3947, Train Acc: 86.68%, Val Loss: 1.0755, Val Acc: 70.33%
# Epoch [28/50], Train Loss: 0.3752, Train Acc: 87.42%, Val Loss: 0.9585, Val Acc: 73.81%
# Epoch [29/50], Train Loss: 0.3915, Train Acc: 87.14%, Val Loss: 1.0003, Val Acc: 72.44%
# Epoch [30/50], Train Loss: 0.3701, Train Acc: 87.60%, Val Loss: 0.9968, Val Acc: 72.54%
# Epoch [31/50], Train Loss: 0.3236, Train Acc: 89.11%, Val Loss: 0.9256, Val Acc: 73.28%
# Epoch [32/50], Train Loss: 0.3174, Train Acc: 89.45%, Val Loss: 0.9650, Val Acc: 69.69%
# Epoch [33/50], Train Loss: 0.3385, Train Acc: 88.75%, Val Loss: 0.9254, Val Acc: 72.86%
# Epoch [34/50], Train Loss: 0.2944, Train Acc: 90.59%, Val Loss: 0.9769, Val Acc: 72.65%
# Epoch [35/50], Train Loss: 0.2848, Train Acc: 90.72%, Val Loss: 1.0697, Val Acc: 73.07%
# Epoch [36/50], Train Loss: 0.2897, Train Acc: 90.67%, Val Loss: 1.1048, Val Acc: 71.81%
# Epoch [37/50], Train Loss: 0.2892, Train Acc: 90.57%, Val Loss: 1.0417, Val Acc: 72.33%
# Epoch [38/50], Train Loss: 0.2341, Train Acc: 92.22%, Val Loss: 1.1510, Val Acc: 71.38%
# Epoch [39/50], Train Loss: 0.2483, Train Acc: 91.99%, Val Loss: 1.2548, Val Acc: 70.86%
# Epoch [40/50], Train Loss: 0.2649, Train Acc: 91.38%, Val Loss: 1.1094, Val Acc: 72.23%
# Epoch [41/50], Train Loss: 0.2550, Train Acc: 91.92%, Val Loss: 0.9789, Val Acc: 74.23%
# Epoch [42/50], Train Loss: 0.2680, Train Acc: 91.62%, Val Loss: 1.0188, Val Acc: 72.76%
# Epoch [43/50], Train Loss: 0.2519, Train Acc: 92.21%, Val Loss: 1.4246, Val Acc: 70.75%
# Epoch [44/50], Train Loss: 0.2306, Train Acc: 92.69%, Val Loss: 1.2163, Val Acc: 72.65%
# Epoch [45/50], Train Loss: 0.2067, Train Acc: 92.97%, Val Loss: 1.0899, Val Acc: 74.55%
# Epoch [46/50], Train Loss: 0.2193, Train Acc: 93.32%, Val Loss: 1.0881, Val Acc: 71.28%
# Epoch [47/50], Train Loss: 0.2511, Train Acc: 92.09%, Val Loss: 1.0977, Val Acc: 72.54%
# Epoch [48/50], Train Loss: 0.1927, Train Acc: 94.03%, Val Loss: 1.1910, Val Acc: 70.96%
# Epoch [49/50], Train Loss: 0.2223, Train Acc: 93.09%, Val Loss: 1.0551, Val Acc: 74.97%
# Epoch [50/50], Train Loss: 0.2118, Train Acc: 93.03%, Val Loss: 1.3279, Val Acc: 66.95%
# Test Accuracy: 70.70%
