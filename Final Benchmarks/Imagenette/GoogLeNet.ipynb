# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.models as models
import torchvision.transforms as transforms
from torchvision.models import googlenet
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

run_name = 'Imagenette_GoogLeNet'

num_epochs = 50
batch_size = 128
learning_rate = 0.001

import os

train_transform = transforms.Compose([
    transforms.Resize((72, 72)),
    transforms.RandomCrop(64),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Imagenette raises an error if download=True and the data already exists
download_needed = not os.path.exists('./data/imagenette2-160')
train_dataset = torchvision.datasets.Imagenette(root='./data', split='train', size='160px', download=download_needed, transform=train_transform)
train_size = int(0.9 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

test_dataset = torchvision.datasets.Imagenette(root='./data', split='val', size='160px', download=False, transform=test_transform)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# Hybrid Initialization (He for Conv2d, Orthogonal for Linear)
def custom_init(model):
    for module in model.modules():
        if isinstance(module, nn.Conv2d):
            nn.init.kaiming_normal_(module.weight, mode='fan_out', nonlinearity='relu')
        elif isinstance(module, nn.Linear):
            nn.init.orthogonal_(module.weight)
        if hasattr(module, 'bias') and module.bias is not None:
            nn.init.constant_(module.bias, 0)

# GoogLeNet (torchvision, trained from scratch)
model = googlenet(num_classes=10, aux_logits=False)
model = model.to(device)
custom_init(model)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss_list.append(val_loss / len(val_loader))
    val_acc_list.append(val_acc)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc:.2f}%')

correct = 0
total = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f'Test Accuracy: {test_acc:.2f}%')

# Save metrics to files labelled with dataset + model name
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(num_epochs):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# /home/aadit/Projects/Optimized-Hybrid-Initialization-for-Deep-CNNs/.venv/lib/python3.13/site-packages/torchvision/models/googlenet.py:47: FutureWarning: The default weight initialization of GoogleNet will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(
# Epoch [1/50], Train Loss: 1.8742, Train Acc: 35.65%, Val Loss: 1.7073, Val Acc: 43.29%
# Epoch [2/50], Train Loss: 1.4215, Train Acc: 52.36%, Val Loss: 1.4053, Val Acc: 52.06%
# Epoch [3/50], Train Loss: 1.1726, Train Acc: 61.64%, Val Loss: 1.2808, Val Acc: 57.55%
# Epoch [4/50], Train Loss: 1.0563, Train Acc: 65.42%, Val Loss: 1.2169, Val Acc: 61.56%
# Epoch [5/50], Train Loss: 0.9446, Train Acc: 69.10%, Val Loss: 1.2351, Val Acc: 62.94%
# Epoch [6/50], Train Loss: 0.8477, Train Acc: 72.49%, Val Loss: 1.1330, Val Acc: 64.63%
# Epoch [7/50], Train Loss: 0.7761, Train Acc: 74.79%, Val Loss: 1.0982, Val Acc: 66.95%
# Epoch [8/50], Train Loss: 0.7237, Train Acc: 76.43%, Val Loss: 1.0868, Val Acc: 66.31%
# Epoch [9/50], Train Loss: 0.6749, Train Acc: 78.07%, Val Loss: 1.0716, Val Acc: 66.10%
# Epoch [10/50], Train Loss: 0.6134, Train Acc: 79.32%, Val Loss: 1.2283, Val Acc: 62.72%
# Epoch [11/50], Train Loss: 0.5816, Train Acc: 80.67%, Val Loss: 0.9987, Val Acc: 68.95%
# Epoch [12/50], Train Loss: 0.5430, Train Acc: 82.07%, Val Loss: 0.9601, Val Acc: 69.90%
# Epoch [13/50], Train Loss: 0.4987, Train Acc: 83.09%, Val Loss: 0.9426, Val Acc: 72.65%
# Epoch [14/50], Train Loss: 0.4654, Train Acc: 84.85%, Val Loss: 1.0839, Val Acc: 67.05%
# Epoch [15/50], Train Loss: 0.4323, Train Acc: 85.13%, Val Loss: 1.0710, Val Acc: 70.75%
# Epoch [16/50], Train Loss: 0.3880, Train Acc: 87.10%, Val Loss: 1.0614, Val Acc: 71.28%
# Epoch [17/50], Train Loss: 0.3707, Train Acc: 87.66%, Val Loss: 1.1416, Val Acc: 68.53%
# Epoch [18/50], Train Loss: 0.3555, Train Acc: 87.89%, Val Loss: 1.2139, Val Acc: 68.85%
# Epoch [19/50], Train Loss: 0.3420, Train Acc: 88.30%, Val Loss: 1.3026, Val Acc: 68.85%
# Epoch [20/50], Train Loss: 0.2806, Train Acc: 90.45%, Val Loss: 1.1366, Val Acc: 71.81%
# Epoch [21/50], Train Loss: 0.2767, Train Acc: 90.35%, Val Loss: 1.1586, Val Acc: 69.48%
# Epoch [22/50], Train Loss: 0.2713, Train Acc: 90.51%, Val Loss: 1.2498, Val Acc: 70.33%
# Epoch [23/50], Train Loss: 0.2573, Train Acc: 91.60%, Val Loss: 1.0945, Val Acc: 73.60%
# Epoch [24/50], Train Loss: 0.2231, Train Acc: 92.54%, Val Loss: 1.3365, Val Acc: 69.06%
# Epoch [25/50], Train Loss: 0.2256, Train Acc: 92.42%, Val Loss: 1.3192, Val Acc: 68.11%
# Epoch [26/50], Train Loss: 0.2212, Train Acc: 92.50%, Val Loss: 1.1002, Val Acc: 72.65%
# Epoch [27/50], Train Loss: 0.1980, Train Acc: 93.29%, Val Loss: 1.3260, Val Acc: 70.12%
# Epoch [28/50], Train Loss: 0.1669, Train Acc: 94.30%, Val Loss: 1.2693, Val Acc: 72.23%
# Epoch [29/50], Train Loss: 0.1919, Train Acc: 93.57%, Val Loss: 1.1837, Val Acc: 71.49%
# Epoch [30/50], Train Loss: 0.1786, Train Acc: 93.99%, Val Loss: 1.2714, Val Acc: 70.96%
# Epoch [31/50], Train Loss: 0.1666, Train Acc: 94.47%, Val Loss: 1.1576, Val Acc: 72.23%
# Epoch [32/50], Train Loss: 0.1168, Train Acc: 96.06%, Val Loss: 1.2995, Val Acc: 72.97%
# Epoch [33/50], Train Loss: 0.1472, Train Acc: 94.85%, Val Loss: 1.2135, Val Acc: 72.97%
# Epoch [34/50], Train Loss: 0.1278, Train Acc: 95.49%, Val Loss: 1.5304, Val Acc: 70.01%
# Epoch [35/50], Train Loss: 0.1142, Train Acc: 96.14%, Val Loss: 1.2634, Val Acc: 73.07%
# Epoch [36/50], Train Loss: 0.1279, Train Acc: 95.60%, Val Loss: 1.2649, Val Acc: 73.60%
# Epoch [37/50], Train Loss: 0.1437, Train Acc: 95.27%, Val Loss: 1.3256, Val Acc: 71.38%
# Epoch [38/50], Train Loss: 0.1459, Train Acc: 95.11%, Val Loss: 1.2825, Val Acc: 73.07%
# Epoch [39/50], Train Loss: 0.1184, Train Acc: 95.83%, Val Loss: 1.3213, Val Acc: 71.59%
# Epoch [40/50], Train Loss: 0.1127, Train Acc: 96.25%, Val Loss: 1.2467, Val Acc: 73.39%
# Epoch [41/50], Train Loss: 0.0900, Train Acc: 96.88%, Val Loss: 1.1402, Val Acc: 77.09%
# Epoch [42/50], Train Loss: 0.0969, Train Acc: 96.35%, Val Loss: 1.3164, Val Acc: 73.81%
# Epoch [43/50], Train Loss: 0.1158, Train Acc: 96.13%, Val Loss: 1.2297, Val Acc: 73.81%
# Epoch [44/50], Train Loss: 0.0927, Train Acc: 96.80%, Val Loss: 1.2432, Val Acc: 74.34%
# Epoch [45/50], Train Loss: 0.1030, Train Acc: 96.44%, Val Loss: 1.2218, Val Acc: 74.23%
# Epoch [46/50], Train Loss: 0.1312, Train Acc: 95.81%, Val Loss: 1.2970, Val Acc: 70.64%
# Epoch [47/50], Train Loss: 0.0865, Train Acc: 97.09%, Val Loss: 1.2631, Val Acc: 73.28%
# Epoch [48/50], Train Loss: 0.0606, Train Acc: 97.96%, Val Loss: 1.2380, Val Acc: 74.55%
# Epoch [49/50], Train Loss: 0.0957, Train Acc: 96.94%, Val Loss: 1.3003, Val Acc: 74.87%
# Epoch [50/50], Train Loss: 0.1032, Train Acc: 96.73%, Val Loss: 1.3543, Val Acc: 70.64%
# Test Accuracy: 72.99%
