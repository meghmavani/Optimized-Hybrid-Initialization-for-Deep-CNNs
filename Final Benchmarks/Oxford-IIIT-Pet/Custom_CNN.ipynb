# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

num_epochs = 50
batch_size = 128
learning_rate = 0.001
run_name = 'Oxford-IIIT-Pet_Custom_CNN'

train_transform = transforms.Compose([
    transforms.Resize((72, 72)),
    transforms.RandomCrop(64),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = torchvision.datasets.OxfordIIITPet(root='./data', split='trainval', transform=train_transform, download=True)
train_size = int(0.9 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

test_dataset = torchvision.datasets.OxfordIIITPet(root='./data', split='test', transform=test_transform, download=True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    layer_idx = 0
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            if layer_idx < 6:
                nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
            else:
                nn.init.orthogonal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
            layer_idx += 1

# 9-layer CNN Model
class NineLayerCNN(nn.Module):
    def __init__(self):
        super(NineLayerCNN, self).__init__()

        # Conv block 1
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)

        # Conv block 2
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)

        # Conv block 3
        self.conv5 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.conv7 = nn.Conv2d(256, 128, kernel_size=3, padding=1)

        # FC layers
        # Image size:
        # 64 -> pool ->32 -> pool ->16 -> pool ->8
        self.fc1 = nn.Linear(128 * 8 * 8, 1024)
        self.fc2 = nn.Linear(1024, 37)


    def forward(self, x):

        # block 1
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)

        # block 2
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2)

        # block 3
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = F.relu(self.conv7(x))
        x = F.max_pool2d(x, 2)

        x = torch.flatten(x, 1)

        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        return x

# Instantiate model, apply custom initialization
model = NineLayerCNN().to(device)
custom_init(model)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss_list.append(val_loss / len(val_loader))
    val_acc_list.append(val_acc)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc:.2f}%')

correct = 0
total = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f'Test Accuracy: {test_acc:.2f}%')

# Save metrics to files labelled with dataset + model name
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(num_epochs):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Epoch [1/50], Train Loss: 4.7590, Train Acc: 2.17%, Val Loss: 3.6110, Val Acc: 1.63%
# Epoch [2/50], Train Loss: 3.6112, Train Acc: 2.93%, Val Loss: 3.6116, Val Acc: 2.17%
# Epoch [3/50], Train Loss: 3.6109, Train Acc: 2.32%, Val Loss: 3.6127, Val Acc: 2.17%
# Epoch [4/50], Train Loss: 3.6060, Train Acc: 2.60%, Val Loss: 3.6043, Val Acc: 4.08%
# Epoch [5/50], Train Loss: 3.5653, Train Acc: 4.74%, Val Loss: 3.4958, Val Acc: 5.98%
# Epoch [6/50], Train Loss: 3.4273, Train Acc: 8.03%, Val Loss: 3.3837, Val Acc: 7.34%
# Epoch [7/50], Train Loss: 3.3150, Train Acc: 10.05%, Val Loss: 3.3944, Val Acc: 7.61%
# Epoch [8/50], Train Loss: 3.2109, Train Acc: 13.22%, Val Loss: 3.4266, Val Acc: 6.52%
# Epoch [9/50], Train Loss: 3.0939, Train Acc: 14.49%, Val Loss: 3.3691, Val Acc: 10.87%
# Epoch [10/50], Train Loss: 2.9734, Train Acc: 18.78%, Val Loss: 3.4139, Val Acc: 10.33%
# Epoch [11/50], Train Loss: 2.8203, Train Acc: 22.80%, Val Loss: 3.5336, Val Acc: 8.97%
# Epoch [12/50], Train Loss: 2.7086, Train Acc: 25.69%, Val Loss: 3.4666, Val Acc: 11.41%
# Epoch [13/50], Train Loss: 2.5369, Train Acc: 31.10%, Val Loss: 3.4681, Val Acc: 14.67%
# Epoch [14/50], Train Loss: 2.3827, Train Acc: 33.79%, Val Loss: 3.6252, Val Acc: 12.77%
# Epoch [15/50], Train Loss: 2.1455, Train Acc: 40.28%, Val Loss: 3.5290, Val Acc: 11.68%
# Epoch [16/50], Train Loss: 1.9985, Train Acc: 45.35%, Val Loss: 3.7735, Val Acc: 14.67%
# Epoch [17/50], Train Loss: 1.8331, Train Acc: 49.49%, Val Loss: 4.1145, Val Acc: 14.67%
# Epoch [18/50], Train Loss: 1.6206, Train Acc: 55.40%, Val Loss: 4.1510, Val Acc: 14.67%
# Epoch [19/50], Train Loss: 1.5144, Train Acc: 58.18%, Val Loss: 4.0082, Val Acc: 13.04%
# Epoch [20/50], Train Loss: 1.3010, Train Acc: 63.29%, Val Loss: 4.9649, Val Acc: 14.13%
# Epoch [21/50], Train Loss: 1.2317, Train Acc: 66.46%, Val Loss: 4.8856, Val Acc: 14.67%
# Epoch [22/50], Train Loss: 1.0960, Train Acc: 70.20%, Val Loss: 4.2965, Val Acc: 13.86%
# Epoch [23/50], Train Loss: 1.0300, Train Acc: 70.68%, Val Loss: 4.8024, Val Acc: 17.12%
# Epoch [24/50], Train Loss: 0.8618, Train Acc: 75.57%, Val Loss: 5.1966, Val Acc: 16.30%
# Epoch [25/50], Train Loss: 0.7994, Train Acc: 77.32%, Val Loss: 5.0389, Val Acc: 14.40%
# Epoch [26/50], Train Loss: 0.7593, Train Acc: 78.99%, Val Loss: 5.0350, Val Acc: 15.22%
# Epoch [27/50], Train Loss: 0.6492, Train Acc: 81.58%, Val Loss: 6.0980, Val Acc: 17.12%
# Epoch [28/50], Train Loss: 0.6030, Train Acc: 83.30%, Val Loss: 5.0051, Val Acc: 18.48%
# Epoch [29/50], Train Loss: 0.5652, Train Acc: 83.48%, Val Loss: 5.7980, Val Acc: 14.95%
# Epoch [30/50], Train Loss: 0.5690, Train Acc: 83.21%, Val Loss: 5.9895, Val Acc: 14.67%
# Epoch [31/50], Train Loss: 0.4602, Train Acc: 86.99%, Val Loss: 6.5889, Val Acc: 17.93%
# Epoch [32/50], Train Loss: 0.4448, Train Acc: 87.47%, Val Loss: 6.7962, Val Acc: 14.13%
# Epoch [33/50], Train Loss: 0.4432, Train Acc: 87.59%, Val Loss: 5.8796, Val Acc: 17.93%
# Epoch [34/50], Train Loss: 0.4188, Train Acc: 88.50%, Val Loss: 6.4718, Val Acc: 13.86%
# Epoch [35/50], Train Loss: 0.3299, Train Acc: 89.82%, Val Loss: 7.4339, Val Acc: 15.22%
# Epoch [36/50], Train Loss: 0.3775, Train Acc: 89.31%, Val Loss: 6.0652, Val Acc: 16.30%
# Epoch [37/50], Train Loss: 0.3448, Train Acc: 90.34%, Val Loss: 7.0632, Val Acc: 13.59%
# Epoch [38/50], Train Loss: 0.3170, Train Acc: 91.18%, Val Loss: 7.3374, Val Acc: 15.49%
# Epoch [39/50], Train Loss: 0.2823, Train Acc: 92.48%, Val Loss: 7.3379, Val Acc: 16.85%
# Epoch [40/50], Train Loss: 0.3103, Train Acc: 91.43%, Val Loss: 7.0237, Val Acc: 16.30%
# Epoch [41/50], Train Loss: 0.2796, Train Acc: 91.39%, Val Loss: 6.6561, Val Acc: 13.04%
# Epoch [42/50], Train Loss: 0.2742, Train Acc: 92.27%, Val Loss: 7.0192, Val Acc: 17.12%
# Epoch [43/50], Train Loss: 0.2101, Train Acc: 94.11%, Val Loss: 7.6137, Val Acc: 15.49%
# Epoch [44/50], Train Loss: 0.2151, Train Acc: 93.54%, Val Loss: 7.6896, Val Acc: 15.76%
# Epoch [45/50], Train Loss: 0.2564, Train Acc: 92.24%, Val Loss: 7.4782, Val Acc: 16.30%
# Epoch [46/50], Train Loss: 0.2331, Train Acc: 93.72%, Val Loss: 7.9910, Val Acc: 13.32%
# Epoch [47/50], Train Loss: 0.1796, Train Acc: 94.81%, Val Loss: 8.4077, Val Acc: 13.86%
# Epoch [48/50], Train Loss: 0.2004, Train Acc: 94.02%, Val Loss: 7.9326, Val Acc: 18.21%
# Epoch [49/50], Train Loss: 0.2339, Train Acc: 93.57%, Val Loss: 7.4056, Val Acc: 12.77%
# Epoch [50/50], Train Loss: 0.1733, Train Acc: 95.02%, Val Loss: 7.9002, Val Acc: 16.30%
# Test Accuracy: 11.83%
