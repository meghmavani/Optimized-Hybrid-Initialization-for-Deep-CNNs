# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)

epochs = 50
batch_size = 128
learning_rate = 0.001

transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
])

train_dataset = torchvision.datasets.CIFAR100(root="./data", train=True, download=True, transform=transform)
test_dataset = torchvision.datasets.CIFAR100(root="./data", train=False, download=True, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

class CustomCNN(nn.Module):
    def __init__(self):
        super(CustomCNN,self).__init__()

        self.features = nn.Sequential(
            nn.Conv2d(3,64,3,padding=1), nn.ReLU(),
            nn.Conv2d(64,64,3,padding=1), nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64,128,3,padding=1), nn.ReLU(),
            nn.Conv2d(128,128,3,padding=1), nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(128,256,3,padding=1), nn.ReLU(),
            nn.Conv2d(256,256,3,padding=1), nn.ReLU(),
            nn.AdaptiveAvgPool2d((4,4))
        )

        self.classifier = nn.Sequential(
            nn.Linear(256*4*4,512),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(512,100)
        )

        self.initialize_weights()

    def initialize_weights(self):
        for m in self.modules():
            if isinstance(m,(nn.Conv2d,nn.Linear)):
                nn.init.orthogonal_(m.weight)
                with torch.no_grad():
                    m.weight *= torch.sqrt(torch.tensor(2.))
                if m.bias is not None:
                    nn.init.constant_(m.bias,0)

    def forward(self,x):
        x = self.features(x)
        x = torch.flatten(x,1)
        return self.classifier(x)

model = CustomCNN().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list=[]
val_loss_list=[]
train_acc_list=[]
val_acc_list=[]

for epoch in range(epochs):
    model.train()
    train_loss=0
    correct=0
    total=0

    for images,labels in train_loader:
        images,labels = images.to(device),labels.to(device)

        optimizer.zero_grad()
        outputs=model(images)
        loss=criterion(outputs,labels)

        loss.backward()
        optimizer.step()

        train_loss+=loss.item()

        _,predicted=torch.max(outputs,1)
        total+=labels.size(0)
        correct+=(predicted==labels).sum().item()

    train_loss/=len(train_loader)
    train_acc=100*correct/total

    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss=0
    correct=0
    total=0

    with torch.no_grad():
        for images,labels in test_loader:
            images,labels = images.to(device),labels.to(device)

            outputs=model(images)
            loss=criterion(outputs,labels)

            val_loss+=loss.item()

            _,predicted=torch.max(outputs,1)
            total+=labels.size(0)
            correct+=(predicted==labels).sum().item()

    val_loss/=len(test_loader)
    val_acc=100*correct/total

    val_loss_list.append(val_loss)
    val_acc_list.append(val_acc)

    print(
        f"Epoch [{epoch+1}/{epochs}] "
        f"Train Loss:{train_loss:.4f} | "
        f"Val Loss:{val_loss:.4f} | "
        f"Train Acc:{train_acc:.2f}% | "
        f"Val Acc:{val_acc:.2f}%"
    )

print(f"\nFinal Test Accuracy: {val_acc_list[-1]:.2f}%")

plt.figure(figsize=(6,4))
plt.plot(train_loss_list)
plt.title("Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid()
plt.show()

plt.figure(figsize=(6,4))
plt.plot(val_loss_list)
plt.title("Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid()
plt.show()

plt.figure(figsize=(6,4))
plt.plot(train_acc_list)
plt.title("Training Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.grid()
plt.show()

plt.figure(figsize=(6,4))
plt.plot(val_acc_list)
plt.title("Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.grid()
plt.show()
# Out:
# Using: cuda
# Epoch [1/50] Train Loss:4.0751 | Val Loss:3.6153 | Train Acc:7.33% | Val Acc:14.59%
# Epoch [2/50] Train Loss:3.4661 | Val Loss:3.1151 | Train Acc:16.75% | Val Acc:23.58%
# Epoch [3/50] Train Loss:3.0302 | Val Loss:2.7909 | Train Acc:24.82% | Val Acc:30.48%
# Epoch [4/50] Train Loss:2.6952 | Val Loss:2.4699 | Train Acc:30.96% | Val Acc:36.07%
# Epoch [5/50] Train Loss:2.4486 | Val Loss:2.2478 | Train Acc:36.34% | Val Acc:40.26%
# Epoch [6/50] Train Loss:2.2618 | Val Loss:2.1595 | Train Acc:40.22% | Val Acc:42.89%
# Epoch [7/50] Train Loss:2.1215 | Val Loss:2.0708 | Train Acc:43.17% | Val Acc:44.87%
# Epoch [8/50] Train Loss:2.0005 | Val Loss:1.9273 | Train Acc:45.88% | Val Acc:48.36%
# Epoch [9/50] Train Loss:1.8970 | Val Loss:1.9630 | Train Acc:48.45% | Val Acc:47.83%
# Epoch [10/50] Train Loss:1.8094 | Val Loss:1.8677 | Train Acc:50.30% | Val Acc:50.05%
# Epoch [11/50] Train Loss:1.7327 | Val Loss:1.7970 | Train Acc:52.19% | Val Acc:51.19%
# Epoch [12/50] Train Loss:1.6624 | Val Loss:1.7723 | Train Acc:53.63% | Val Acc:51.50%
# Epoch [13/50] Train Loss:1.6051 | Val Loss:1.7640 | Train Acc:55.21% | Val Acc:52.20%
# Epoch [14/50] Train Loss:1.5388 | Val Loss:1.7566 | Train Acc:56.81% | Val Acc:52.72%
# Epoch [15/50] Train Loss:1.4935 | Val Loss:1.7098 | Train Acc:57.77% | Val Acc:53.71%
# Epoch [16/50] Train Loss:1.4586 | Val Loss:1.6620 | Train Acc:58.74% | Val Acc:54.71%
# Epoch [17/50] Train Loss:1.4108 | Val Loss:1.6801 | Train Acc:59.80% | Val Acc:54.88%
# Epoch [18/50] Train Loss:1.3704 | Val Loss:1.6599 | Train Acc:60.98% | Val Acc:55.01%
# Epoch [19/50] Train Loss:1.3261 | Val Loss:1.6637 | Train Acc:61.90% | Val Acc:55.35%
# Epoch [20/50] Train Loss:1.2937 | Val Loss:1.6298 | Train Acc:62.75% | Val Acc:56.63%
# Epoch [21/50] Train Loss:1.2777 | Val Loss:1.7182 | Train Acc:63.38% | Val Acc:55.89%
# Epoch [22/50] Train Loss:1.2370 | Val Loss:1.6741 | Train Acc:64.36% | Val Acc:55.65%
# Epoch [23/50] Train Loss:1.2053 | Val Loss:1.6534 | Train Acc:64.81% | Val Acc:56.49%
# Epoch [24/50] Train Loss:1.1846 | Val Loss:1.6877 | Train Acc:65.54% | Val Acc:56.20%
# Epoch [25/50] Train Loss:1.1615 | Val Loss:1.6741 | Train Acc:66.08% | Val Acc:56.47%
# Epoch [26/50] Train Loss:1.1388 | Val Loss:1.6565 | Train Acc:66.70% | Val Acc:56.93%
# Epoch [27/50] Train Loss:1.1201 | Val Loss:1.6665 | Train Acc:67.23% | Val Acc:57.18%
# Epoch [28/50] Train Loss:1.0874 | Val Loss:1.6548 | Train Acc:67.78% | Val Acc:56.78%
# Epoch [29/50] Train Loss:1.0765 | Val Loss:1.6715 | Train Acc:68.20% | Val Acc:57.08%
# Epoch [30/50] Train Loss:1.0550 | Val Loss:1.6635 | Train Acc:68.76% | Val Acc:57.87%
# Epoch [31/50] Train Loss:1.0341 | Val Loss:1.6586 | Train Acc:69.04% | Val Acc:56.91%
# Epoch [32/50] Train Loss:1.0203 | Val Loss:1.6634 | Train Acc:69.83% | Val Acc:58.35%
# Epoch [33/50] Train Loss:1.0030 | Val Loss:1.6988 | Train Acc:70.48% | Val Acc:57.83%
# Epoch [34/50] Train Loss:0.9937 | Val Loss:1.7142 | Train Acc:70.48% | Val Acc:57.26%
# Epoch [35/50] Train Loss:0.9835 | Val Loss:1.7122 | Train Acc:70.51% | Val Acc:57.37%
# Epoch [36/50] Train Loss:0.9570 | Val Loss:1.6518 | Train Acc:71.57% | Val Acc:57.99%
# Epoch [37/50] Train Loss:0.9490 | Val Loss:1.7142 | Train Acc:71.77% | Val Acc:58.14%
# Epoch [38/50] Train Loss:0.9295 | Val Loss:1.7023 | Train Acc:72.24% | Val Acc:58.56%
# Epoch [39/50] Train Loss:0.9183 | Val Loss:1.7825 | Train Acc:72.34% | Val Acc:57.36%
# Epoch [40/50] Train Loss:0.9129 | Val Loss:1.7002 | Train Acc:72.74% | Val Acc:57.89%
# Epoch [41/50] Train Loss:0.8906 | Val Loss:1.7260 | Train Acc:73.24% | Val Acc:57.95%
# Epoch [42/50] Train Loss:0.8943 | Val Loss:1.7328 | Train Acc:73.14% | Val Acc:58.21%
# Epoch [43/50] Train Loss:0.8773 | Val Loss:1.7583 | Train Acc:73.51% | Val Acc:58.16%
# Epoch [44/50] Train Loss:0.8642 | Val Loss:1.7423 | Train Acc:74.00% | Val Acc:57.90%
# Epoch [45/50] Train Loss:0.8613 | Val Loss:1.7557 | Train Acc:74.17% | Val Acc:57.96%
# Epoch [46/50] Train Loss:0.8509 | Val Loss:1.8022 | Train Acc:74.33% | Val Acc:57.69%
# Epoch [47/50] Train Loss:0.8389 | Val Loss:1.7847 | Train Acc:74.68% | Val Acc:58.02%
# Epoch [48/50] Train Loss:0.8337 | Val Loss:1.7872 | Train Acc:74.67% | Val Acc:58.46%
# Epoch [49/50] Train Loss:0.8121 | Val Loss:1.7912 | Train Acc:75.37% | Val Acc:58.23%
# Epoch [50/50] Train Loss:0.8024 | Val Loss:1.8247 | Train Acc:75.50% | Val Acc:58.58%
#
# Final Test Accuracy: 58.58%
