# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

num_epochs = 50
batch_size = 128
learning_rate = 0.001

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = torchvision.datasets.CIFAR100(root='./data', train=True, transform=train_transform, download=True)
test_dataset = torchvision.datasets.CIFAR100(root='./data', train=False, transform=test_transform, download=True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    layer_idx = 0
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            if layer_idx < 6:
                nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
            else:
                nn.init.orthogonal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
            layer_idx += 1

class VGGLike(nn.Module):
    def __init__(self):
        super(VGGLike, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, 3, padding=1), nn.ReLU(), nn.BatchNorm2d(64),
            nn.Conv2d(64, 64, 3, padding=1), nn.ReLU(), nn.BatchNorm2d(64),
            nn.MaxPool2d(2, 2),

            nn.Conv2d(64, 128, 3, padding=1), nn.ReLU(), nn.BatchNorm2d(128),
            nn.Conv2d(128, 128, 3, padding=1), nn.ReLU(), nn.BatchNorm2d(128),
            nn.MaxPool2d(2, 2)
        )
        self.classifier = nn.Sequential(
            nn.Linear(8*8*128, 256), nn.ReLU(),
            nn.Linear(256, 100)
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        return self.classifier(x)

def train_model(model):
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)

    train_acc_list, val_acc_list = [], []
    train_loss_list, val_loss_list = [], []

    start_time = time.time()

    for epoch in range(num_epochs):
        model.train()
        correct, total, train_loss = 0, 0, 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_acc = 100 * correct / total
        train_acc_list.append(train_acc)
        train_loss_list.append(train_loss / len(train_loader))

        model.eval()
        correct, total, val_loss = 0, 0, 0
        with torch.no_grad():
            for images, labels in test_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        val_acc = 100 * correct / total
        val_acc_list.append(val_acc)
        val_loss_list.append(val_loss / len(test_loader))

        scheduler.step()

        print(f"Epoch [{epoch+1}/{num_epochs}] Train Acc: {train_acc:.2f}% Val Acc: {val_acc:.2f}% Train Loss: {train_loss_list[-1]:.4f} Val Loss: {val_loss_list[-1]:.4f}")

    duration = time.time() - start_time
    return train_acc_list, val_acc_list, train_loss_list, val_loss_list, duration

model = VGGLike()
custom_init(model)
train_acc, val_acc, train_loss, val_loss, time_taken = train_model(model)

plt.figure(figsize=(6, 4))
plt.plot(train_loss, label='Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train Loss')
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(val_loss, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Validation Loss')
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(train_acc, label='Train Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Train Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(val_acc, label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Validation Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

print(f"\nTraining completed in {time_taken:.2f} seconds.")
# Out:
# Epoch [1/50] Train Acc: 8.97% Val Acc: 15.96% Train Loss: 4.0918 Val Loss: 3.5187
# Epoch [2/50] Train Acc: 19.86% Val Acc: 26.10% Train Loss: 3.2662 Val Loss: 2.9143
# Epoch [3/50] Train Acc: 28.15% Val Acc: 32.96% Train Loss: 2.8131 Val Loss: 2.5666
# Epoch [4/50] Train Acc: 33.65% Val Acc: 37.51% Train Loss: 2.5271 Val Loss: 2.3650
# Epoch [5/50] Train Acc: 38.09% Val Acc: 41.71% Train Loss: 2.3247 Val Loss: 2.1814
# Epoch [6/50] Train Acc: 41.52% Val Acc: 43.84% Train Loss: 2.1656 Val Loss: 2.0876
# Epoch [7/50] Train Acc: 44.34% Val Acc: 45.92% Train Loss: 2.0437 Val Loss: 2.0275
# Epoch [8/50] Train Acc: 46.95% Val Acc: 47.59% Train Loss: 1.9403 Val Loss: 1.9873
# Epoch [9/50] Train Acc: 48.73% Val Acc: 49.17% Train Loss: 1.8482 Val Loss: 1.8934
# Epoch [10/50] Train Acc: 50.64% Val Acc: 49.54% Train Loss: 1.7846 Val Loss: 1.8691
# Epoch [11/50] Train Acc: 51.90% Val Acc: 50.51% Train Loss: 1.7300 Val Loss: 1.8319
# Epoch [12/50] Train Acc: 53.42% Val Acc: 52.41% Train Loss: 1.6622 Val Loss: 1.7990
# Epoch [13/50] Train Acc: 54.51% Val Acc: 52.93% Train Loss: 1.6119 Val Loss: 1.7621
# Epoch [14/50] Train Acc: 55.96% Val Acc: 52.71% Train Loss: 1.5582 Val Loss: 1.7819
# Epoch [15/50] Train Acc: 56.86% Val Acc: 53.70% Train Loss: 1.5218 Val Loss: 1.7331
# Epoch [16/50] Train Acc: 57.99% Val Acc: 54.21% Train Loss: 1.4741 Val Loss: 1.7164
# Epoch [17/50] Train Acc: 58.88% Val Acc: 54.28% Train Loss: 1.4411 Val Loss: 1.7128
# Epoch [18/50] Train Acc: 59.70% Val Acc: 55.53% Train Loss: 1.3994 Val Loss: 1.6874
# Epoch [19/50] Train Acc: 61.19% Val Acc: 55.43% Train Loss: 1.3612 Val Loss: 1.6743
# Epoch [20/50] Train Acc: 61.73% Val Acc: 55.55% Train Loss: 1.3259 Val Loss: 1.6728
# Epoch [21/50] Train Acc: 62.77% Val Acc: 55.97% Train Loss: 1.2880 Val Loss: 1.6602
# Epoch [22/50] Train Acc: 63.72% Val Acc: 55.73% Train Loss: 1.2552 Val Loss: 1.7068
# Epoch [23/50] Train Acc: 64.50% Val Acc: 56.38% Train Loss: 1.2211 Val Loss: 1.6860
# Epoch [24/50] Train Acc: 65.52% Val Acc: 56.94% Train Loss: 1.1839 Val Loss: 1.6761
# Epoch [25/50] Train Acc: 66.47% Val Acc: 57.05% Train Loss: 1.1523 Val Loss: 1.6636
# Epoch [26/50] Train Acc: 67.40% Val Acc: 57.11% Train Loss: 1.1174 Val Loss: 1.6857
# Epoch [27/50] Train Acc: 67.99% Val Acc: 57.59% Train Loss: 1.0925 Val Loss: 1.6958
# Epoch [28/50] Train Acc: 68.62% Val Acc: 58.03% Train Loss: 1.0668 Val Loss: 1.6662
# Epoch [29/50] Train Acc: 69.42% Val Acc: 58.12% Train Loss: 1.0410 Val Loss: 1.6675
# Epoch [30/50] Train Acc: 69.90% Val Acc: 58.27% Train Loss: 1.0142 Val Loss: 1.6785
# Epoch [31/50] Train Acc: 71.05% Val Acc: 58.32% Train Loss: 0.9813 Val Loss: 1.6746
# Epoch [32/50] Train Acc: 71.58% Val Acc: 58.29% Train Loss: 0.9662 Val Loss: 1.6876
# Epoch [33/50] Train Acc: 72.43% Val Acc: 58.89% Train Loss: 0.9306 Val Loss: 1.6757
# Epoch [34/50] Train Acc: 72.91% Val Acc: 59.12% Train Loss: 0.9105 Val Loss: 1.6702
# Epoch [35/50] Train Acc: 73.82% Val Acc: 58.89% Train Loss: 0.8808 Val Loss: 1.6922
# Epoch [36/50] Train Acc: 74.03% Val Acc: 59.47% Train Loss: 0.8708 Val Loss: 1.6809
# Epoch [37/50] Train Acc: 74.49% Val Acc: 59.38% Train Loss: 0.8585 Val Loss: 1.6930
# Epoch [38/50] Train Acc: 75.36% Val Acc: 59.25% Train Loss: 0.8279 Val Loss: 1.6969
# Epoch [39/50] Train Acc: 75.57% Val Acc: 59.36% Train Loss: 0.8214 Val Loss: 1.6935
# Epoch [40/50] Train Acc: 75.95% Val Acc: 59.33% Train Loss: 0.8036 Val Loss: 1.7140
# Epoch [41/50] Train Acc: 76.37% Val Acc: 59.34% Train Loss: 0.7907 Val Loss: 1.7115
# Epoch [42/50] Train Acc: 76.66% Val Acc: 59.53% Train Loss: 0.7815 Val Loss: 1.7107
# Epoch [43/50] Train Acc: 76.69% Val Acc: 59.55% Train Loss: 0.7720 Val Loss: 1.7129
# Epoch [44/50] Train Acc: 77.13% Val Acc: 59.46% Train Loss: 0.7619 Val Loss: 1.7061
# Epoch [45/50] Train Acc: 77.57% Val Acc: 59.73% Train Loss: 0.7494 Val Loss: 1.7107
# Epoch [46/50] Train Acc: 77.43% Val Acc: 59.64% Train Loss: 0.7520 Val Loss: 1.7097
# Epoch [47/50] Train Acc: 77.78% Val Acc: 59.63% Train Loss: 0.7417 Val Loss: 1.7107
# Epoch [48/50] Train Acc: 77.69% Val Acc: 59.57% Train Loss: 0.7467 Val Loss: 1.7131
# Epoch [49/50] Train Acc: 77.85% Val Acc: 59.60% Train Loss: 0.7426 Val Loss: 1.7109
# Epoch [50/50] Train Acc: 77.74% Val Acc: 59.74% Train Loss: 0.7451 Val Loss: 1.7092
# Training completed in 1851.53 seconds.
