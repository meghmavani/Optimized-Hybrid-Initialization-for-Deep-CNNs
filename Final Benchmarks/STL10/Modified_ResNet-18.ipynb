# %% [markdown]
# # This is a Modified ResNet-18 (an 18-Layer RNN with Dropout).

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision.models import resnet18
import matplotlib.pyplot as plt
import time

# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.cuda.empty_cache()
torch.backends.cudnn.benchmark = True

# Hyperparameters
num_epochs = 50
batch_size = 16
learning_rate = 0.001

# STL10 transforms with Data Augmentation
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(64, padding=4),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.Resize((64, 64)),  # Resize from 96x96 to 64x64
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5),
                         (0.5, 0.5, 0.5))
])

# STL10 dataset
train_dataset = torchvision.datasets.STL10(root='./data', split='train', download=True, transform=transform)
test_dataset = torchvision.datasets.STL10(root='./data', split='test', download=True, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Custom Initialization: He for shallow, Orthogonal for deep
def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    layer_idx = 0
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            if layer_idx < 10:
                nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
            else:
                nn.init.orthogonal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
            layer_idx += 1

# Modify ResNet18 with Dropout in the Fully Connected Layer
class ResNet18Modified(nn.Module):
    def __init__(self):
        super(ResNet18Modified, self).__init__()
        self.model = resnet18()
        self.model.fc = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(self.model.fc.in_features, 10)
        )
        custom_init(self.model)

    def forward(self, x):
        return self.model(x)

model = ResNet18Modified().to(device)

# Loss and optimizer with weight decay for L2 regularization
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=num_epochs)

# Train the model
train_acc_list, val_acc_list = [], []
train_loss_list, val_loss_list = [], []
start_time = time.time()

for epoch in range(num_epochs):
    model.train()
    total, correct, train_loss = 0, 0, 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_acc = 100 * correct / total
    train_acc_list.append(train_acc)
    train_loss_list.append(train_loss / len(train_loader))

    # Validation
    model.eval()
    correct, total, val_loss = 0, 0, 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    val_acc = 100 * correct / total
    val_acc_list.append(val_acc)
    val_loss_list.append(val_loss / len(test_loader))

    scheduler.step()

    print(f"Epoch [{epoch + 1}/{num_epochs}], "
          f"Train Acc: {train_acc:.2f}%, Val Acc: {val_acc:.2f}%, "
          f"Train Loss: {train_loss_list[-1]:.4f}, Val Loss: {val_loss_list[-1]:.4f}")

duration = time.time() - start_time
print(f"\nTraining completed in {duration:.2f} seconds.")

# Visualization
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.plot(val_loss_list, label='Val Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_acc_list, label='Train Acc')
plt.plot(val_acc_list, label='Val Acc')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch [1/50], Train Acc: 19.46%, Val Acc: 26.23%, Train Loss: 2.5729, Val Loss: 1.9646
# Epoch [2/50], Train Acc: 24.78%, Val Acc: 28.54%, Train Loss: 2.1000, Val Loss: 1.9165
# Epoch [3/50], Train Acc: 28.18%, Val Acc: 30.91%, Train Loss: 1.9416, Val Loss: 2.1104
# Epoch [4/50], Train Acc: 32.46%, Val Acc: 34.86%, Train Loss: 1.8281, Val Loss: 1.6942
# Epoch [5/50], Train Acc: 34.30%, Val Acc: 35.06%, Train Loss: 1.7777, Val Loss: 1.7108
# Epoch [6/50], Train Acc: 37.00%, Val Acc: 36.46%, Train Loss: 1.7063, Val Loss: 1.7789
# Epoch [7/50], Train Acc: 36.92%, Val Acc: 41.95%, Train Loss: 1.6679, Val Loss: 1.5358
# Epoch [8/50], Train Acc: 41.02%, Val Acc: 41.88%, Train Loss: 1.5897, Val Loss: 1.6161
# Epoch [9/50], Train Acc: 42.60%, Val Acc: 43.52%, Train Loss: 1.5467, Val Loss: 1.5292
# Epoch [10/50], Train Acc: 43.48%, Val Acc: 43.12%, Train Loss: 1.5416, Val Loss: 1.5517
# Epoch [11/50], Train Acc: 45.28%, Val Acc: 48.48%, Train Loss: 1.5019, Val Loss: 1.3917
# Epoch [12/50], Train Acc: 45.98%, Val Acc: 48.46%, Train Loss: 1.4832, Val Loss: 1.3900
# Epoch [13/50], Train Acc: 46.74%, Val Acc: 44.21%, Train Loss: 1.4628, Val Loss: 1.5454
# Epoch [14/50], Train Acc: 47.82%, Val Acc: 43.31%, Train Loss: 1.4189, Val Loss: 1.9135
# Epoch [15/50], Train Acc: 48.62%, Val Acc: 46.73%, Train Loss: 1.4065, Val Loss: 1.3963
# Epoch [16/50], Train Acc: 50.70%, Val Acc: 47.61%, Train Loss: 1.3604, Val Loss: 1.4484
# Epoch [17/50], Train Acc: 50.48%, Val Acc: 52.49%, Train Loss: 1.3436, Val Loss: 1.3241
# Epoch [18/50], Train Acc: 52.08%, Val Acc: 52.55%, Train Loss: 1.3329, Val Loss: 1.2900
# Epoch [19/50], Train Acc: 52.30%, Val Acc: 52.44%, Train Loss: 1.2988, Val Loss: 1.2899
# Epoch [20/50], Train Acc: 53.66%, Val Acc: 55.35%, Train Loss: 1.2889, Val Loss: 1.2307
# Epoch [21/50], Train Acc: 54.84%, Val Acc: 52.48%, Train Loss: 1.2506, Val Loss: 1.3161
# Epoch [22/50], Train Acc: 55.78%, Val Acc: 56.27%, Train Loss: 1.2319, Val Loss: 1.2177
# Epoch [23/50], Train Acc: 57.42%, Val Acc: 54.05%, Train Loss: 1.1925, Val Loss: 1.3581
# Epoch [24/50], Train Acc: 57.70%, Val Acc: 58.65%, Train Loss: 1.1779, Val Loss: 1.1607
# Epoch [25/50], Train Acc: 58.38%, Val Acc: 56.83%, Train Loss: 1.1671, Val Loss: 1.1710
# Epoch [26/50], Train Acc: 59.44%, Val Acc: 60.49%, Train Loss: 1.1365, Val Loss: 1.1177
# Epoch [27/50], Train Acc: 59.44%, Val Acc: 60.15%, Train Loss: 1.1118, Val Loss: 1.1106
# Epoch [28/50], Train Acc: 60.90%, Val Acc: 59.45%, Train Loss: 1.0942, Val Loss: 1.1226
# Epoch [29/50], Train Acc: 62.40%, Val Acc: 61.48%, Train Loss: 1.0662, Val Loss: 1.0918
# Epoch [30/50], Train Acc: 62.04%, Val Acc: 61.45%, Train Loss: 1.0519, Val Loss: 1.0691
# Epoch [31/50], Train Acc: 63.56%, Val Acc: 62.75%, Train Loss: 1.0193, Val Loss: 1.0437
# Epoch [32/50], Train Acc: 63.54%, Val Acc: 62.46%, Train Loss: 1.0177, Val Loss: 1.0427
# Epoch [33/50], Train Acc: 65.46%, Val Acc: 64.49%, Train Loss: 0.9660, Val Loss: 1.0134
# Epoch [34/50], Train Acc: 66.04%, Val Acc: 63.95%, Train Loss: 0.9530, Val Loss: 1.0070
# Epoch [35/50], Train Acc: 67.34%, Val Acc: 64.80%, Train Loss: 0.9112, Val Loss: 0.9817
# Epoch [36/50], Train Acc: 67.68%, Val Acc: 64.79%, Train Loss: 0.9013, Val Loss: 1.0120
# Epoch [37/50], Train Acc: 68.92%, Val Acc: 64.70%, Train Loss: 0.8773, Val Loss: 0.9808
# Epoch [38/50], Train Acc: 69.36%, Val Acc: 66.29%, Train Loss: 0.8558, Val Loss: 0.9506
# Epoch [39/50], Train Acc: 69.48%, Val Acc: 67.00%, Train Loss: 0.8452, Val Loss: 0.9266
# Epoch [40/50], Train Acc: 70.52%, Val Acc: 66.61%, Train Loss: 0.8344, Val Loss: 0.9529
# Epoch [41/50], Train Acc: 70.98%, Val Acc: 66.75%, Train Loss: 0.8050, Val Loss: 0.9462
# Epoch [42/50], Train Acc: 70.86%, Val Acc: 67.60%, Train Loss: 0.8050, Val Loss: 0.9227
# Epoch [43/50], Train Acc: 72.06%, Val Acc: 66.66%, Train Loss: 0.7819, Val Loss: 0.9328
# Epoch [44/50], Train Acc: 72.04%, Val Acc: 67.79%, Train Loss: 0.7748, Val Loss: 0.9140
# Epoch [45/50], Train Acc: 73.18%, Val Acc: 68.66%, Train Loss: 0.7482, Val Loss: 0.9229
# Epoch [46/50], Train Acc: 74.00%, Val Acc: 67.45%, Train Loss: 0.7436, Val Loss: 0.9208
# Epoch [47/50], Train Acc: 74.06%, Val Acc: 67.67%, Train Loss: 0.7426, Val Loss: 0.9091
# Epoch [48/50], Train Acc: 74.50%, Val Acc: 67.91%, Train Loss: 0.7307, Val Loss: 0.9078
# Epoch [49/50], Train Acc: 74.16%, Val Acc: 68.31%, Train Loss: 0.7297, Val Loss: 0.9053
# Epoch [50/50], Train Acc: 74.08%, Val Acc: 68.12%, Train Loss: 0.7269, Val Loss: 0.9035
#
# Training completed in 877.86 seconds.
