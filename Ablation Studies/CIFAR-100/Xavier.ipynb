# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)

run_name = 'CIFAR-100_Xavier'
epochs = 50
batch_size = 128
learning_rate = 0.001

transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
])

train_dataset = torchvision.datasets.CIFAR100(root="../../Final Benchmarks/CIFAR-100/data", train=True, download=True, transform=transform)
test_dataset = torchvision.datasets.CIFAR100(root="../../Final Benchmarks/CIFAR-100/data", train=False, download=True, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# No separate validation split in the source notebook: the test set is
# evaluated every epoch and doubles as "val" throughout training.
val_loader = test_loader

def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            nn.init.xavier_normal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)


class CustomCNN(nn.Module):
    def __init__(self):
        super(CustomCNN,self).__init__()

        self.features = nn.Sequential(
            nn.Conv2d(3,64,3,padding=1), nn.ReLU(),
            nn.Conv2d(64,64,3,padding=1), nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64,128,3,padding=1), nn.ReLU(),
            nn.Conv2d(128,128,3,padding=1), nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(128,256,3,padding=1), nn.ReLU(),
            nn.Conv2d(256,256,3,padding=1), nn.ReLU(),
            nn.AdaptiveAvgPool2d((4,4))
        )

        self.classifier = nn.Sequential(
            nn.Linear(256*4*4,512),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(512,100)
        )

    def forward(self,x):
        x = self.features(x)
        x = torch.flatten(x,1)
        return self.classifier(x)

model = CustomCNN().to(device)
custom_init(model)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list=[]
val_loss_list=[]
train_acc_list=[]
val_acc_list=[]

for epoch in range(epochs):
    model.train()
    train_loss=0
    correct=0
    total=0

    for images,labels in train_loader:
        images,labels = images.to(device),labels.to(device)

        optimizer.zero_grad()
        outputs=model(images)
        loss=criterion(outputs,labels)

        loss.backward()
        optimizer.step()

        train_loss+=loss.item()

        _,predicted=torch.max(outputs,1)
        total+=labels.size(0)
        correct+=(predicted==labels).sum().item()

    train_loss/=len(train_loader)
    train_acc=100*correct/total

    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss=0
    correct=0
    total=0

    with torch.no_grad():
        for images,labels in val_loader:
            images,labels = images.to(device),labels.to(device)

            outputs=model(images)
            loss=criterion(outputs,labels)

            val_loss+=loss.item()

            _,predicted=torch.max(outputs,1)
            total+=labels.size(0)
            correct+=(predicted==labels).sum().item()

    val_loss/=len(val_loader)
    val_acc=100*correct/total

    val_loss_list.append(val_loss)
    val_acc_list.append(val_acc)

    print(
        f"Epoch [{epoch+1}/{epochs}] "
        f"Train Loss:{train_loss:.4f} | "
        f"Val Loss:{val_loss:.4f} | "
        f"Train Acc:{train_acc:.2f}% | "
        f"Val Acc:{val_acc:.2f}%"
    )

test_acc = val_acc_list[-1]
print(f"\nFinal Test Accuracy: {test_acc:.2f}%")

# Save metrics to files labelled with dataset + init method
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(len(train_loss_list)):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Using: cuda
# Epoch [1/50] Train Loss:4.0902 | Val Loss:3.6343 | Train Acc:7.04% | Val Acc:14.53%
# Epoch [2/50] Train Loss:3.4846 | Val Loss:3.1598 | Train Acc:16.27% | Val Acc:22.63%
# Epoch [3/50] Train Loss:3.0548 | Val Loss:2.8149 | Train Acc:24.22% | Val Acc:28.95%
# Epoch [4/50] Train Loss:2.7427 | Val Loss:2.4870 | Train Acc:30.05% | Val Acc:35.63%
# Epoch [5/50] Train Loss:2.5014 | Val Loss:2.3397 | Train Acc:35.11% | Val Acc:39.08%
# Epoch [6/50] Train Loss:2.3193 | Val Loss:2.2089 | Train Acc:38.86% | Val Acc:42.53%
# Epoch [7/50] Train Loss:2.1560 | Val Loss:2.0734 | Train Acc:42.57% | Val Acc:45.24%
# Epoch [8/50] Train Loss:2.0305 | Val Loss:1.9974 | Train Acc:45.26% | Val Acc:46.32%
# Epoch [9/50] Train Loss:1.9151 | Val Loss:1.9010 | Train Acc:47.91% | Val Acc:48.21%
# Epoch [10/50] Train Loss:1.8316 | Val Loss:1.8915 | Train Acc:49.57% | Val Acc:49.21%
# Epoch [11/50] Train Loss:1.7538 | Val Loss:1.7998 | Train Acc:51.95% | Val Acc:51.79%
# Epoch [12/50] Train Loss:1.6831 | Val Loss:1.7592 | Train Acc:53.29% | Val Acc:52.30%
# Epoch [13/50] Train Loss:1.6196 | Val Loss:1.7598 | Train Acc:54.72% | Val Acc:52.39%
# Epoch [14/50] Train Loss:1.5632 | Val Loss:1.7464 | Train Acc:56.15% | Val Acc:52.67%
# Epoch [15/50] Train Loss:1.5117 | Val Loss:1.7492 | Train Acc:57.50% | Val Acc:53.19%
# Epoch [16/50] Train Loss:1.4616 | Val Loss:1.7128 | Train Acc:58.47% | Val Acc:53.99%
# Epoch [17/50] Train Loss:1.4222 | Val Loss:1.6882 | Train Acc:59.63% | Val Acc:54.63%
# Epoch [18/50] Train Loss:1.3702 | Val Loss:1.6934 | Train Acc:60.83% | Val Acc:55.08%
# Epoch [19/50] Train Loss:1.3338 | Val Loss:1.6693 | Train Acc:61.44% | Val Acc:55.35%
# Epoch [20/50] Train Loss:1.3137 | Val Loss:1.6473 | Train Acc:62.41% | Val Acc:55.82%
# Epoch [21/50] Train Loss:1.2682 | Val Loss:1.6671 | Train Acc:63.32% | Val Acc:55.34%
# Epoch [22/50] Train Loss:1.2561 | Val Loss:1.7029 | Train Acc:63.60% | Val Acc:54.62%
# Epoch [23/50] Train Loss:1.2249 | Val Loss:1.6553 | Train Acc:64.46% | Val Acc:55.99%
# Epoch [24/50] Train Loss:1.1990 | Val Loss:1.6609 | Train Acc:64.89% | Val Acc:56.45%
# Epoch [25/50] Train Loss:1.1670 | Val Loss:1.6622 | Train Acc:65.88% | Val Acc:56.60%
# Epoch [26/50] Train Loss:1.1346 | Val Loss:1.6626 | Train Acc:66.85% | Val Acc:57.15%
# Epoch [27/50] Train Loss:1.1171 | Val Loss:1.6468 | Train Acc:67.29% | Val Acc:57.26%
# Epoch [28/50] Train Loss:1.0936 | Val Loss:1.6553 | Train Acc:67.69% | Val Acc:56.68%
# Epoch [29/50] Train Loss:1.0733 | Val Loss:1.6402 | Train Acc:68.30% | Val Acc:57.31%
# Epoch [30/50] Train Loss:1.0531 | Val Loss:1.7067 | Train Acc:68.82% | Val Acc:57.04%
# Epoch [31/50] Train Loss:1.0392 | Val Loss:1.7028 | Train Acc:69.29% | Val Acc:56.49%
# Epoch [32/50] Train Loss:1.0221 | Val Loss:1.6691 | Train Acc:69.54% | Val Acc:58.07%
# Epoch [33/50] Train Loss:1.0037 | Val Loss:1.6985 | Train Acc:70.08% | Val Acc:57.26%
# Epoch [34/50] Train Loss:0.9915 | Val Loss:1.6928 | Train Acc:70.46% | Val Acc:57.68%
# Epoch [35/50] Train Loss:0.9708 | Val Loss:1.6890 | Train Acc:70.77% | Val Acc:57.59%
# Epoch [36/50] Train Loss:0.9594 | Val Loss:1.6976 | Train Acc:70.92% | Val Acc:58.01%
# Epoch [37/50] Train Loss:0.9479 | Val Loss:1.7234 | Train Acc:71.67% | Val Acc:57.67%
# Epoch [38/50] Train Loss:0.9311 | Val Loss:1.7174 | Train Acc:72.14% | Val Acc:57.84%
# Epoch [39/50] Train Loss:0.9172 | Val Loss:1.7223 | Train Acc:72.45% | Val Acc:57.62%
# Epoch [40/50] Train Loss:0.9044 | Val Loss:1.7626 | Train Acc:72.79% | Val Acc:57.60%
# Epoch [41/50] Train Loss:0.8980 | Val Loss:1.7601 | Train Acc:73.07% | Val Acc:57.75%
# Epoch [42/50] Train Loss:0.8880 | Val Loss:1.7138 | Train Acc:73.22% | Val Acc:58.35%
# Epoch [43/50] Train Loss:0.8740 | Val Loss:1.7396 | Train Acc:73.54% | Val Acc:57.75%
# Epoch [44/50] Train Loss:0.8655 | Val Loss:1.7708 | Train Acc:73.58% | Val Acc:57.92%
# Epoch [45/50] Train Loss:0.8615 | Val Loss:1.7853 | Train Acc:73.77% | Val Acc:58.53%
# Epoch [46/50] Train Loss:0.8423 | Val Loss:1.7863 | Train Acc:74.52% | Val Acc:58.23%
# Epoch [47/50] Train Loss:0.8378 | Val Loss:1.7826 | Train Acc:74.65% | Val Acc:57.95%
# Epoch [48/50] Train Loss:0.8287 | Val Loss:1.7442 | Train Acc:74.76% | Val Acc:58.41%
# Epoch [49/50] Train Loss:0.8194 | Val Loss:1.7479 | Train Acc:75.20% | Val Acc:58.13%
# Epoch [50/50] Train Loss:0.8127 | Val Loss:1.8008 | Train Acc:75.30% | Val Acc:58.17%
#
# Final Test Accuracy: 58.17%
