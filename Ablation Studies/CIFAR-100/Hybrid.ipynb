# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)

run_name = 'CIFAR-100_Hybrid'
epochs = 50
batch_size = 128
learning_rate = 0.001

transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
])

train_dataset = torchvision.datasets.CIFAR100(root="../../Final Benchmarks/CIFAR-100/data", train=True, download=True, transform=transform)
test_dataset = torchvision.datasets.CIFAR100(root="../../Final Benchmarks/CIFAR-100/data", train=False, download=True, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# No separate validation split in the source notebook: the test set is
# evaluated every epoch and doubles as "val" throughout training.
val_loader = test_loader

def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    layer_idx = 0
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            if layer_idx < 6:
                nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
            else:
                nn.init.orthogonal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
            layer_idx += 1


class CustomCNN(nn.Module):
    def __init__(self):
        super(CustomCNN,self).__init__()

        self.features = nn.Sequential(
            nn.Conv2d(3,64,3,padding=1), nn.ReLU(),
            nn.Conv2d(64,64,3,padding=1), nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64,128,3,padding=1), nn.ReLU(),
            nn.Conv2d(128,128,3,padding=1), nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(128,256,3,padding=1), nn.ReLU(),
            nn.Conv2d(256,256,3,padding=1), nn.ReLU(),
            nn.AdaptiveAvgPool2d((4,4))
        )

        self.classifier = nn.Sequential(
            nn.Linear(256*4*4,512),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(512,100)
        )

    def forward(self,x):
        x = self.features(x)
        x = torch.flatten(x,1)
        return self.classifier(x)

model = CustomCNN().to(device)
custom_init(model)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list=[]
val_loss_list=[]
train_acc_list=[]
val_acc_list=[]

for epoch in range(epochs):
    model.train()
    train_loss=0
    correct=0
    total=0

    for images,labels in train_loader:
        images,labels = images.to(device),labels.to(device)

        optimizer.zero_grad()
        outputs=model(images)
        loss=criterion(outputs,labels)

        loss.backward()
        optimizer.step()

        train_loss+=loss.item()

        _,predicted=torch.max(outputs,1)
        total+=labels.size(0)
        correct+=(predicted==labels).sum().item()

    train_loss/=len(train_loader)
    train_acc=100*correct/total

    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss=0
    correct=0
    total=0

    with torch.no_grad():
        for images,labels in val_loader:
            images,labels = images.to(device),labels.to(device)

            outputs=model(images)
            loss=criterion(outputs,labels)

            val_loss+=loss.item()

            _,predicted=torch.max(outputs,1)
            total+=labels.size(0)
            correct+=(predicted==labels).sum().item()

    val_loss/=len(val_loader)
    val_acc=100*correct/total

    val_loss_list.append(val_loss)
    val_acc_list.append(val_acc)

    print(
        f"Epoch [{epoch+1}/{epochs}] "
        f"Train Loss:{train_loss:.4f} | "
        f"Val Loss:{val_loss:.4f} | "
        f"Train Acc:{train_acc:.2f}% | "
        f"Val Acc:{val_acc:.2f}%"
    )

test_acc = val_acc_list[-1]
print(f"\nFinal Test Accuracy: {test_acc:.2f}%")

# Save metrics to files labelled with dataset + init method
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(len(train_loss_list)):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Using: cuda
# Epoch [1/50] Train Loss:4.0650 | Val Loss:3.6264 | Train Acc:7.69% | Val Acc:14.48%
# Epoch [2/50] Train Loss:3.4313 | Val Loss:3.0487 | Train Acc:17.37% | Val Acc:24.90%
# Epoch [3/50] Train Loss:2.9992 | Val Loss:2.7380 | Train Acc:25.15% | Val Acc:30.57%
# Epoch [4/50] Train Loss:2.6809 | Val Loss:2.4245 | Train Acc:31.25% | Val Acc:37.35%
# Epoch [5/50] Train Loss:2.4416 | Val Loss:2.3389 | Train Acc:36.55% | Val Acc:39.31%
# Epoch [6/50] Train Loss:2.2552 | Val Loss:2.1921 | Train Acc:40.61% | Val Acc:42.37%
# Epoch [7/50] Train Loss:2.1122 | Val Loss:2.0542 | Train Acc:43.53% | Val Acc:44.98%
# Epoch [8/50] Train Loss:1.9862 | Val Loss:2.0124 | Train Acc:46.05% | Val Acc:46.49%
# Epoch [9/50] Train Loss:1.8835 | Val Loss:1.8697 | Train Acc:48.94% | Val Acc:49.47%
# Epoch [10/50] Train Loss:1.7876 | Val Loss:1.8298 | Train Acc:50.83% | Val Acc:50.63%
# Epoch [11/50] Train Loss:1.7040 | Val Loss:1.8175 | Train Acc:52.65% | Val Acc:51.21%
# Epoch [12/50] Train Loss:1.6401 | Val Loss:1.7847 | Train Acc:54.44% | Val Acc:52.27%
# Epoch [13/50] Train Loss:1.5813 | Val Loss:1.7650 | Train Acc:55.62% | Val Acc:52.67%
# Epoch [14/50] Train Loss:1.5310 | Val Loss:1.7158 | Train Acc:57.10% | Val Acc:53.52%
# Epoch [15/50] Train Loss:1.4852 | Val Loss:1.7357 | Train Acc:58.00% | Val Acc:53.37%
# Epoch [16/50] Train Loss:1.4342 | Val Loss:1.6565 | Train Acc:59.27% | Val Acc:54.76%
# Epoch [17/50] Train Loss:1.3896 | Val Loss:1.6785 | Train Acc:60.44% | Val Acc:54.89%
# Epoch [18/50] Train Loss:1.3585 | Val Loss:1.6907 | Train Acc:61.00% | Val Acc:55.29%
# Epoch [19/50] Train Loss:1.3209 | Val Loss:1.6754 | Train Acc:62.28% | Val Acc:55.31%
# Epoch [20/50] Train Loss:1.2833 | Val Loss:1.6661 | Train Acc:62.79% | Val Acc:56.00%
# Epoch [21/50] Train Loss:1.2551 | Val Loss:1.6900 | Train Acc:63.67% | Val Acc:55.49%
# Epoch [22/50] Train Loss:1.2282 | Val Loss:1.6848 | Train Acc:64.38% | Val Acc:54.97%
# Epoch [23/50] Train Loss:1.1978 | Val Loss:1.6695 | Train Acc:65.23% | Val Acc:55.79%
# Epoch [24/50] Train Loss:1.1776 | Val Loss:1.6475 | Train Acc:65.39% | Val Acc:56.47%
# Epoch [25/50] Train Loss:1.1575 | Val Loss:1.6898 | Train Acc:66.14% | Val Acc:56.33%
# Epoch [26/50] Train Loss:1.1298 | Val Loss:1.6544 | Train Acc:66.64% | Val Acc:56.74%
# Epoch [27/50] Train Loss:1.1021 | Val Loss:1.6417 | Train Acc:67.77% | Val Acc:56.99%
# Epoch [28/50] Train Loss:1.0811 | Val Loss:1.6834 | Train Acc:68.34% | Val Acc:56.53%
# Epoch [29/50] Train Loss:1.0613 | Val Loss:1.7092 | Train Acc:68.84% | Val Acc:57.33%
# Epoch [30/50] Train Loss:1.0509 | Val Loss:1.6431 | Train Acc:68.96% | Val Acc:57.49%
# Epoch [31/50] Train Loss:1.0156 | Val Loss:1.7097 | Train Acc:69.69% | Val Acc:57.27%
# Epoch [32/50] Train Loss:1.0176 | Val Loss:1.6774 | Train Acc:69.89% | Val Acc:57.86%
# Epoch [33/50] Train Loss:1.0000 | Val Loss:1.7300 | Train Acc:70.45% | Val Acc:56.66%
# Epoch [34/50] Train Loss:0.9887 | Val Loss:1.6855 | Train Acc:70.77% | Val Acc:57.20%
# Epoch [35/50] Train Loss:0.9796 | Val Loss:1.7512 | Train Acc:70.81% | Val Acc:56.49%
# Epoch [36/50] Train Loss:0.9559 | Val Loss:1.7024 | Train Acc:71.33% | Val Acc:57.28%
# Epoch [37/50] Train Loss:0.9417 | Val Loss:1.7304 | Train Acc:71.87% | Val Acc:57.69%
# Epoch [38/50] Train Loss:0.9316 | Val Loss:1.7090 | Train Acc:72.05% | Val Acc:58.07%
# Epoch [39/50] Train Loss:0.9196 | Val Loss:1.7144 | Train Acc:72.46% | Val Acc:57.75%
# Epoch [40/50] Train Loss:0.9038 | Val Loss:1.7575 | Train Acc:72.84% | Val Acc:57.76%
# Epoch [41/50] Train Loss:0.8992 | Val Loss:1.7286 | Train Acc:73.13% | Val Acc:57.99%
# Epoch [42/50] Train Loss:0.8778 | Val Loss:1.7396 | Train Acc:73.59% | Val Acc:58.31%
# Epoch [43/50] Train Loss:0.8707 | Val Loss:1.7683 | Train Acc:73.72% | Val Acc:58.00%
# Epoch [44/50] Train Loss:0.8630 | Val Loss:1.8264 | Train Acc:73.98% | Val Acc:57.35%
# Epoch [45/50] Train Loss:0.8608 | Val Loss:1.7635 | Train Acc:74.31% | Val Acc:58.62%
# Epoch [46/50] Train Loss:0.8418 | Val Loss:1.8298 | Train Acc:74.59% | Val Acc:57.84%
# Epoch [47/50] Train Loss:0.8462 | Val Loss:1.7638 | Train Acc:74.45% | Val Acc:58.27%
# Epoch [48/50] Train Loss:0.8348 | Val Loss:1.7678 | Train Acc:74.83% | Val Acc:58.06%
# Epoch [49/50] Train Loss:0.8124 | Val Loss:1.8280 | Train Acc:75.55% | Val Acc:57.52%
# Epoch [50/50] Train Loss:0.8180 | Val Loss:1.8328 | Train Acc:75.53% | Val Acc:58.12%
#
# Final Test Accuracy: 58.12%
