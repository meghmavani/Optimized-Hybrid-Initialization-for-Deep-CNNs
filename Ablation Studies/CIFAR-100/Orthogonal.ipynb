# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)

run_name = 'CIFAR-100_Orthogonal'
epochs = 50
batch_size = 128
learning_rate = 0.001

transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
])

train_dataset = torchvision.datasets.CIFAR100(root="../../Final Benchmarks/CIFAR-100/data", train=True, download=True, transform=transform)
test_dataset = torchvision.datasets.CIFAR100(root="../../Final Benchmarks/CIFAR-100/data", train=False, download=True, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# No separate validation split in the source notebook: the test set is
# evaluated every epoch and doubles as "val" throughout training.
val_loader = test_loader

def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            nn.init.orthogonal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)


class CustomCNN(nn.Module):
    def __init__(self):
        super(CustomCNN,self).__init__()

        self.features = nn.Sequential(
            nn.Conv2d(3,64,3,padding=1), nn.ReLU(),
            nn.Conv2d(64,64,3,padding=1), nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64,128,3,padding=1), nn.ReLU(),
            nn.Conv2d(128,128,3,padding=1), nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(128,256,3,padding=1), nn.ReLU(),
            nn.Conv2d(256,256,3,padding=1), nn.ReLU(),
            nn.AdaptiveAvgPool2d((4,4))
        )

        self.classifier = nn.Sequential(
            nn.Linear(256*4*4,512),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(512,100)
        )

    def forward(self,x):
        x = self.features(x)
        x = torch.flatten(x,1)
        return self.classifier(x)

model = CustomCNN().to(device)
custom_init(model)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list=[]
val_loss_list=[]
train_acc_list=[]
val_acc_list=[]

for epoch in range(epochs):
    model.train()
    train_loss=0
    correct=0
    total=0

    for images,labels in train_loader:
        images,labels = images.to(device),labels.to(device)

        optimizer.zero_grad()
        outputs=model(images)
        loss=criterion(outputs,labels)

        loss.backward()
        optimizer.step()

        train_loss+=loss.item()

        _,predicted=torch.max(outputs,1)
        total+=labels.size(0)
        correct+=(predicted==labels).sum().item()

    train_loss/=len(train_loader)
    train_acc=100*correct/total

    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss=0
    correct=0
    total=0

    with torch.no_grad():
        for images,labels in val_loader:
            images,labels = images.to(device),labels.to(device)

            outputs=model(images)
            loss=criterion(outputs,labels)

            val_loss+=loss.item()

            _,predicted=torch.max(outputs,1)
            total+=labels.size(0)
            correct+=(predicted==labels).sum().item()

    val_loss/=len(val_loader)
    val_acc=100*correct/total

    val_loss_list.append(val_loss)
    val_acc_list.append(val_acc)

    print(
        f"Epoch [{epoch+1}/{epochs}] "
        f"Train Loss:{train_loss:.4f} | "
        f"Val Loss:{val_loss:.4f} | "
        f"Train Acc:{train_acc:.2f}% | "
        f"Val Acc:{val_acc:.2f}%"
    )

test_acc = val_acc_list[-1]
print(f"\nFinal Test Accuracy: {test_acc:.2f}%")

# Save metrics to files labelled with dataset + init method
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(len(train_loss_list)):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Using: cuda
# Epoch [1/50] Train Loss:4.0722 | Val Loss:3.5829 | Train Acc:7.48% | Val Acc:15.10%
# Epoch [2/50] Train Loss:3.4382 | Val Loss:3.1413 | Train Acc:17.45% | Val Acc:22.83%
# Epoch [3/50] Train Loss:3.0216 | Val Loss:2.7178 | Train Acc:24.97% | Val Acc:31.59%
# Epoch [4/50] Train Loss:2.6931 | Val Loss:2.4341 | Train Acc:30.98% | Val Acc:36.74%
# Epoch [5/50] Train Loss:2.4475 | Val Loss:2.2797 | Train Acc:36.27% | Val Acc:39.81%
# Epoch [6/50] Train Loss:2.2619 | Val Loss:2.2001 | Train Acc:40.30% | Val Acc:42.91%
# Epoch [7/50] Train Loss:2.1151 | Val Loss:2.0595 | Train Acc:43.26% | Val Acc:45.07%
# Epoch [8/50] Train Loss:1.9883 | Val Loss:1.9579 | Train Acc:46.25% | Val Acc:47.92%
# Epoch [9/50] Train Loss:1.8844 | Val Loss:1.8739 | Train Acc:48.57% | Val Acc:49.33%
# Epoch [10/50] Train Loss:1.8127 | Val Loss:1.8540 | Train Acc:50.39% | Val Acc:50.41%
# Epoch [11/50] Train Loss:1.7262 | Val Loss:1.8131 | Train Acc:52.40% | Val Acc:51.33%
# Epoch [12/50] Train Loss:1.6627 | Val Loss:1.7722 | Train Acc:53.89% | Val Acc:51.96%
# Epoch [13/50] Train Loss:1.6021 | Val Loss:1.7742 | Train Acc:55.42% | Val Acc:52.05%
# Epoch [14/50] Train Loss:1.5459 | Val Loss:1.7585 | Train Acc:56.64% | Val Acc:52.73%
# Epoch [15/50] Train Loss:1.4976 | Val Loss:1.7573 | Train Acc:58.07% | Val Acc:52.94%
# Epoch [16/50] Train Loss:1.4572 | Val Loss:1.8223 | Train Acc:58.75% | Val Acc:52.43%
# Epoch [17/50] Train Loss:1.4120 | Val Loss:1.7128 | Train Acc:59.90% | Val Acc:53.89%
# Epoch [18/50] Train Loss:1.3658 | Val Loss:1.7090 | Train Acc:60.85% | Val Acc:54.20%
# Epoch [19/50] Train Loss:1.3382 | Val Loss:1.6546 | Train Acc:61.55% | Val Acc:55.86%
# Epoch [20/50] Train Loss:1.3089 | Val Loss:1.7222 | Train Acc:62.51% | Val Acc:55.26%
# Epoch [21/50] Train Loss:1.2740 | Val Loss:1.6696 | Train Acc:63.44% | Val Acc:56.07%
# Epoch [22/50] Train Loss:1.2387 | Val Loss:1.6840 | Train Acc:63.94% | Val Acc:55.97%
# Epoch [23/50] Train Loss:1.2135 | Val Loss:1.6816 | Train Acc:64.71% | Val Acc:56.48%
# Epoch [24/50] Train Loss:1.1822 | Val Loss:1.6619 | Train Acc:65.59% | Val Acc:56.55%
# Epoch [25/50] Train Loss:1.1671 | Val Loss:1.6902 | Train Acc:65.95% | Val Acc:56.64%
# Epoch [26/50] Train Loss:1.1529 | Val Loss:1.7328 | Train Acc:66.27% | Val Acc:56.48%
# Epoch [27/50] Train Loss:1.1322 | Val Loss:1.6708 | Train Acc:66.94% | Val Acc:57.07%
# Epoch [28/50] Train Loss:1.1007 | Val Loss:1.6715 | Train Acc:67.64% | Val Acc:56.26%
# Epoch [29/50] Train Loss:1.0812 | Val Loss:1.7098 | Train Acc:68.11% | Val Acc:56.42%
# Epoch [30/50] Train Loss:1.0653 | Val Loss:1.7309 | Train Acc:68.65% | Val Acc:55.81%
# Epoch [31/50] Train Loss:1.0424 | Val Loss:1.7023 | Train Acc:69.28% | Val Acc:56.81%
# Epoch [32/50] Train Loss:1.0357 | Val Loss:1.7161 | Train Acc:69.38% | Val Acc:57.46%
# Epoch [33/50] Train Loss:1.0139 | Val Loss:1.7202 | Train Acc:69.71% | Val Acc:57.02%
# Epoch [34/50] Train Loss:1.0006 | Val Loss:1.7239 | Train Acc:70.24% | Val Acc:56.59%
# Epoch [35/50] Train Loss:0.9806 | Val Loss:1.7297 | Train Acc:70.64% | Val Acc:57.71%
# Epoch [36/50] Train Loss:0.9766 | Val Loss:1.6906 | Train Acc:70.96% | Val Acc:57.46%
# Epoch [37/50] Train Loss:0.9630 | Val Loss:1.7362 | Train Acc:71.32% | Val Acc:56.99%
# Epoch [38/50] Train Loss:0.9454 | Val Loss:1.7339 | Train Acc:71.82% | Val Acc:57.23%
# Epoch [39/50] Train Loss:0.9447 | Val Loss:1.7196 | Train Acc:71.65% | Val Acc:57.66%
# Epoch [40/50] Train Loss:0.9191 | Val Loss:1.7383 | Train Acc:72.42% | Val Acc:57.08%
# Epoch [41/50] Train Loss:0.9151 | Val Loss:1.7496 | Train Acc:72.82% | Val Acc:57.70%
# Epoch [42/50] Train Loss:0.9032 | Val Loss:1.7655 | Train Acc:72.89% | Val Acc:56.85%
# Epoch [43/50] Train Loss:0.8988 | Val Loss:1.7662 | Train Acc:72.93% | Val Acc:58.23%
# Epoch [44/50] Train Loss:0.8850 | Val Loss:1.7617 | Train Acc:73.49% | Val Acc:57.52%
# Epoch [45/50] Train Loss:0.8729 | Val Loss:1.7585 | Train Acc:73.60% | Val Acc:58.11%
# Epoch [46/50] Train Loss:0.8590 | Val Loss:1.7947 | Train Acc:74.09% | Val Acc:58.02%
# Epoch [47/50] Train Loss:0.8490 | Val Loss:1.8528 | Train Acc:74.44% | Val Acc:56.94%
# Epoch [48/50] Train Loss:0.8426 | Val Loss:1.8054 | Train Acc:74.61% | Val Acc:57.27%
# Epoch [49/50] Train Loss:0.8433 | Val Loss:1.8385 | Train Acc:74.69% | Val Acc:57.91%
# Epoch [50/50] Train Loss:0.8311 | Val Loss:1.8496 | Train Acc:74.70% | Val Acc:57.50%
#
# Final Test Accuracy: 57.50%
