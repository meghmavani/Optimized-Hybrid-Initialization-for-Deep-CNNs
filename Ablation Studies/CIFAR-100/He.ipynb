# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using:", device)

run_name = 'CIFAR-100_He'
epochs = 50
batch_size = 128
learning_rate = 0.001

transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
])

train_dataset = torchvision.datasets.CIFAR100(root="../../Final Benchmarks/CIFAR-100/data", train=True, download=True, transform=transform)
test_dataset = torchvision.datasets.CIFAR100(root="../../Final Benchmarks/CIFAR-100/data", train=False, download=True, transform=transform)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# No separate validation split in the source notebook: the test set is
# evaluated every epoch and doubles as "val" throughout training.
val_loader = test_loader

def custom_init(model):
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)


class CustomCNN(nn.Module):
    def __init__(self):
        super(CustomCNN,self).__init__()

        self.features = nn.Sequential(
            nn.Conv2d(3,64,3,padding=1), nn.ReLU(),
            nn.Conv2d(64,64,3,padding=1), nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64,128,3,padding=1), nn.ReLU(),
            nn.Conv2d(128,128,3,padding=1), nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(128,256,3,padding=1), nn.ReLU(),
            nn.Conv2d(256,256,3,padding=1), nn.ReLU(),
            nn.AdaptiveAvgPool2d((4,4))
        )

        self.classifier = nn.Sequential(
            nn.Linear(256*4*4,512),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(512,100)
        )

    def forward(self,x):
        x = self.features(x)
        x = torch.flatten(x,1)
        return self.classifier(x)

model = CustomCNN().to(device)
custom_init(model)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list=[]
val_loss_list=[]
train_acc_list=[]
val_acc_list=[]

for epoch in range(epochs):
    model.train()
    train_loss=0
    correct=0
    total=0

    for images,labels in train_loader:
        images,labels = images.to(device),labels.to(device)

        optimizer.zero_grad()
        outputs=model(images)
        loss=criterion(outputs,labels)

        loss.backward()
        optimizer.step()

        train_loss+=loss.item()

        _,predicted=torch.max(outputs,1)
        total+=labels.size(0)
        correct+=(predicted==labels).sum().item()

    train_loss/=len(train_loader)
    train_acc=100*correct/total

    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss=0
    correct=0
    total=0

    with torch.no_grad():
        for images,labels in val_loader:
            images,labels = images.to(device),labels.to(device)

            outputs=model(images)
            loss=criterion(outputs,labels)

            val_loss+=loss.item()

            _,predicted=torch.max(outputs,1)
            total+=labels.size(0)
            correct+=(predicted==labels).sum().item()

    val_loss/=len(val_loader)
    val_acc=100*correct/total

    val_loss_list.append(val_loss)
    val_acc_list.append(val_acc)

    print(
        f"Epoch [{epoch+1}/{epochs}] "
        f"Train Loss:{train_loss:.4f} | "
        f"Val Loss:{val_loss:.4f} | "
        f"Train Acc:{train_acc:.2f}% | "
        f"Val Acc:{val_acc:.2f}%"
    )

test_acc = val_acc_list[-1]
print(f"\nFinal Test Accuracy: {test_acc:.2f}%")

# Save metrics to files labelled with dataset + init method
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(len(train_loss_list)):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Using: cuda
# Epoch [1/50] Train Loss:4.0668 | Val Loss:3.7009 | Train Acc:7.80% | Val Acc:14.18%
# Epoch [2/50] Train Loss:3.4487 | Val Loss:3.1232 | Train Acc:17.39% | Val Acc:23.45%
# Epoch [3/50] Train Loss:3.0366 | Val Loss:2.7908 | Train Acc:24.86% | Val Acc:29.66%
# Epoch [4/50] Train Loss:2.7362 | Val Loss:2.5202 | Train Acc:30.42% | Val Acc:35.53%
# Epoch [5/50] Train Loss:2.4975 | Val Loss:2.3719 | Train Acc:35.29% | Val Acc:38.52%
# Epoch [6/50] Train Loss:2.3089 | Val Loss:2.2049 | Train Acc:39.63% | Val Acc:41.25%
# Epoch [7/50] Train Loss:2.1574 | Val Loss:2.0831 | Train Acc:42.44% | Val Acc:44.92%
# Epoch [8/50] Train Loss:2.0398 | Val Loss:2.0372 | Train Acc:45.37% | Val Acc:46.46%
# Epoch [9/50] Train Loss:1.9253 | Val Loss:1.9592 | Train Acc:47.93% | Val Acc:48.06%
# Epoch [10/50] Train Loss:1.8353 | Val Loss:1.9001 | Train Acc:49.90% | Val Acc:49.85%
# Epoch [11/50] Train Loss:1.7562 | Val Loss:1.8830 | Train Acc:51.53% | Val Acc:49.55%
# Epoch [12/50] Train Loss:1.6831 | Val Loss:1.8323 | Train Acc:53.25% | Val Acc:50.29%
# Epoch [13/50] Train Loss:1.6249 | Val Loss:1.7794 | Train Acc:54.75% | Val Acc:52.26%
# Epoch [14/50] Train Loss:1.5702 | Val Loss:1.7726 | Train Acc:56.18% | Val Acc:53.05%
# Epoch [15/50] Train Loss:1.5111 | Val Loss:1.7121 | Train Acc:57.57% | Val Acc:53.62%
# Epoch [16/50] Train Loss:1.4750 | Val Loss:1.7126 | Train Acc:58.17% | Val Acc:53.56%
# Epoch [17/50] Train Loss:1.4221 | Val Loss:1.7137 | Train Acc:59.51% | Val Acc:54.32%
# Epoch [18/50] Train Loss:1.3940 | Val Loss:1.7038 | Train Acc:60.37% | Val Acc:54.71%
# Epoch [19/50] Train Loss:1.3535 | Val Loss:1.6917 | Train Acc:61.11% | Val Acc:54.94%
# Epoch [20/50] Train Loss:1.3138 | Val Loss:1.6928 | Train Acc:62.28% | Val Acc:54.40%
# Epoch [21/50] Train Loss:1.2770 | Val Loss:1.7017 | Train Acc:62.80% | Val Acc:55.76%
# Epoch [22/50] Train Loss:1.2513 | Val Loss:1.6992 | Train Acc:63.91% | Val Acc:55.67%
# Epoch [23/50] Train Loss:1.2264 | Val Loss:1.6722 | Train Acc:64.54% | Val Acc:55.92%
# Epoch [24/50] Train Loss:1.2058 | Val Loss:1.6943 | Train Acc:64.65% | Val Acc:55.46%
# Epoch [25/50] Train Loss:1.1764 | Val Loss:1.6816 | Train Acc:65.85% | Val Acc:56.39%
# Epoch [26/50] Train Loss:1.1576 | Val Loss:1.6985 | Train Acc:66.00% | Val Acc:56.13%
# Epoch [27/50] Train Loss:1.1379 | Val Loss:1.6491 | Train Acc:66.80% | Val Acc:56.41%
# Epoch [28/50] Train Loss:1.1121 | Val Loss:1.6732 | Train Acc:67.28% | Val Acc:56.77%
# Epoch [29/50] Train Loss:1.0995 | Val Loss:1.6984 | Train Acc:67.36% | Val Acc:56.66%
# Epoch [30/50] Train Loss:1.0728 | Val Loss:1.6731 | Train Acc:68.41% | Val Acc:57.07%
# Epoch [31/50] Train Loss:1.0636 | Val Loss:1.6714 | Train Acc:68.51% | Val Acc:56.83%
# Epoch [32/50] Train Loss:1.0411 | Val Loss:1.6764 | Train Acc:69.15% | Val Acc:57.40%
# Epoch [33/50] Train Loss:1.0208 | Val Loss:1.7556 | Train Acc:70.02% | Val Acc:57.00%
# Epoch [34/50] Train Loss:1.0061 | Val Loss:1.7351 | Train Acc:70.03% | Val Acc:56.89%
# Epoch [35/50] Train Loss:0.9951 | Val Loss:1.6771 | Train Acc:70.40% | Val Acc:57.79%
# Epoch [36/50] Train Loss:0.9792 | Val Loss:1.6877 | Train Acc:70.88% | Val Acc:57.53%
# Epoch [37/50] Train Loss:0.9620 | Val Loss:1.7167 | Train Acc:71.37% | Val Acc:57.25%
# Epoch [38/50] Train Loss:0.9591 | Val Loss:1.7446 | Train Acc:71.25% | Val Acc:57.40%
# Epoch [39/50] Train Loss:0.9386 | Val Loss:1.7003 | Train Acc:71.94% | Val Acc:57.59%
# Epoch [40/50] Train Loss:0.9224 | Val Loss:1.7208 | Train Acc:72.30% | Val Acc:58.18%
# Epoch [41/50] Train Loss:0.9182 | Val Loss:1.7483 | Train Acc:72.53% | Val Acc:57.66%
# Epoch [42/50] Train Loss:0.9088 | Val Loss:1.7578 | Train Acc:72.72% | Val Acc:57.19%
# Epoch [43/50] Train Loss:0.8937 | Val Loss:1.7605 | Train Acc:73.16% | Val Acc:57.77%
# Epoch [44/50] Train Loss:0.8819 | Val Loss:1.7616 | Train Acc:73.63% | Val Acc:57.21%
# Epoch [45/50] Train Loss:0.8690 | Val Loss:1.7858 | Train Acc:73.77% | Val Acc:57.33%
# Epoch [46/50] Train Loss:0.8641 | Val Loss:1.7885 | Train Acc:73.84% | Val Acc:58.55%
# Epoch [47/50] Train Loss:0.8515 | Val Loss:1.8068 | Train Acc:74.35% | Val Acc:57.64%
# Epoch [48/50] Train Loss:0.8410 | Val Loss:1.8507 | Train Acc:74.66% | Val Acc:57.60%
# Epoch [49/50] Train Loss:0.8426 | Val Loss:1.8010 | Train Acc:74.55% | Val Acc:58.01%
# Epoch [50/50] Train Loss:0.8390 | Val Loss:1.8325 | Train Acc:74.75% | Val Acc:56.55%
#
# Final Test Accuracy: 56.55%
