# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

num_epochs = 50
batch_size = 128
learning_rate = 0.001
run_name = 'GTSRB_Hybrid'

# No horizontal flip: traffic signs are direction-sensitive
train_transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = torchvision.datasets.GTSRB(root='../../Final Benchmarks/GTSRB/data', split='train', transform=train_transform, download=True)
train_size = int(0.9 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

test_dataset = torchvision.datasets.GTSRB(root='../../Final Benchmarks/GTSRB/data', split='test', transform=test_transform, download=True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    layer_idx = 0
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            if layer_idx < 6:
                nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
            else:
                nn.init.orthogonal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
            layer_idx += 1


# 9-layer CNN Model
class NineLayerCNN(nn.Module):
    def __init__(self):
        super(NineLayerCNN, self).__init__()

        # Conv block 1
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)

        # Conv block 2
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)

        # Conv block 3
        self.conv5 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.conv7 = nn.Conv2d(256, 128, kernel_size=3, padding=1)

        # FC layers
        self.fc1 = nn.Linear(128 * 4 * 4, 1024)
        self.fc2 = nn.Linear(1024, 43)


    def forward(self, x):

        # block 1
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)

        # block 2
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2)

        # block 3
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = F.relu(self.conv7(x))
        x = F.max_pool2d(x, 2)

        x = torch.flatten(x, 1)

        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        return x

# Instantiate model, apply custom initialization
model = NineLayerCNN().to(device)
custom_init(model)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss_list.append(val_loss / len(val_loader))
    val_acc_list.append(val_acc)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc:.2f}%')

correct = 0
total = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f'Test Accuracy: {test_acc:.2f}%')

# Save metrics to files labelled with dataset + init method
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(len(train_loss_list)):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Epoch [1/50], Train Loss: 2.8290, Train Acc: 21.31%, Val Loss: 1.7207, Val Acc: 45.01%
# Epoch [2/50], Train Loss: 1.0118, Train Acc: 65.92%, Val Loss: 0.4248, Val Acc: 86.22%
# Epoch [3/50], Train Loss: 0.2211, Train Acc: 92.92%, Val Loss: 0.1109, Val Acc: 96.70%
# Epoch [4/50], Train Loss: 0.0842, Train Acc: 97.46%, Val Loss: 0.0498, Val Acc: 98.50%
# Epoch [5/50], Train Loss: 0.0461, Train Acc: 98.68%, Val Loss: 0.0555, Val Acc: 98.27%
# Epoch [6/50], Train Loss: 0.0372, Train Acc: 98.90%, Val Loss: 0.0717, Val Acc: 97.86%
# Epoch [7/50], Train Loss: 0.0249, Train Acc: 99.27%, Val Loss: 0.0345, Val Acc: 99.14%
# Epoch [8/50], Train Loss: 0.0278, Train Acc: 99.22%, Val Loss: 0.0462, Val Acc: 98.80%
# Epoch [9/50], Train Loss: 0.0517, Train Acc: 98.64%, Val Loss: 0.0508, Val Acc: 98.57%
# Epoch [10/50], Train Loss: 0.0239, Train Acc: 99.32%, Val Loss: 0.0206, Val Acc: 99.55%
# Epoch [11/50], Train Loss: 0.0247, Train Acc: 99.34%, Val Loss: 0.0560, Val Acc: 98.65%
# Epoch [12/50], Train Loss: 0.0230, Train Acc: 99.37%, Val Loss: 0.0703, Val Acc: 98.54%
# Epoch [13/50], Train Loss: 0.0156, Train Acc: 99.55%, Val Loss: 0.1643, Val Acc: 96.88%
# Epoch [14/50], Train Loss: 0.0292, Train Acc: 99.24%, Val Loss: 0.0570, Val Acc: 98.84%
# Epoch [15/50], Train Loss: 0.0342, Train Acc: 99.18%, Val Loss: 0.0463, Val Acc: 99.21%
# Epoch [16/50], Train Loss: 0.0302, Train Acc: 99.30%, Val Loss: 0.1049, Val Acc: 97.18%
# Epoch [17/50], Train Loss: 0.0436, Train Acc: 98.94%, Val Loss: 0.0332, Val Acc: 99.17%
# Epoch [18/50], Train Loss: 0.0082, Train Acc: 99.77%, Val Loss: 0.0297, Val Acc: 99.59%
# Epoch [19/50], Train Loss: 0.0075, Train Acc: 99.86%, Val Loss: 0.0126, Val Acc: 99.77%
# Epoch [20/50], Train Loss: 0.0039, Train Acc: 99.91%, Val Loss: 0.0099, Val Acc: 99.70%
# Epoch [21/50], Train Loss: 0.0360, Train Acc: 99.22%, Val Loss: 0.0668, Val Acc: 98.31%
# Epoch [22/50], Train Loss: 0.0157, Train Acc: 99.63%, Val Loss: 0.0157, Val Acc: 99.62%
# Epoch [23/50], Train Loss: 0.0216, Train Acc: 99.46%, Val Loss: 0.0212, Val Acc: 99.62%
# Epoch [24/50], Train Loss: 0.0160, Train Acc: 99.66%, Val Loss: 0.0225, Val Acc: 99.62%
# Epoch [25/50], Train Loss: 0.0166, Train Acc: 99.66%, Val Loss: 0.0694, Val Acc: 98.65%
# Epoch [26/50], Train Loss: 0.0211, Train Acc: 99.55%, Val Loss: 0.0260, Val Acc: 99.62%
# Epoch [27/50], Train Loss: 0.0225, Train Acc: 99.50%, Val Loss: 0.0273, Val Acc: 99.40%
# Epoch [28/50], Train Loss: 0.0441, Train Acc: 99.14%, Val Loss: 0.0799, Val Acc: 98.57%
# Epoch [29/50], Train Loss: 0.0420, Train Acc: 99.14%, Val Loss: 0.0198, Val Acc: 99.55%
# Epoch [30/50], Train Loss: 0.0127, Train Acc: 99.70%, Val Loss: 0.0132, Val Acc: 99.74%
# Epoch [31/50], Train Loss: 0.0084, Train Acc: 99.84%, Val Loss: 0.0256, Val Acc: 99.44%
# Epoch [32/50], Train Loss: 0.0093, Train Acc: 99.78%, Val Loss: 0.0401, Val Acc: 99.10%
# Epoch [33/50], Train Loss: 0.0067, Train Acc: 99.85%, Val Loss: 0.0349, Val Acc: 99.40%
# Epoch [34/50], Train Loss: 0.0161, Train Acc: 99.67%, Val Loss: 0.0163, Val Acc: 99.59%
# Epoch [35/50], Train Loss: 0.0019, Train Acc: 99.95%, Val Loss: 0.0149, Val Acc: 99.81%
# Epoch [36/50], Train Loss: 0.0201, Train Acc: 99.64%, Val Loss: 0.0288, Val Acc: 99.40%
# Epoch [37/50], Train Loss: 0.0169, Train Acc: 99.65%, Val Loss: 0.0225, Val Acc: 99.85%
# Epoch [38/50], Train Loss: 0.0083, Train Acc: 99.81%, Val Loss: 0.0141, Val Acc: 99.81%
# Epoch [39/50], Train Loss: 0.0601, Train Acc: 98.81%, Val Loss: 0.0357, Val Acc: 99.47%
# Epoch [40/50], Train Loss: 0.0280, Train Acc: 99.48%, Val Loss: 0.0277, Val Acc: 99.66%
# Epoch [41/50], Train Loss: 0.0170, Train Acc: 99.67%, Val Loss: 0.0284, Val Acc: 99.62%
# Epoch [42/50], Train Loss: 0.0134, Train Acc: 99.77%, Val Loss: 0.0969, Val Acc: 97.60%
# Epoch [43/50], Train Loss: 0.0354, Train Acc: 99.35%, Val Loss: 0.0216, Val Acc: 99.55%
# Epoch [44/50], Train Loss: 0.0779, Train Acc: 98.95%, Val Loss: 0.0528, Val Acc: 99.17%
# Epoch [45/50], Train Loss: 0.0207, Train Acc: 99.55%, Val Loss: 0.0230, Val Acc: 99.59%
# Epoch [46/50], Train Loss: 0.0160, Train Acc: 99.76%, Val Loss: 0.0268, Val Acc: 99.14%
# Epoch [47/50], Train Loss: 0.0339, Train Acc: 99.44%, Val Loss: 0.0254, Val Acc: 99.59%
# Epoch [48/50], Train Loss: 0.0030, Train Acc: 99.94%, Val Loss: 0.0341, Val Acc: 99.62%
# Epoch [49/50], Train Loss: 0.0068, Train Acc: 99.91%, Val Loss: 0.0497, Val Acc: 99.74%
# Epoch [50/50], Train Loss: 0.0060, Train Acc: 99.90%, Val Loss: 0.0767, Val Acc: 99.40%
# Test Accuracy: 96.08%
