# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

num_epochs = 50
batch_size = 128
learning_rate = 0.001
run_name = 'GTSRB_Xavier'

# No horizontal flip: traffic signs are direction-sensitive
train_transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.RandomCrop(32, padding=4),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = torchvision.datasets.GTSRB(root='../../Final Benchmarks/GTSRB/data', split='train', transform=train_transform, download=True)
train_size = int(0.9 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

test_dataset = torchvision.datasets.GTSRB(root='../../Final Benchmarks/GTSRB/data', split='test', transform=test_transform, download=True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            nn.init.xavier_normal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)


# 9-layer CNN Model
class NineLayerCNN(nn.Module):
    def __init__(self):
        super(NineLayerCNN, self).__init__()

        # Conv block 1
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)

        # Conv block 2
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)

        # Conv block 3
        self.conv5 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.conv7 = nn.Conv2d(256, 128, kernel_size=3, padding=1)

        # FC layers
        self.fc1 = nn.Linear(128 * 4 * 4, 1024)
        self.fc2 = nn.Linear(1024, 43)


    def forward(self, x):

        # block 1
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)

        # block 2
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2)

        # block 3
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = F.relu(self.conv7(x))
        x = F.max_pool2d(x, 2)

        x = torch.flatten(x, 1)

        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        return x

# Instantiate model, apply custom initialization
model = NineLayerCNN().to(device)
custom_init(model)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss_list.append(val_loss / len(val_loader))
    val_acc_list.append(val_acc)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc:.2f}%')

correct = 0
total = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f'Test Accuracy: {test_acc:.2f}%')

# Save metrics to files labelled with dataset + init method
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(len(train_loss_list)):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Epoch [1/50], Train Loss: 2.8652, Train Acc: 19.65%, Val Loss: 1.9684, Val Acc: 36.97%
# Epoch [2/50], Train Loss: 1.0486, Train Acc: 65.21%, Val Loss: 0.5199, Val Acc: 84.53%
# Epoch [3/50], Train Loss: 0.2376, Train Acc: 92.55%, Val Loss: 0.1699, Val Acc: 95.76%
# Epoch [4/50], Train Loss: 0.0883, Train Acc: 97.26%, Val Loss: 0.0665, Val Acc: 98.20%
# Epoch [5/50], Train Loss: 0.0633, Train Acc: 97.96%, Val Loss: 0.0715, Val Acc: 98.35%
# Epoch [6/50], Train Loss: 0.0541, Train Acc: 98.47%, Val Loss: 0.0530, Val Acc: 98.65%
# Epoch [7/50], Train Loss: 0.0377, Train Acc: 98.82%, Val Loss: 0.0414, Val Acc: 99.10%
# Epoch [8/50], Train Loss: 0.0283, Train Acc: 99.17%, Val Loss: 0.0291, Val Acc: 99.29%
# Epoch [9/50], Train Loss: 0.0312, Train Acc: 99.11%, Val Loss: 0.0805, Val Acc: 98.12%
# Epoch [10/50], Train Loss: 0.0281, Train Acc: 99.14%, Val Loss: 0.0278, Val Acc: 99.29%
# Epoch [11/50], Train Loss: 0.0295, Train Acc: 99.15%, Val Loss: 0.0347, Val Acc: 99.17%
# Epoch [12/50], Train Loss: 0.0300, Train Acc: 99.11%, Val Loss: 0.0290, Val Acc: 99.44%
# Epoch [13/50], Train Loss: 0.0165, Train Acc: 99.50%, Val Loss: 0.1016, Val Acc: 97.71%
# Epoch [14/50], Train Loss: 0.0254, Train Acc: 99.25%, Val Loss: 0.0364, Val Acc: 98.80%
# Epoch [15/50], Train Loss: 0.0211, Train Acc: 99.41%, Val Loss: 0.0423, Val Acc: 99.21%
# Epoch [16/50], Train Loss: 0.0285, Train Acc: 99.27%, Val Loss: 0.0982, Val Acc: 97.79%
# Epoch [17/50], Train Loss: 0.0224, Train Acc: 99.43%, Val Loss: 0.0191, Val Acc: 99.66%
# Epoch [18/50], Train Loss: 0.0121, Train Acc: 99.63%, Val Loss: 0.0210, Val Acc: 99.70%
# Epoch [19/50], Train Loss: 0.0154, Train Acc: 99.62%, Val Loss: 0.0633, Val Acc: 98.57%
# Epoch [20/50], Train Loss: 0.0152, Train Acc: 99.64%, Val Loss: 0.0295, Val Acc: 99.40%
# Epoch [21/50], Train Loss: 0.0379, Train Acc: 99.09%, Val Loss: 0.0339, Val Acc: 99.14%
# Epoch [22/50], Train Loss: 0.0400, Train Acc: 99.10%, Val Loss: 0.0195, Val Acc: 99.55%
# Epoch [23/50], Train Loss: 0.0106, Train Acc: 99.75%, Val Loss: 0.0400, Val Acc: 99.17%
# Epoch [24/50], Train Loss: 0.0327, Train Acc: 99.20%, Val Loss: 0.0551, Val Acc: 98.84%
# Epoch [25/50], Train Loss: 0.0243, Train Acc: 99.47%, Val Loss: 0.0438, Val Acc: 98.95%
# Epoch [26/50], Train Loss: 0.0226, Train Acc: 99.50%, Val Loss: 0.0510, Val Acc: 98.76%
# Epoch [27/50], Train Loss: 0.0186, Train Acc: 99.52%, Val Loss: 0.0340, Val Acc: 99.40%
# Epoch [28/50], Train Loss: 0.0276, Train Acc: 99.40%, Val Loss: 0.0499, Val Acc: 98.61%
# Epoch [29/50], Train Loss: 0.0215, Train Acc: 99.54%, Val Loss: 0.0302, Val Acc: 99.40%
# Epoch [30/50], Train Loss: 0.0193, Train Acc: 99.51%, Val Loss: 0.0490, Val Acc: 98.91%
# Epoch [31/50], Train Loss: 0.0076, Train Acc: 99.84%, Val Loss: 0.0222, Val Acc: 99.66%
# Epoch [32/50], Train Loss: 0.0085, Train Acc: 99.75%, Val Loss: 0.0189, Val Acc: 99.59%
# Epoch [33/50], Train Loss: 0.0153, Train Acc: 99.65%, Val Loss: 0.0462, Val Acc: 99.40%
# Epoch [34/50], Train Loss: 0.0621, Train Acc: 98.77%, Val Loss: 0.4478, Val Acc: 93.28%
# Epoch [35/50], Train Loss: 0.0648, Train Acc: 98.86%, Val Loss: 0.0310, Val Acc: 99.51%
# Epoch [36/50], Train Loss: 0.0108, Train Acc: 99.75%, Val Loss: 0.0376, Val Acc: 99.17%
# Epoch [37/50], Train Loss: 0.0115, Train Acc: 99.70%, Val Loss: 0.0451, Val Acc: 99.25%
# Epoch [38/50], Train Loss: 0.0055, Train Acc: 99.89%, Val Loss: 0.0259, Val Acc: 99.66%
# Epoch [39/50], Train Loss: 0.0134, Train Acc: 99.71%, Val Loss: 0.0495, Val Acc: 99.47%
# Epoch [40/50], Train Loss: 0.0108, Train Acc: 99.77%, Val Loss: 0.0265, Val Acc: 99.70%
# Epoch [41/50], Train Loss: 0.0096, Train Acc: 99.82%, Val Loss: 0.0277, Val Acc: 99.36%
# Epoch [42/50], Train Loss: 0.0063, Train Acc: 99.82%, Val Loss: 0.0236, Val Acc: 99.70%
# Epoch [43/50], Train Loss: 0.0100, Train Acc: 99.80%, Val Loss: 0.0182, Val Acc: 99.70%
# Epoch [44/50], Train Loss: 0.0032, Train Acc: 99.92%, Val Loss: 0.0207, Val Acc: 99.70%
# Epoch [45/50], Train Loss: 0.0355, Train Acc: 99.34%, Val Loss: 0.0442, Val Acc: 99.29%
# Epoch [46/50], Train Loss: 0.0292, Train Acc: 99.39%, Val Loss: 0.1148, Val Acc: 98.65%
# Epoch [47/50], Train Loss: 0.0422, Train Acc: 99.16%, Val Loss: 0.0129, Val Acc: 99.70%
# Epoch [48/50], Train Loss: 0.0115, Train Acc: 99.72%, Val Loss: 0.0187, Val Acc: 99.74%
# Epoch [49/50], Train Loss: 0.0152, Train Acc: 99.67%, Val Loss: 0.0191, Val Acc: 99.70%
# Epoch [50/50], Train Loss: 0.0489, Train Acc: 99.20%, Val Loss: 0.1140, Val Acc: 98.84%
# Test Accuracy: 96.09%
