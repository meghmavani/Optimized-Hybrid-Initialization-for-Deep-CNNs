# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

num_epochs = 50
batch_size = 128
learning_rate = 0.001
run_name = 'Fashion-MNIST_Xavier'

train_transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.RandomHorizontalFlip(),
    transforms.Lambda(lambda img: img.convert("RGB")),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.Lambda(lambda img: img.convert("RGB")),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = torchvision.datasets.FashionMNIST(root='../../Final Benchmarks/Fashion-MNIST/data', train=True, transform=train_transform, download=True)
train_size = int(0.9 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

test_dataset = torchvision.datasets.FashionMNIST(root='../../Final Benchmarks/Fashion-MNIST/data', train=False, transform=test_transform, download=True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            nn.init.xavier_normal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)


# 9-layer CNN Model
class NineLayerCNN(nn.Module):
    def __init__(self):
        super(NineLayerCNN, self).__init__()

        # Conv block 1
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)

        # Conv block 2
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)

        # Conv block 3
        self.conv5 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.conv7 = nn.Conv2d(256, 128, kernel_size=3, padding=1)

        # FC layers
        self.fc1 = nn.Linear(128 * 4 * 4, 1024)
        self.fc2 = nn.Linear(1024, 10)


    def forward(self, x):

        # block 1
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)

        # block 2
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2)

        # block 3
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = F.relu(self.conv7(x))
        x = F.max_pool2d(x, 2)

        x = torch.flatten(x, 1)

        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        return x

# Instantiate model, apply custom initialization
model = NineLayerCNN().to(device)
custom_init(model)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss_list.append(val_loss / len(val_loader))
    val_acc_list.append(val_acc)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc:.2f}%')

correct = 0
total = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f'Test Accuracy: {test_acc:.2f}%')

# Save metrics to files labelled with dataset + init method
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(len(train_loss_list)):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Epoch [1/50], Train Loss: 0.5679, Train Acc: 80.19%, Val Loss: 0.3424, Val Acc: 87.42%
# Epoch [2/50], Train Loss: 0.2893, Train Acc: 89.56%, Val Loss: 0.2816, Val Acc: 89.57%
# Epoch [3/50], Train Loss: 0.2405, Train Acc: 91.29%, Val Loss: 0.2320, Val Acc: 91.43%
# Epoch [4/50], Train Loss: 0.2135, Train Acc: 92.19%, Val Loss: 0.2405, Val Acc: 91.23%
# Epoch [5/50], Train Loss: 0.1931, Train Acc: 93.03%, Val Loss: 0.2419, Val Acc: 90.93%
# Epoch [6/50], Train Loss: 0.1733, Train Acc: 93.68%, Val Loss: 0.2182, Val Acc: 91.92%
# Epoch [7/50], Train Loss: 0.1622, Train Acc: 94.05%, Val Loss: 0.2082, Val Acc: 92.55%
# Epoch [8/50], Train Loss: 0.1457, Train Acc: 94.69%, Val Loss: 0.2186, Val Acc: 92.15%
# Epoch [9/50], Train Loss: 0.1378, Train Acc: 95.06%, Val Loss: 0.2076, Val Acc: 92.37%
# Epoch [10/50], Train Loss: 0.1272, Train Acc: 95.27%, Val Loss: 0.2247, Val Acc: 92.02%
# Epoch [11/50], Train Loss: 0.1177, Train Acc: 95.76%, Val Loss: 0.2197, Val Acc: 92.67%
# Epoch [12/50], Train Loss: 0.1087, Train Acc: 96.05%, Val Loss: 0.2292, Val Acc: 92.37%
# Epoch [13/50], Train Loss: 0.1013, Train Acc: 96.32%, Val Loss: 0.2295, Val Acc: 92.72%
# Epoch [14/50], Train Loss: 0.0908, Train Acc: 96.67%, Val Loss: 0.2718, Val Acc: 92.52%
# Epoch [15/50], Train Loss: 0.0890, Train Acc: 96.70%, Val Loss: 0.2659, Val Acc: 92.08%
# Epoch [16/50], Train Loss: 0.0790, Train Acc: 97.11%, Val Loss: 0.3018, Val Acc: 92.48%
# Epoch [17/50], Train Loss: 0.0752, Train Acc: 97.26%, Val Loss: 0.2664, Val Acc: 92.77%
# Epoch [18/50], Train Loss: 0.0692, Train Acc: 97.54%, Val Loss: 0.2679, Val Acc: 92.23%
# Epoch [19/50], Train Loss: 0.0710, Train Acc: 97.43%, Val Loss: 0.3025, Val Acc: 92.58%
# Epoch [20/50], Train Loss: 0.0680, Train Acc: 97.63%, Val Loss: 0.3289, Val Acc: 92.45%
# Epoch [21/50], Train Loss: 0.0613, Train Acc: 97.81%, Val Loss: 0.2780, Val Acc: 92.58%
# Epoch [22/50], Train Loss: 0.0595, Train Acc: 97.84%, Val Loss: 0.3553, Val Acc: 92.12%
# Epoch [23/50], Train Loss: 0.0592, Train Acc: 97.93%, Val Loss: 0.3402, Val Acc: 92.33%
# Epoch [24/50], Train Loss: 0.0511, Train Acc: 98.14%, Val Loss: 0.3469, Val Acc: 92.85%
# Epoch [25/50], Train Loss: 0.0529, Train Acc: 98.19%, Val Loss: 0.3233, Val Acc: 92.78%
# Epoch [26/50], Train Loss: 0.0507, Train Acc: 98.26%, Val Loss: 0.3522, Val Acc: 92.13%
# Epoch [27/50], Train Loss: 0.0540, Train Acc: 98.12%, Val Loss: 0.4017, Val Acc: 92.13%
# Epoch [28/50], Train Loss: 0.0515, Train Acc: 98.28%, Val Loss: 0.3665, Val Acc: 92.30%
# Epoch [29/50], Train Loss: 0.0576, Train Acc: 98.05%, Val Loss: 0.3361, Val Acc: 92.37%
# Epoch [30/50], Train Loss: 0.0393, Train Acc: 98.59%, Val Loss: 0.3819, Val Acc: 92.78%
# Epoch [31/50], Train Loss: 0.0470, Train Acc: 98.41%, Val Loss: 0.4167, Val Acc: 92.23%
# Epoch [32/50], Train Loss: 0.0467, Train Acc: 98.41%, Val Loss: 0.4103, Val Acc: 92.08%
# Epoch [33/50], Train Loss: 0.0430, Train Acc: 98.55%, Val Loss: 0.3798, Val Acc: 92.50%
# Epoch [34/50], Train Loss: 0.0399, Train Acc: 98.65%, Val Loss: 0.4107, Val Acc: 91.92%
# Epoch [35/50], Train Loss: 0.0515, Train Acc: 98.27%, Val Loss: 0.3812, Val Acc: 92.40%
# Epoch [36/50], Train Loss: 0.0427, Train Acc: 98.61%, Val Loss: 0.3786, Val Acc: 92.23%
# Epoch [37/50], Train Loss: 0.0381, Train Acc: 98.65%, Val Loss: 0.4381, Val Acc: 92.40%
# Epoch [38/50], Train Loss: 0.0436, Train Acc: 98.62%, Val Loss: 0.4190, Val Acc: 92.27%
# Epoch [39/50], Train Loss: 0.0421, Train Acc: 98.58%, Val Loss: 0.4019, Val Acc: 92.03%
# Epoch [40/50], Train Loss: 0.0417, Train Acc: 98.66%, Val Loss: 0.4074, Val Acc: 92.37%
# Epoch [41/50], Train Loss: 0.0371, Train Acc: 98.78%, Val Loss: 0.4588, Val Acc: 92.35%
# Epoch [42/50], Train Loss: 0.0460, Train Acc: 98.56%, Val Loss: 0.4225, Val Acc: 92.40%
# Epoch [43/50], Train Loss: 0.0391, Train Acc: 98.72%, Val Loss: 0.4181, Val Acc: 92.60%
# Epoch [44/50], Train Loss: 0.0397, Train Acc: 98.69%, Val Loss: 0.4462, Val Acc: 92.38%
# Epoch [45/50], Train Loss: 0.0428, Train Acc: 98.62%, Val Loss: 0.4257, Val Acc: 92.70%
# Epoch [46/50], Train Loss: 0.0396, Train Acc: 98.70%, Val Loss: 0.4291, Val Acc: 92.53%
# Epoch [47/50], Train Loss: 0.0407, Train Acc: 98.64%, Val Loss: 0.4184, Val Acc: 92.25%
# Epoch [48/50], Train Loss: 0.0350, Train Acc: 98.82%, Val Loss: 0.5051, Val Acc: 92.83%
# Epoch [49/50], Train Loss: 0.0476, Train Acc: 98.54%, Val Loss: 0.4398, Val Acc: 91.70%
# Epoch [50/50], Train Loss: 0.0411, Train Acc: 98.64%, Val Loss: 0.4116, Val Acc: 92.38%
# Test Accuracy: 91.96%
