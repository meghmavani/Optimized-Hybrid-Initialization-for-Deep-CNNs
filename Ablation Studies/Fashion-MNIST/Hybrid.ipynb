# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

num_epochs = 50
batch_size = 128
learning_rate = 0.001
run_name = 'Fashion-MNIST_Hybrid'

train_transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.RandomHorizontalFlip(),
    transforms.Lambda(lambda img: img.convert("RGB")),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.Lambda(lambda img: img.convert("RGB")),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = torchvision.datasets.FashionMNIST(root='../../Final Benchmarks/Fashion-MNIST/data', train=True, transform=train_transform, download=True)
train_size = int(0.9 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

test_dataset = torchvision.datasets.FashionMNIST(root='../../Final Benchmarks/Fashion-MNIST/data', train=False, transform=test_transform, download=True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    layer_idx = 0
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            if layer_idx < 6:
                nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
            else:
                nn.init.orthogonal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
            layer_idx += 1


# 9-layer CNN Model
class NineLayerCNN(nn.Module):
    def __init__(self):
        super(NineLayerCNN, self).__init__()

        # Conv block 1
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)

        # Conv block 2
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)

        # Conv block 3
        self.conv5 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.conv7 = nn.Conv2d(256, 128, kernel_size=3, padding=1)

        # FC layers
        self.fc1 = nn.Linear(128 * 4 * 4, 1024)
        self.fc2 = nn.Linear(1024, 10)


    def forward(self, x):

        # block 1
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)

        # block 2
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2)

        # block 3
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = F.relu(self.conv7(x))
        x = F.max_pool2d(x, 2)

        x = torch.flatten(x, 1)

        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        return x

# Instantiate model, apply custom initialization
model = NineLayerCNN().to(device)
custom_init(model)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss_list.append(val_loss / len(val_loader))
    val_acc_list.append(val_acc)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc:.2f}%')

correct = 0
total = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f'Test Accuracy: {test_acc:.2f}%')

# Save metrics to files labelled with dataset + init method
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(len(train_loss_list)):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Epoch [1/50], Train Loss: 0.6892, Train Acc: 78.20%, Val Loss: 0.3242, Val Acc: 87.68%
# Epoch [2/50], Train Loss: 0.3097, Train Acc: 88.66%, Val Loss: 0.2756, Val Acc: 90.12%
# Epoch [3/50], Train Loss: 0.2600, Train Acc: 90.40%, Val Loss: 0.2455, Val Acc: 90.97%
# Epoch [4/50], Train Loss: 0.2238, Train Acc: 91.76%, Val Loss: 0.2173, Val Acc: 91.77%
# Epoch [5/50], Train Loss: 0.2019, Train Acc: 92.54%, Val Loss: 0.2150, Val Acc: 92.00%
# Epoch [6/50], Train Loss: 0.1856, Train Acc: 93.20%, Val Loss: 0.2077, Val Acc: 92.45%
# Epoch [7/50], Train Loss: 0.1726, Train Acc: 93.63%, Val Loss: 0.2175, Val Acc: 92.58%
# Epoch [8/50], Train Loss: 0.1540, Train Acc: 94.38%, Val Loss: 0.2106, Val Acc: 92.42%
# Epoch [9/50], Train Loss: 0.1428, Train Acc: 94.78%, Val Loss: 0.2027, Val Acc: 92.58%
# Epoch [10/50], Train Loss: 0.1330, Train Acc: 95.07%, Val Loss: 0.2217, Val Acc: 92.73%
# Epoch [11/50], Train Loss: 0.1226, Train Acc: 95.54%, Val Loss: 0.2174, Val Acc: 92.82%
# Epoch [12/50], Train Loss: 0.1099, Train Acc: 95.96%, Val Loss: 0.2205, Val Acc: 92.77%
# Epoch [13/50], Train Loss: 0.1054, Train Acc: 96.15%, Val Loss: 0.2180, Val Acc: 92.82%
# Epoch [14/50], Train Loss: 0.0936, Train Acc: 96.65%, Val Loss: 0.2320, Val Acc: 93.12%
# Epoch [15/50], Train Loss: 0.0924, Train Acc: 96.61%, Val Loss: 0.2195, Val Acc: 92.83%
# Epoch [16/50], Train Loss: 0.0857, Train Acc: 96.84%, Val Loss: 0.2366, Val Acc: 93.10%
# Epoch [17/50], Train Loss: 0.0805, Train Acc: 97.05%, Val Loss: 0.2666, Val Acc: 93.07%
# Epoch [18/50], Train Loss: 0.0758, Train Acc: 97.32%, Val Loss: 0.2390, Val Acc: 93.10%
# Epoch [19/50], Train Loss: 0.0684, Train Acc: 97.51%, Val Loss: 0.2542, Val Acc: 92.48%
# Epoch [20/50], Train Loss: 0.0621, Train Acc: 97.76%, Val Loss: 0.3181, Val Acc: 92.60%
# Epoch [21/50], Train Loss: 0.0630, Train Acc: 97.71%, Val Loss: 0.3124, Val Acc: 92.92%
# Epoch [22/50], Train Loss: 0.0644, Train Acc: 97.68%, Val Loss: 0.3065, Val Acc: 92.67%
# Epoch [23/50], Train Loss: 0.0631, Train Acc: 97.74%, Val Loss: 0.2748, Val Acc: 93.03%
# Epoch [24/50], Train Loss: 0.0551, Train Acc: 98.00%, Val Loss: 0.2903, Val Acc: 92.87%
# Epoch [25/50], Train Loss: 0.0549, Train Acc: 98.12%, Val Loss: 0.3285, Val Acc: 92.50%
# Epoch [26/50], Train Loss: 0.0552, Train Acc: 98.04%, Val Loss: 0.2856, Val Acc: 92.80%
# Epoch [27/50], Train Loss: 0.0556, Train Acc: 98.14%, Val Loss: 0.2719, Val Acc: 93.17%
# Epoch [28/50], Train Loss: 0.0477, Train Acc: 98.31%, Val Loss: 0.3188, Val Acc: 92.85%
# Epoch [29/50], Train Loss: 0.0478, Train Acc: 98.39%, Val Loss: 0.3485, Val Acc: 92.87%
# Epoch [30/50], Train Loss: 0.0513, Train Acc: 98.26%, Val Loss: 0.3108, Val Acc: 92.23%
# Epoch [31/50], Train Loss: 0.0474, Train Acc: 98.40%, Val Loss: 0.3398, Val Acc: 92.97%
# Epoch [32/50], Train Loss: 0.0512, Train Acc: 98.30%, Val Loss: 0.3621, Val Acc: 92.80%
# Epoch [33/50], Train Loss: 0.0483, Train Acc: 98.37%, Val Loss: 0.3885, Val Acc: 92.52%
# Epoch [34/50], Train Loss: 0.0458, Train Acc: 98.50%, Val Loss: 0.3534, Val Acc: 93.23%
# Epoch [35/50], Train Loss: 0.0451, Train Acc: 98.53%, Val Loss: 0.3793, Val Acc: 92.93%
# Epoch [36/50], Train Loss: 0.0394, Train Acc: 98.72%, Val Loss: 0.3118, Val Acc: 92.48%
# Epoch [37/50], Train Loss: 0.0448, Train Acc: 98.49%, Val Loss: 0.4033, Val Acc: 92.85%
# Epoch [38/50], Train Loss: 0.0485, Train Acc: 98.44%, Val Loss: 0.3935, Val Acc: 92.23%
# Epoch [39/50], Train Loss: 0.0466, Train Acc: 98.49%, Val Loss: 0.3463, Val Acc: 92.72%
# Epoch [40/50], Train Loss: 0.0436, Train Acc: 98.64%, Val Loss: 0.3845, Val Acc: 92.72%
# Epoch [41/50], Train Loss: 0.0364, Train Acc: 98.81%, Val Loss: 0.4021, Val Acc: 92.45%
# Epoch [42/50], Train Loss: 0.0456, Train Acc: 98.56%, Val Loss: 0.3726, Val Acc: 93.07%
# Epoch [43/50], Train Loss: 0.0452, Train Acc: 98.53%, Val Loss: 0.3827, Val Acc: 92.73%
# Epoch [44/50], Train Loss: 0.0390, Train Acc: 98.73%, Val Loss: 0.4044, Val Acc: 93.03%
# Epoch [45/50], Train Loss: 0.0393, Train Acc: 98.77%, Val Loss: 0.3836, Val Acc: 92.22%
# Epoch [46/50], Train Loss: 0.0395, Train Acc: 98.74%, Val Loss: 0.3944, Val Acc: 92.90%
# Epoch [47/50], Train Loss: 0.0395, Train Acc: 98.74%, Val Loss: 0.4262, Val Acc: 92.60%
# Epoch [48/50], Train Loss: 0.0382, Train Acc: 98.82%, Val Loss: 0.4310, Val Acc: 92.65%
# Epoch [49/50], Train Loss: 0.0416, Train Acc: 98.67%, Val Loss: 0.4285, Val Acc: 92.68%
# Epoch [50/50], Train Loss: 0.0514, Train Acc: 98.42%, Val Loss: 0.4201, Val Acc: 92.42%
# Test Accuracy: 92.33%
