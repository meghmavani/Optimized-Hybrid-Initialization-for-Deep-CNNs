# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

num_epochs = 50
batch_size = 128
learning_rate = 0.001
run_name = 'CIFAR-10_Xavier'

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = torchvision.datasets.CIFAR10(root='../../Final Benchmarks/CIFAR-10/data', train=True, transform=train_transform, download=True)
train_size = int(0.9 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

test_dataset = torchvision.datasets.CIFAR10(root='../../Final Benchmarks/CIFAR-10/data', train=False, transform=test_transform, download=True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            nn.init.xavier_normal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)


# 9-layer CNN Model
class NineLayerCNN(nn.Module):
    def __init__(self):
        super(NineLayerCNN, self).__init__()

        # Conv block 1
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)

        # Conv block 2
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)

        # Conv block 3
        self.conv5 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.conv7 = nn.Conv2d(256, 128, kernel_size=3, padding=1)

        # FC layers
        self.fc1 = nn.Linear(128 * 4 * 4, 1024)
        self.fc2 = nn.Linear(1024, 10)


    def forward(self, x):

        # block 1
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)

        # block 2
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2)

        # block 3
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = F.relu(self.conv7(x))
        x = F.max_pool2d(x, 2)

        x = torch.flatten(x, 1)

        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        return x

# Instantiate model, apply custom initialization
model = NineLayerCNN().to(device)
custom_init(model)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss_list.append(val_loss / len(val_loader))
    val_acc_list.append(val_acc)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc:.2f}%')

correct = 0
total = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f'Test Accuracy: {test_acc:.2f}%')

# Save metrics to files labelled with dataset + init method
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(len(train_loss_list)):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Epoch [1/50], Train Loss: 1.7205, Train Acc: 36.77%, Val Loss: 1.3650, Val Acc: 49.82%
# Epoch [2/50], Train Loss: 1.1533, Train Acc: 58.34%, Val Loss: 1.0142, Val Acc: 63.74%
# Epoch [3/50], Train Loss: 0.8878, Train Acc: 68.40%, Val Loss: 0.8414, Val Acc: 70.48%
# Epoch [4/50], Train Loss: 0.7399, Train Acc: 74.12%, Val Loss: 0.7324, Val Acc: 74.32%
# Epoch [5/50], Train Loss: 0.6468, Train Acc: 77.43%, Val Loss: 0.6419, Val Acc: 77.38%
# Epoch [6/50], Train Loss: 0.5740, Train Acc: 79.94%, Val Loss: 0.6515, Val Acc: 77.68%
# Epoch [7/50], Train Loss: 0.5184, Train Acc: 82.11%, Val Loss: 0.5889, Val Acc: 79.58%
# Epoch [8/50], Train Loss: 0.4716, Train Acc: 83.51%, Val Loss: 0.5518, Val Acc: 81.12%
# Epoch [9/50], Train Loss: 0.4416, Train Acc: 84.75%, Val Loss: 0.5414, Val Acc: 81.74%
# Epoch [10/50], Train Loss: 0.4119, Train Acc: 85.72%, Val Loss: 0.5373, Val Acc: 81.98%
# Epoch [11/50], Train Loss: 0.3810, Train Acc: 86.79%, Val Loss: 0.5256, Val Acc: 82.38%
# Epoch [12/50], Train Loss: 0.3606, Train Acc: 87.44%, Val Loss: 0.5133, Val Acc: 83.32%
# Epoch [13/50], Train Loss: 0.3426, Train Acc: 88.03%, Val Loss: 0.5080, Val Acc: 82.88%
# Epoch [14/50], Train Loss: 0.3250, Train Acc: 88.81%, Val Loss: 0.4626, Val Acc: 84.40%
# Epoch [15/50], Train Loss: 0.3095, Train Acc: 89.34%, Val Loss: 0.5051, Val Acc: 84.14%
# Epoch [16/50], Train Loss: 0.2910, Train Acc: 90.05%, Val Loss: 0.5151, Val Acc: 83.54%
# Epoch [17/50], Train Loss: 0.2825, Train Acc: 90.26%, Val Loss: 0.4982, Val Acc: 84.34%
# Epoch [18/50], Train Loss: 0.2725, Train Acc: 90.61%, Val Loss: 0.5123, Val Acc: 84.44%
# Epoch [19/50], Train Loss: 0.2617, Train Acc: 90.74%, Val Loss: 0.4995, Val Acc: 84.90%
# Epoch [20/50], Train Loss: 0.2524, Train Acc: 91.38%, Val Loss: 0.5269, Val Acc: 84.02%
# Epoch [21/50], Train Loss: 0.2418, Train Acc: 91.53%, Val Loss: 0.4639, Val Acc: 85.76%
# Epoch [22/50], Train Loss: 0.2338, Train Acc: 91.80%, Val Loss: 0.5616, Val Acc: 83.18%
# Epoch [23/50], Train Loss: 0.2296, Train Acc: 92.13%, Val Loss: 0.5407, Val Acc: 84.86%
# Epoch [24/50], Train Loss: 0.2325, Train Acc: 92.07%, Val Loss: 0.5005, Val Acc: 84.64%
# Epoch [25/50], Train Loss: 0.2152, Train Acc: 92.58%, Val Loss: 0.5220, Val Acc: 85.06%
# Epoch [26/50], Train Loss: 0.2238, Train Acc: 92.23%, Val Loss: 0.4711, Val Acc: 85.80%
# Epoch [27/50], Train Loss: 0.1978, Train Acc: 93.20%, Val Loss: 0.5200, Val Acc: 85.54%
# Epoch [28/50], Train Loss: 0.2029, Train Acc: 93.07%, Val Loss: 0.5550, Val Acc: 84.38%
# Epoch [29/50], Train Loss: 0.1961, Train Acc: 93.36%, Val Loss: 0.5789, Val Acc: 84.22%
# Epoch [30/50], Train Loss: 0.1946, Train Acc: 93.29%, Val Loss: 0.5019, Val Acc: 86.34%
# Epoch [31/50], Train Loss: 0.1872, Train Acc: 93.64%, Val Loss: 0.5690, Val Acc: 85.40%
# Epoch [32/50], Train Loss: 0.1820, Train Acc: 93.79%, Val Loss: 0.5407, Val Acc: 85.40%
# Epoch [33/50], Train Loss: 0.1808, Train Acc: 93.78%, Val Loss: 0.5598, Val Acc: 86.00%
# Epoch [34/50], Train Loss: 0.1766, Train Acc: 93.98%, Val Loss: 0.5211, Val Acc: 86.28%
# Epoch [35/50], Train Loss: 0.1844, Train Acc: 93.70%, Val Loss: 0.6051, Val Acc: 84.00%
# Epoch [36/50], Train Loss: 0.1739, Train Acc: 94.05%, Val Loss: 0.5282, Val Acc: 85.46%
# Epoch [37/50], Train Loss: 0.1786, Train Acc: 93.98%, Val Loss: 0.5854, Val Acc: 84.26%
# Epoch [38/50], Train Loss: 0.1665, Train Acc: 94.43%, Val Loss: 0.5190, Val Acc: 85.60%
# Epoch [39/50], Train Loss: 0.1642, Train Acc: 94.48%, Val Loss: 0.5239, Val Acc: 86.26%
# Epoch [40/50], Train Loss: 0.1608, Train Acc: 94.54%, Val Loss: 0.5461, Val Acc: 84.90%
# Epoch [41/50], Train Loss: 0.1592, Train Acc: 94.74%, Val Loss: 0.5520, Val Acc: 85.56%
# Epoch [42/50], Train Loss: 0.1617, Train Acc: 94.56%, Val Loss: 0.5268, Val Acc: 84.94%
# Epoch [43/50], Train Loss: 0.1557, Train Acc: 94.69%, Val Loss: 0.6034, Val Acc: 85.14%
# Epoch [44/50], Train Loss: 0.1525, Train Acc: 94.82%, Val Loss: 0.5959, Val Acc: 85.74%
# Epoch [45/50], Train Loss: 0.1486, Train Acc: 94.96%, Val Loss: 0.6031, Val Acc: 85.68%
# Epoch [46/50], Train Loss: 0.1517, Train Acc: 94.84%, Val Loss: 0.6179, Val Acc: 85.30%
# Epoch [47/50], Train Loss: 0.1477, Train Acc: 94.94%, Val Loss: 0.5968, Val Acc: 86.08%
# Epoch [48/50], Train Loss: 0.1536, Train Acc: 94.90%, Val Loss: 0.5651, Val Acc: 85.64%
# Epoch [49/50], Train Loss: 0.1437, Train Acc: 95.28%, Val Loss: 0.6252, Val Acc: 85.52%
# Epoch [50/50], Train Loss: 0.1459, Train Acc: 95.23%, Val Loss: 0.5496, Val Acc: 86.34%
# Test Accuracy: 86.83%
