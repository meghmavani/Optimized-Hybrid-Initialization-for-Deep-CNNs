# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

num_epochs = 50
batch_size = 128
learning_rate = 0.001
run_name = 'CIFAR-10_Orthogonal'

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = torchvision.datasets.CIFAR10(root='../../Final Benchmarks/CIFAR-10/data', train=True, transform=train_transform, download=True)
train_size = int(0.9 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

test_dataset = torchvision.datasets.CIFAR10(root='../../Final Benchmarks/CIFAR-10/data', train=False, transform=test_transform, download=True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            nn.init.orthogonal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)


# 9-layer CNN Model
class NineLayerCNN(nn.Module):
    def __init__(self):
        super(NineLayerCNN, self).__init__()

        # Conv block 1
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)

        # Conv block 2
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)

        # Conv block 3
        self.conv5 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.conv7 = nn.Conv2d(256, 128, kernel_size=3, padding=1)

        # FC layers
        self.fc1 = nn.Linear(128 * 4 * 4, 1024)
        self.fc2 = nn.Linear(1024, 10)


    def forward(self, x):

        # block 1
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)

        # block 2
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2)

        # block 3
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = F.relu(self.conv7(x))
        x = F.max_pool2d(x, 2)

        x = torch.flatten(x, 1)

        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        return x

# Instantiate model, apply custom initialization
model = NineLayerCNN().to(device)
custom_init(model)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss_list.append(val_loss / len(val_loader))
    val_acc_list.append(val_acc)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc:.2f}%')

correct = 0
total = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f'Test Accuracy: {test_acc:.2f}%')

# Save metrics to files labelled with dataset + init method
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(len(train_loss_list)):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Epoch [1/50], Train Loss: 1.7713, Train Acc: 36.34%, Val Loss: 1.4526, Val Acc: 47.62%
# Epoch [2/50], Train Loss: 1.1982, Train Acc: 56.72%, Val Loss: 0.9879, Val Acc: 64.74%
# Epoch [3/50], Train Loss: 0.9160, Train Acc: 67.72%, Val Loss: 0.9205, Val Acc: 67.46%
# Epoch [4/50], Train Loss: 0.7547, Train Acc: 73.40%, Val Loss: 0.7859, Val Acc: 73.06%
# Epoch [5/50], Train Loss: 0.6481, Train Acc: 77.30%, Val Loss: 0.7077, Val Acc: 76.46%
# Epoch [6/50], Train Loss: 0.5898, Train Acc: 79.49%, Val Loss: 0.7334, Val Acc: 77.48%
# Epoch [7/50], Train Loss: 0.5224, Train Acc: 81.88%, Val Loss: 0.6599, Val Acc: 78.48%
# Epoch [8/50], Train Loss: 0.4875, Train Acc: 83.13%, Val Loss: 0.5565, Val Acc: 81.88%
# Epoch [9/50], Train Loss: 0.4520, Train Acc: 84.49%, Val Loss: 0.6097, Val Acc: 80.08%
# Epoch [10/50], Train Loss: 0.4214, Train Acc: 85.33%, Val Loss: 0.5386, Val Acc: 82.80%
# Epoch [11/50], Train Loss: 0.3888, Train Acc: 86.57%, Val Loss: 0.5263, Val Acc: 83.20%
# Epoch [12/50], Train Loss: 0.3629, Train Acc: 87.47%, Val Loss: 0.5444, Val Acc: 83.32%
# Epoch [13/50], Train Loss: 0.3402, Train Acc: 88.36%, Val Loss: 0.5553, Val Acc: 83.04%
# Epoch [14/50], Train Loss: 0.3314, Train Acc: 88.74%, Val Loss: 0.5077, Val Acc: 83.62%
# Epoch [15/50], Train Loss: 0.3144, Train Acc: 89.23%, Val Loss: 0.5361, Val Acc: 83.76%
# Epoch [16/50], Train Loss: 0.2917, Train Acc: 89.87%, Val Loss: 0.4802, Val Acc: 84.96%
# Epoch [17/50], Train Loss: 0.2818, Train Acc: 90.24%, Val Loss: 0.5172, Val Acc: 84.86%
# Epoch [18/50], Train Loss: 0.2751, Train Acc: 90.43%, Val Loss: 0.5004, Val Acc: 84.40%
# Epoch [19/50], Train Loss: 0.2709, Train Acc: 90.58%, Val Loss: 0.5277, Val Acc: 84.50%
# Epoch [20/50], Train Loss: 0.2487, Train Acc: 91.35%, Val Loss: 0.5431, Val Acc: 85.38%
# Epoch [21/50], Train Loss: 0.2465, Train Acc: 91.59%, Val Loss: 0.5604, Val Acc: 84.10%
# Epoch [22/50], Train Loss: 0.2362, Train Acc: 91.95%, Val Loss: 0.5180, Val Acc: 85.52%
# Epoch [23/50], Train Loss: 0.2319, Train Acc: 91.99%, Val Loss: 0.4885, Val Acc: 86.22%
# Epoch [24/50], Train Loss: 0.2243, Train Acc: 92.29%, Val Loss: 0.5514, Val Acc: 85.48%
# Epoch [25/50], Train Loss: 0.2191, Train Acc: 92.52%, Val Loss: 0.5582, Val Acc: 85.56%
# Epoch [26/50], Train Loss: 0.2152, Train Acc: 92.69%, Val Loss: 0.6386, Val Acc: 85.16%
# Epoch [27/50], Train Loss: 0.2000, Train Acc: 93.17%, Val Loss: 0.4904, Val Acc: 85.88%
# Epoch [28/50], Train Loss: 0.1966, Train Acc: 93.40%, Val Loss: 0.4935, Val Acc: 85.64%
# Epoch [29/50], Train Loss: 0.2000, Train Acc: 93.35%, Val Loss: 0.4846, Val Acc: 86.06%
# Epoch [30/50], Train Loss: 0.1907, Train Acc: 93.40%, Val Loss: 0.5393, Val Acc: 85.10%
# Epoch [31/50], Train Loss: 0.1886, Train Acc: 93.62%, Val Loss: 0.5306, Val Acc: 86.42%
# Epoch [32/50], Train Loss: 0.1878, Train Acc: 93.58%, Val Loss: 0.5196, Val Acc: 85.90%
# Epoch [33/50], Train Loss: 0.1785, Train Acc: 93.94%, Val Loss: 0.5512, Val Acc: 85.66%
# Epoch [34/50], Train Loss: 0.1752, Train Acc: 94.15%, Val Loss: 0.5390, Val Acc: 85.96%
# Epoch [35/50], Train Loss: 0.1760, Train Acc: 94.12%, Val Loss: 0.5715, Val Acc: 85.28%
# Epoch [36/50], Train Loss: 0.1688, Train Acc: 94.40%, Val Loss: 0.5688, Val Acc: 85.96%
# Epoch [37/50], Train Loss: 0.1810, Train Acc: 93.88%, Val Loss: 0.5975, Val Acc: 85.40%
# Epoch [38/50], Train Loss: 0.1616, Train Acc: 94.53%, Val Loss: 0.6011, Val Acc: 85.08%
# Epoch [39/50], Train Loss: 0.1616, Train Acc: 94.62%, Val Loss: 0.5503, Val Acc: 86.70%
# Epoch [40/50], Train Loss: 0.1602, Train Acc: 94.62%, Val Loss: 0.5666, Val Acc: 85.68%
# Epoch [41/50], Train Loss: 0.1563, Train Acc: 94.75%, Val Loss: 0.6128, Val Acc: 85.42%
# Epoch [42/50], Train Loss: 0.1527, Train Acc: 94.92%, Val Loss: 0.6300, Val Acc: 85.78%
# Epoch [43/50], Train Loss: 0.1594, Train Acc: 94.68%, Val Loss: 0.5752, Val Acc: 86.64%
# Epoch [44/50], Train Loss: 0.1544, Train Acc: 94.83%, Val Loss: 0.6167, Val Acc: 85.02%
# Epoch [45/50], Train Loss: 0.1514, Train Acc: 94.95%, Val Loss: 0.6203, Val Acc: 86.32%
# Epoch [46/50], Train Loss: 0.1446, Train Acc: 95.07%, Val Loss: 0.6300, Val Acc: 85.82%
# Epoch [47/50], Train Loss: 0.1488, Train Acc: 95.09%, Val Loss: 0.5585, Val Acc: 86.12%
# Epoch [48/50], Train Loss: 0.1414, Train Acc: 95.31%, Val Loss: 0.6000, Val Acc: 85.60%
# Epoch [49/50], Train Loss: 0.1402, Train Acc: 95.35%, Val Loss: 0.6019, Val Acc: 85.70%
# Epoch [50/50], Train Loss: 0.1404, Train Acc: 95.37%, Val Loss: 0.6158, Val Acc: 86.50%
# Test Accuracy: 86.50%
