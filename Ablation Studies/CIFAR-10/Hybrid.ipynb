# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

num_epochs = 50
batch_size = 128
learning_rate = 0.001
run_name = 'CIFAR-10_Hybrid'

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

train_dataset = torchvision.datasets.CIFAR10(root='../../Final Benchmarks/CIFAR-10/data', train=True, transform=train_transform, download=True)
train_size = int(0.9 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [train_size, val_size])

test_dataset = torchvision.datasets.CIFAR10(root='../../Final Benchmarks/CIFAR-10/data', train=False, transform=test_transform, download=True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    layer_idx = 0
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            if layer_idx < 6:
                nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
            else:
                nn.init.orthogonal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
            layer_idx += 1


# 9-layer CNN Model
class NineLayerCNN(nn.Module):
    def __init__(self):
        super(NineLayerCNN, self).__init__()

        # Conv block 1
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)

        # Conv block 2
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)

        # Conv block 3
        self.conv5 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.conv7 = nn.Conv2d(256, 128, kernel_size=3, padding=1)

        # FC layers
        self.fc1 = nn.Linear(128 * 4 * 4, 1024)
        self.fc2 = nn.Linear(1024, 10)


    def forward(self, x):

        # block 1
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)

        # block 2
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2)

        # block 3
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = F.relu(self.conv7(x))
        x = F.max_pool2d(x, 2)

        x = torch.flatten(x, 1)

        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        return x

# Instantiate model, apply custom initialization
model = NineLayerCNN().to(device)
custom_init(model)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss_list.append(val_loss / len(val_loader))
    val_acc_list.append(val_acc)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc:.2f}%')

correct = 0
total = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f'Test Accuracy: {test_acc:.2f}%')

# Save metrics to files labelled with dataset + init method
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(len(train_loss_list)):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Epoch [1/50], Train Loss: 1.8478, Train Acc: 35.83%, Val Loss: 1.3824, Val Acc: 49.20%
# Epoch [2/50], Train Loss: 1.2267, Train Acc: 55.55%, Val Loss: 1.0500, Val Acc: 62.12%
# Epoch [3/50], Train Loss: 0.9536, Train Acc: 65.95%, Val Loss: 0.9007, Val Acc: 67.76%
# Epoch [4/50], Train Loss: 0.7915, Train Acc: 72.06%, Val Loss: 0.7763, Val Acc: 73.14%
# Epoch [5/50], Train Loss: 0.6858, Train Acc: 76.08%, Val Loss: 0.6430, Val Acc: 77.48%
# Epoch [6/50], Train Loss: 0.6100, Train Acc: 78.71%, Val Loss: 0.6538, Val Acc: 77.74%
# Epoch [7/50], Train Loss: 0.5552, Train Acc: 80.72%, Val Loss: 0.6207, Val Acc: 78.24%
# Epoch [8/50], Train Loss: 0.5018, Train Acc: 82.64%, Val Loss: 0.6212, Val Acc: 78.82%
# Epoch [9/50], Train Loss: 0.4642, Train Acc: 83.86%, Val Loss: 0.5643, Val Acc: 80.24%
# Epoch [10/50], Train Loss: 0.4340, Train Acc: 84.95%, Val Loss: 0.5554, Val Acc: 82.20%
# Epoch [11/50], Train Loss: 0.4049, Train Acc: 86.04%, Val Loss: 0.5315, Val Acc: 81.16%
# Epoch [12/50], Train Loss: 0.3776, Train Acc: 87.02%, Val Loss: 0.5567, Val Acc: 81.70%
# Epoch [13/50], Train Loss: 0.3569, Train Acc: 87.70%, Val Loss: 0.5229, Val Acc: 83.00%
# Epoch [14/50], Train Loss: 0.3350, Train Acc: 88.31%, Val Loss: 0.5073, Val Acc: 83.42%
# Epoch [15/50], Train Loss: 0.3237, Train Acc: 88.82%, Val Loss: 0.5075, Val Acc: 84.26%
# Epoch [16/50], Train Loss: 0.3086, Train Acc: 89.43%, Val Loss: 0.4574, Val Acc: 85.08%
# Epoch [17/50], Train Loss: 0.2941, Train Acc: 89.81%, Val Loss: 0.5301, Val Acc: 83.28%
# Epoch [18/50], Train Loss: 0.2874, Train Acc: 90.00%, Val Loss: 0.4881, Val Acc: 84.78%
# Epoch [19/50], Train Loss: 0.2662, Train Acc: 90.90%, Val Loss: 0.4851, Val Acc: 84.36%
# Epoch [20/50], Train Loss: 0.2607, Train Acc: 91.08%, Val Loss: 0.4790, Val Acc: 84.92%
# Epoch [21/50], Train Loss: 0.2532, Train Acc: 91.34%, Val Loss: 0.5107, Val Acc: 84.52%
# Epoch [22/50], Train Loss: 0.2459, Train Acc: 91.52%, Val Loss: 0.4712, Val Acc: 85.26%
# Epoch [23/50], Train Loss: 0.2324, Train Acc: 92.07%, Val Loss: 0.5169, Val Acc: 84.34%
# Epoch [24/50], Train Loss: 0.2342, Train Acc: 91.93%, Val Loss: 0.4751, Val Acc: 85.68%
# Epoch [25/50], Train Loss: 0.2068, Train Acc: 93.04%, Val Loss: 0.5209, Val Acc: 85.12%
# Epoch [26/50], Train Loss: 0.2143, Train Acc: 92.73%, Val Loss: 0.4946, Val Acc: 85.04%
# Epoch [27/50], Train Loss: 0.2089, Train Acc: 93.01%, Val Loss: 0.4903, Val Acc: 85.24%
# Epoch [28/50], Train Loss: 0.2059, Train Acc: 92.97%, Val Loss: 0.4905, Val Acc: 85.58%
# Epoch [29/50], Train Loss: 0.1955, Train Acc: 93.40%, Val Loss: 0.4922, Val Acc: 85.70%
# Epoch [30/50], Train Loss: 0.1910, Train Acc: 93.43%, Val Loss: 0.5240, Val Acc: 85.18%
# Epoch [31/50], Train Loss: 0.1887, Train Acc: 93.65%, Val Loss: 0.5415, Val Acc: 85.06%
# Epoch [32/50], Train Loss: 0.1883, Train Acc: 93.56%, Val Loss: 0.5564, Val Acc: 84.50%
# Epoch [33/50], Train Loss: 0.1853, Train Acc: 93.76%, Val Loss: 0.5156, Val Acc: 85.38%
# Epoch [34/50], Train Loss: 0.1761, Train Acc: 94.10%, Val Loss: 0.4966, Val Acc: 86.22%
# Epoch [35/50], Train Loss: 0.1803, Train Acc: 93.98%, Val Loss: 0.5488, Val Acc: 85.54%
# Epoch [36/50], Train Loss: 0.1705, Train Acc: 94.35%, Val Loss: 0.5109, Val Acc: 86.64%
# Epoch [37/50], Train Loss: 0.1661, Train Acc: 94.28%, Val Loss: 0.5177, Val Acc: 85.74%
# Epoch [38/50], Train Loss: 0.1570, Train Acc: 94.69%, Val Loss: 0.5619, Val Acc: 85.74%
# Epoch [39/50], Train Loss: 0.1692, Train Acc: 94.36%, Val Loss: 0.5241, Val Acc: 85.74%
# Epoch [40/50], Train Loss: 0.1549, Train Acc: 94.82%, Val Loss: 0.5416, Val Acc: 85.22%
# Epoch [41/50], Train Loss: 0.1524, Train Acc: 94.91%, Val Loss: 0.5268, Val Acc: 85.82%
# Epoch [42/50], Train Loss: 0.1551, Train Acc: 94.94%, Val Loss: 0.5246, Val Acc: 86.26%
# Epoch [43/50], Train Loss: 0.1449, Train Acc: 95.11%, Val Loss: 0.5525, Val Acc: 85.58%
# Epoch [44/50], Train Loss: 0.1623, Train Acc: 94.62%, Val Loss: 0.5610, Val Acc: 85.08%
# Epoch [45/50], Train Loss: 0.1532, Train Acc: 94.88%, Val Loss: 0.5396, Val Acc: 86.34%
# Epoch [46/50], Train Loss: 0.1469, Train Acc: 95.17%, Val Loss: 0.5691, Val Acc: 85.92%
# Epoch [47/50], Train Loss: 0.1464, Train Acc: 95.24%, Val Loss: 0.6072, Val Acc: 85.38%
# Epoch [48/50], Train Loss: 0.1503, Train Acc: 95.05%, Val Loss: 0.5384, Val Acc: 86.36%
# Epoch [49/50], Train Loss: 0.1362, Train Acc: 95.51%, Val Loss: 0.5555, Val Acc: 85.76%
# Epoch [50/50], Train Loss: 0.1281, Train Acc: 95.62%, Val Loss: 0.6094, Val Acc: 86.52%
# Test Accuracy: 86.99%
