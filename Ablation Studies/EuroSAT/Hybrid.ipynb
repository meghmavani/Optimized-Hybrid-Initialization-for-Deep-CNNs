# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

num_epochs = 50
batch_size = 128
learning_rate = 0.001
run_name = 'EuroSAT_Hybrid'

train_transform = transforms.Compose([
    transforms.RandomCrop(64, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# EuroSAT has no official split: 80/10/10 train/val/test with a fixed seed
full_train = torchvision.datasets.EuroSAT(root='../../Final Benchmarks/EuroSAT/data', transform=train_transform, download=True)
full_eval = torchvision.datasets.EuroSAT(root='../../Final Benchmarks/EuroSAT/data', transform=test_transform, download=False)

n_total = len(full_train)
n_train = int(0.8 * n_total)
n_val = int(0.1 * n_total)
indices = torch.randperm(n_total, generator=torch.Generator().manual_seed(42)).tolist()

train_dataset = torch.utils.data.Subset(full_train, indices[:n_train])
val_dataset = torch.utils.data.Subset(full_eval, indices[n_train:n_train + n_val])
test_dataset = torch.utils.data.Subset(full_eval, indices[n_train + n_val:])

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    layer_idx = 0
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            if layer_idx < 6:
                nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
            else:
                nn.init.orthogonal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
            layer_idx += 1


# 9-layer CNN Model
class NineLayerCNN(nn.Module):
    def __init__(self):
        super(NineLayerCNN, self).__init__()

        # Conv block 1
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)

        # Conv block 2
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)

        # Conv block 3
        self.conv5 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.conv7 = nn.Conv2d(256, 128, kernel_size=3, padding=1)

        # FC layers
        self.fc1 = nn.Linear(128 * 8 * 8, 1024)
        self.fc2 = nn.Linear(1024, 10)


    def forward(self, x):

        # block 1
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)

        # block 2
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2)

        # block 3
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = F.relu(self.conv7(x))
        x = F.max_pool2d(x, 2)

        x = torch.flatten(x, 1)

        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        return x

# Instantiate model, apply custom initialization
model = NineLayerCNN().to(device)
custom_init(model)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss_list.append(val_loss / len(val_loader))
    val_acc_list.append(val_acc)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc:.2f}%')

correct = 0
total = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f'Test Accuracy: {test_acc:.2f}%')

# Save metrics to files labelled with dataset + init method
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(len(train_loss_list)):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Epoch [1/50], Train Loss: 1.8784, Train Acc: 42.70%, Val Loss: 1.2314, Val Acc: 54.48%
# Epoch [2/50], Train Loss: 0.8659, Train Acc: 68.48%, Val Loss: 0.8586, Val Acc: 68.74%
# Epoch [3/50], Train Loss: 0.7049, Train Acc: 74.88%, Val Loss: 0.7847, Val Acc: 72.19%
# Epoch [4/50], Train Loss: 0.5657, Train Acc: 79.97%, Val Loss: 0.6101, Val Acc: 80.41%
# Epoch [5/50], Train Loss: 0.4480, Train Acc: 84.52%, Val Loss: 0.4575, Val Acc: 84.33%
# Epoch [6/50], Train Loss: 0.3762, Train Acc: 86.82%, Val Loss: 0.4458, Val Acc: 85.00%
# Epoch [7/50], Train Loss: 0.3132, Train Acc: 88.99%, Val Loss: 0.3151, Val Acc: 90.00%
# Epoch [8/50], Train Loss: 0.2676, Train Acc: 90.89%, Val Loss: 0.2711, Val Acc: 91.19%
# Epoch [9/50], Train Loss: 0.2557, Train Acc: 91.28%, Val Loss: 0.2445, Val Acc: 92.07%
# Epoch [10/50], Train Loss: 0.2102, Train Acc: 92.90%, Val Loss: 0.2176, Val Acc: 93.33%
# Epoch [11/50], Train Loss: 0.1855, Train Acc: 93.57%, Val Loss: 0.2749, Val Acc: 90.89%
# Epoch [12/50], Train Loss: 0.1745, Train Acc: 94.16%, Val Loss: 0.2338, Val Acc: 92.26%
# Epoch [13/50], Train Loss: 0.1599, Train Acc: 94.75%, Val Loss: 0.2208, Val Acc: 93.44%
# Epoch [14/50], Train Loss: 0.1448, Train Acc: 94.94%, Val Loss: 0.1817, Val Acc: 94.63%
# Epoch [15/50], Train Loss: 0.1439, Train Acc: 94.99%, Val Loss: 0.2286, Val Acc: 93.41%
# Epoch [16/50], Train Loss: 0.1383, Train Acc: 95.45%, Val Loss: 0.1855, Val Acc: 94.15%
# Epoch [17/50], Train Loss: 0.1232, Train Acc: 95.80%, Val Loss: 0.1675, Val Acc: 95.63%
# Epoch [18/50], Train Loss: 0.1126, Train Acc: 96.20%, Val Loss: 0.1932, Val Acc: 93.89%
# Epoch [19/50], Train Loss: 0.1131, Train Acc: 96.21%, Val Loss: 0.1702, Val Acc: 94.22%
# Epoch [20/50], Train Loss: 0.1049, Train Acc: 96.54%, Val Loss: 0.2349, Val Acc: 93.33%
# Epoch [21/50], Train Loss: 0.1022, Train Acc: 96.48%, Val Loss: 0.1609, Val Acc: 95.00%
# Epoch [22/50], Train Loss: 0.0943, Train Acc: 96.74%, Val Loss: 0.1516, Val Acc: 95.44%
# Epoch [23/50], Train Loss: 0.1015, Train Acc: 96.69%, Val Loss: 0.2320, Val Acc: 93.15%
# Epoch [24/50], Train Loss: 0.0953, Train Acc: 96.81%, Val Loss: 0.2507, Val Acc: 92.59%
# Epoch [25/50], Train Loss: 0.1089, Train Acc: 96.41%, Val Loss: 0.1632, Val Acc: 95.26%
# Epoch [26/50], Train Loss: 0.0908, Train Acc: 97.10%, Val Loss: 0.1809, Val Acc: 94.81%
# Epoch [27/50], Train Loss: 0.0778, Train Acc: 97.35%, Val Loss: 0.1533, Val Acc: 95.59%
# Epoch [28/50], Train Loss: 0.0754, Train Acc: 97.36%, Val Loss: 0.1793, Val Acc: 94.96%
# Epoch [29/50], Train Loss: 0.0808, Train Acc: 97.27%, Val Loss: 0.1938, Val Acc: 95.04%
# Epoch [30/50], Train Loss: 0.0739, Train Acc: 97.50%, Val Loss: 0.2006, Val Acc: 94.59%
# Epoch [31/50], Train Loss: 0.0671, Train Acc: 97.86%, Val Loss: 0.1596, Val Acc: 94.56%
# Epoch [32/50], Train Loss: 0.0830, Train Acc: 97.11%, Val Loss: 0.1825, Val Acc: 95.26%
# Epoch [33/50], Train Loss: 0.0745, Train Acc: 97.53%, Val Loss: 0.1697, Val Acc: 95.26%
# Epoch [34/50], Train Loss: 0.0646, Train Acc: 97.85%, Val Loss: 0.1490, Val Acc: 96.33%
# Epoch [35/50], Train Loss: 0.0672, Train Acc: 97.70%, Val Loss: 0.1721, Val Acc: 95.67%
# Epoch [36/50], Train Loss: 0.0766, Train Acc: 97.47%, Val Loss: 0.1549, Val Acc: 95.44%
# Epoch [37/50], Train Loss: 0.0599, Train Acc: 97.94%, Val Loss: 0.2016, Val Acc: 95.67%
# Epoch [38/50], Train Loss: 0.0562, Train Acc: 98.21%, Val Loss: 0.1819, Val Acc: 95.07%
# Epoch [39/50], Train Loss: 0.0615, Train Acc: 98.00%, Val Loss: 0.1664, Val Acc: 94.70%
# Epoch [40/50], Train Loss: 0.0672, Train Acc: 97.89%, Val Loss: 0.1623, Val Acc: 95.56%
# Epoch [41/50], Train Loss: 0.0625, Train Acc: 97.96%, Val Loss: 0.1909, Val Acc: 95.48%
# Epoch [42/50], Train Loss: 0.0635, Train Acc: 97.89%, Val Loss: 0.1751, Val Acc: 95.41%
# Epoch [43/50], Train Loss: 0.0491, Train Acc: 98.32%, Val Loss: 0.1476, Val Acc: 96.26%
# Epoch [44/50], Train Loss: 0.0489, Train Acc: 98.41%, Val Loss: 0.1479, Val Acc: 96.07%
# Epoch [45/50], Train Loss: 0.0556, Train Acc: 98.15%, Val Loss: 0.2072, Val Acc: 94.22%
# Epoch [46/50], Train Loss: 0.0577, Train Acc: 98.14%, Val Loss: 0.1839, Val Acc: 95.59%
# Epoch [47/50], Train Loss: 0.0524, Train Acc: 98.19%, Val Loss: 0.1811, Val Acc: 95.26%
# Epoch [48/50], Train Loss: 0.0516, Train Acc: 98.15%, Val Loss: 0.1608, Val Acc: 95.89%
# Epoch [49/50], Train Loss: 0.0545, Train Acc: 98.34%, Val Loss: 0.1925, Val Acc: 95.22%
# Epoch [50/50], Train Loss: 0.0605, Train Acc: 98.09%, Val Loss: 0.2026, Val Acc: 95.63%
# Test Accuracy: 94.81%
