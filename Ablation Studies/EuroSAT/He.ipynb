# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

num_epochs = 50
batch_size = 128
learning_rate = 0.001
run_name = 'EuroSAT_He'

train_transform = transforms.Compose([
    transforms.RandomCrop(64, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# EuroSAT has no official split: 80/10/10 train/val/test with a fixed seed
full_train = torchvision.datasets.EuroSAT(root='../../Final Benchmarks/EuroSAT/data', transform=train_transform, download=True)
full_eval = torchvision.datasets.EuroSAT(root='../../Final Benchmarks/EuroSAT/data', transform=test_transform, download=False)

n_total = len(full_train)
n_train = int(0.8 * n_total)
n_val = int(0.1 * n_total)
indices = torch.randperm(n_total, generator=torch.Generator().manual_seed(42)).tolist()

train_dataset = torch.utils.data.Subset(full_train, indices[:n_train])
val_dataset = torch.utils.data.Subset(full_eval, indices[n_train:n_train + n_val])
test_dataset = torch.utils.data.Subset(full_eval, indices[n_train + n_val:])

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

def custom_init(model):
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)


# 9-layer CNN Model
class NineLayerCNN(nn.Module):
    def __init__(self):
        super(NineLayerCNN, self).__init__()

        # Conv block 1
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)

        # Conv block 2
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)

        # Conv block 3
        self.conv5 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.conv7 = nn.Conv2d(256, 128, kernel_size=3, padding=1)

        # FC layers
        self.fc1 = nn.Linear(128 * 8 * 8, 1024)
        self.fc2 = nn.Linear(1024, 10)


    def forward(self, x):

        # block 1
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)

        # block 2
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2)

        # block 3
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = F.relu(self.conv7(x))
        x = F.max_pool2d(x, 2)

        x = torch.flatten(x, 1)

        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        return x

# Instantiate model, apply custom initialization
model = NineLayerCNN().to(device)
custom_init(model)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss_list.append(val_loss / len(val_loader))
    val_acc_list.append(val_acc)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc:.2f}%')

correct = 0
total = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f'Test Accuracy: {test_acc:.2f}%')

# Save metrics to files labelled with dataset + init method
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(len(train_loss_list)):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Epoch [1/50], Train Loss: 1.8602, Train Acc: 45.43%, Val Loss: 1.0723, Val Acc: 61.30%
# Epoch [2/50], Train Loss: 0.7735, Train Acc: 72.72%, Val Loss: 0.7362, Val Acc: 72.26%
# Epoch [3/50], Train Loss: 0.6225, Train Acc: 78.16%, Val Loss: 0.6944, Val Acc: 76.37%
# Epoch [4/50], Train Loss: 0.5133, Train Acc: 82.29%, Val Loss: 0.5371, Val Acc: 80.81%
# Epoch [5/50], Train Loss: 0.4148, Train Acc: 85.81%, Val Loss: 0.4031, Val Acc: 86.93%
# Epoch [6/50], Train Loss: 0.3479, Train Acc: 88.07%, Val Loss: 0.3671, Val Acc: 87.00%
# Epoch [7/50], Train Loss: 0.3157, Train Acc: 89.18%, Val Loss: 0.3003, Val Acc: 89.96%
# Epoch [8/50], Train Loss: 0.2594, Train Acc: 90.83%, Val Loss: 0.2397, Val Acc: 92.04%
# Epoch [9/50], Train Loss: 0.2287, Train Acc: 92.29%, Val Loss: 0.2448, Val Acc: 91.74%
# Epoch [10/50], Train Loss: 0.1963, Train Acc: 93.23%, Val Loss: 0.2753, Val Acc: 91.04%
# Epoch [11/50], Train Loss: 0.1756, Train Acc: 94.12%, Val Loss: 0.1640, Val Acc: 94.37%
# Epoch [12/50], Train Loss: 0.1682, Train Acc: 94.01%, Val Loss: 0.2256, Val Acc: 92.04%
# Epoch [13/50], Train Loss: 0.1549, Train Acc: 94.66%, Val Loss: 0.1904, Val Acc: 93.70%
# Epoch [14/50], Train Loss: 0.1490, Train Acc: 94.92%, Val Loss: 0.1939, Val Acc: 93.67%
# Epoch [15/50], Train Loss: 0.1268, Train Acc: 95.74%, Val Loss: 0.1608, Val Acc: 94.93%
# Epoch [16/50], Train Loss: 0.1232, Train Acc: 95.83%, Val Loss: 0.1470, Val Acc: 95.33%
# Epoch [17/50], Train Loss: 0.1210, Train Acc: 95.88%, Val Loss: 0.1777, Val Acc: 94.04%
# Epoch [18/50], Train Loss: 0.1093, Train Acc: 96.29%, Val Loss: 0.1931, Val Acc: 94.11%
# Epoch [19/50], Train Loss: 0.1065, Train Acc: 96.28%, Val Loss: 0.1432, Val Acc: 95.11%
# Epoch [20/50], Train Loss: 0.0963, Train Acc: 96.70%, Val Loss: 0.1472, Val Acc: 95.44%
# Epoch [21/50], Train Loss: 0.1095, Train Acc: 96.18%, Val Loss: 0.1890, Val Acc: 94.22%
# Epoch [22/50], Train Loss: 0.0946, Train Acc: 96.92%, Val Loss: 0.1930, Val Acc: 94.93%
# Epoch [23/50], Train Loss: 0.0910, Train Acc: 96.95%, Val Loss: 0.1274, Val Acc: 95.70%
# Epoch [24/50], Train Loss: 0.0927, Train Acc: 96.82%, Val Loss: 0.2397, Val Acc: 94.00%
# Epoch [25/50], Train Loss: 0.0915, Train Acc: 96.98%, Val Loss: 0.1759, Val Acc: 94.74%
# Epoch [26/50], Train Loss: 0.0772, Train Acc: 97.36%, Val Loss: 0.1767, Val Acc: 94.74%
# Epoch [27/50], Train Loss: 0.0726, Train Acc: 97.63%, Val Loss: 0.1650, Val Acc: 94.85%
# Epoch [28/50], Train Loss: 0.0898, Train Acc: 97.15%, Val Loss: 0.1488, Val Acc: 95.41%
# Epoch [29/50], Train Loss: 0.0789, Train Acc: 97.39%, Val Loss: 0.1559, Val Acc: 95.07%
# Epoch [30/50], Train Loss: 0.0763, Train Acc: 97.39%, Val Loss: 0.1536, Val Acc: 95.11%
# Epoch [31/50], Train Loss: 0.0797, Train Acc: 97.44%, Val Loss: 0.1512, Val Acc: 95.37%
# Epoch [32/50], Train Loss: 0.0725, Train Acc: 97.70%, Val Loss: 0.1855, Val Acc: 94.78%
# Epoch [33/50], Train Loss: 0.0773, Train Acc: 97.38%, Val Loss: 0.1594, Val Acc: 95.56%
# Epoch [34/50], Train Loss: 0.0632, Train Acc: 97.87%, Val Loss: 0.1619, Val Acc: 95.00%
# Epoch [35/50], Train Loss: 0.0696, Train Acc: 97.81%, Val Loss: 0.2069, Val Acc: 93.85%
# Epoch [36/50], Train Loss: 0.0815, Train Acc: 97.36%, Val Loss: 0.1694, Val Acc: 95.70%
# Epoch [37/50], Train Loss: 0.0522, Train Acc: 98.24%, Val Loss: 0.1542, Val Acc: 95.81%
# Epoch [38/50], Train Loss: 0.0630, Train Acc: 98.00%, Val Loss: 0.1311, Val Acc: 96.07%
# Epoch [39/50], Train Loss: 0.0581, Train Acc: 98.08%, Val Loss: 0.1370, Val Acc: 95.56%
# Epoch [40/50], Train Loss: 0.0741, Train Acc: 97.66%, Val Loss: 0.2284, Val Acc: 92.67%
# Epoch [41/50], Train Loss: 0.0592, Train Acc: 98.00%, Val Loss: 0.1836, Val Acc: 95.30%
# Epoch [42/50], Train Loss: 0.0560, Train Acc: 98.12%, Val Loss: 0.2988, Val Acc: 92.89%
# Epoch [43/50], Train Loss: 0.0578, Train Acc: 98.08%, Val Loss: 0.2066, Val Acc: 95.30%
# Epoch [44/50], Train Loss: 0.0597, Train Acc: 98.15%, Val Loss: 0.1910, Val Acc: 95.41%
# Epoch [45/50], Train Loss: 0.0451, Train Acc: 98.53%, Val Loss: 0.1963, Val Acc: 95.04%
# Epoch [46/50], Train Loss: 0.0502, Train Acc: 98.38%, Val Loss: 0.1887, Val Acc: 95.52%
# Epoch [47/50], Train Loss: 0.0416, Train Acc: 98.74%, Val Loss: 0.1871, Val Acc: 96.07%
# Epoch [48/50], Train Loss: 0.0505, Train Acc: 98.29%, Val Loss: 0.1396, Val Acc: 96.30%
# Epoch [49/50], Train Loss: 0.0567, Train Acc: 98.15%, Val Loss: 0.1821, Val Acc: 95.19%
# Epoch [50/50], Train Loss: 0.0573, Train Acc: 98.27%, Val Loss: 0.1779, Val Acc: 95.41%
# Test Accuracy: 94.74%
