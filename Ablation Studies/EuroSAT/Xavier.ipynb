# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import time

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

num_epochs = 50
batch_size = 128
learning_rate = 0.001
run_name = 'EuroSAT_Xavier'

train_transform = transforms.Compose([
    transforms.RandomCrop(64, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# EuroSAT has no official split: 80/10/10 train/val/test with a fixed seed
full_train = torchvision.datasets.EuroSAT(root='../../Final Benchmarks/EuroSAT/data', transform=train_transform, download=True)
full_eval = torchvision.datasets.EuroSAT(root='../../Final Benchmarks/EuroSAT/data', transform=test_transform, download=False)

n_total = len(full_train)
n_train = int(0.8 * n_total)
n_val = int(0.1 * n_total)
indices = torch.randperm(n_total, generator=torch.Generator().manual_seed(42)).tolist()

train_dataset = torch.utils.data.Subset(full_train, indices[:n_train])
val_dataset = torch.utils.data.Subset(full_eval, indices[n_train:n_train + n_val])
test_dataset = torch.utils.data.Subset(full_eval, indices[n_train + n_val:])

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            nn.init.xavier_normal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)


# 9-layer CNN Model
class NineLayerCNN(nn.Module):
    def __init__(self):
        super(NineLayerCNN, self).__init__()

        # Conv block 1
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)

        # Conv block 2
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)

        # Conv block 3
        self.conv5 = nn.Conv2d(512, 512, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(512, 256, kernel_size=3, padding=1)
        self.conv7 = nn.Conv2d(256, 128, kernel_size=3, padding=1)

        # FC layers
        self.fc1 = nn.Linear(128 * 8 * 8, 1024)
        self.fc2 = nn.Linear(1024, 10)


    def forward(self, x):

        # block 1
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)

        # block 2
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2)

        # block 3
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = F.relu(self.conv7(x))
        x = F.max_pool2d(x, 2)

        x = torch.flatten(x, 1)

        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        return x

# Instantiate model, apply custom initialization
model = NineLayerCNN().to(device)
custom_init(model)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

train_loss_list = []
train_acc_list = []
val_loss_list = []
val_acc_list = []

# Training loop
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct / total
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()

    val_acc = 100 * val_correct / val_total
    val_loss_list.append(val_loss / len(val_loader))
    val_acc_list.append(val_acc)

    print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_loss_list[-1]:.4f}, Train Acc: {train_acc:.2f}%, Val Loss: {val_loss_list[-1]:.4f}, Val Acc: {val_acc:.2f}%')

correct = 0
total = 0
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_acc = 100 * correct / total
print(f'Test Accuracy: {test_acc:.2f}%')

# Save metrics to files labelled with dataset + init method
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(len(train_loss_list)):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Epoch [1/50], Train Loss: 1.4139, Train Acc: 48.73%, Val Loss: 0.9502, Val Acc: 65.56%
# Epoch [2/50], Train Loss: 0.7765, Train Acc: 72.35%, Val Loss: 0.8681, Val Acc: 71.74%
# Epoch [3/50], Train Loss: 0.6063, Train Acc: 78.70%, Val Loss: 0.5863, Val Acc: 79.00%
# Epoch [4/50], Train Loss: 0.5216, Train Acc: 81.99%, Val Loss: 0.4686, Val Acc: 84.15%
# Epoch [5/50], Train Loss: 0.4223, Train Acc: 85.56%, Val Loss: 0.4010, Val Acc: 86.44%
# Epoch [6/50], Train Loss: 0.3389, Train Acc: 88.61%, Val Loss: 0.3453, Val Acc: 89.33%
# Epoch [7/50], Train Loss: 0.2789, Train Acc: 90.58%, Val Loss: 0.3737, Val Acc: 87.93%
# Epoch [8/50], Train Loss: 0.2382, Train Acc: 91.83%, Val Loss: 0.2498, Val Acc: 92.04%
# Epoch [9/50], Train Loss: 0.2165, Train Acc: 92.49%, Val Loss: 0.2645, Val Acc: 91.67%
# Epoch [10/50], Train Loss: 0.1926, Train Acc: 93.50%, Val Loss: 0.2382, Val Acc: 92.11%
# Epoch [11/50], Train Loss: 0.1752, Train Acc: 94.14%, Val Loss: 0.2386, Val Acc: 92.48%
# Epoch [12/50], Train Loss: 0.1638, Train Acc: 94.47%, Val Loss: 0.1656, Val Acc: 94.63%
# Epoch [13/50], Train Loss: 0.1593, Train Acc: 94.67%, Val Loss: 0.2053, Val Acc: 93.48%
# Epoch [14/50], Train Loss: 0.1447, Train Acc: 95.09%, Val Loss: 0.1630, Val Acc: 94.78%
# Epoch [15/50], Train Loss: 0.1266, Train Acc: 95.72%, Val Loss: 0.1617, Val Acc: 94.96%
# Epoch [16/50], Train Loss: 0.1194, Train Acc: 96.03%, Val Loss: 0.1856, Val Acc: 93.93%
# Epoch [17/50], Train Loss: 0.1156, Train Acc: 95.93%, Val Loss: 0.1611, Val Acc: 94.93%
# Epoch [18/50], Train Loss: 0.1116, Train Acc: 96.29%, Val Loss: 0.1713, Val Acc: 95.19%
# Epoch [19/50], Train Loss: 0.1131, Train Acc: 96.24%, Val Loss: 0.1886, Val Acc: 93.93%
# Epoch [20/50], Train Loss: 0.1166, Train Acc: 96.12%, Val Loss: 0.2195, Val Acc: 93.56%
# Epoch [21/50], Train Loss: 0.0994, Train Acc: 96.61%, Val Loss: 0.1715, Val Acc: 95.30%
# Epoch [22/50], Train Loss: 0.0985, Train Acc: 96.71%, Val Loss: 0.1663, Val Acc: 94.81%
# Epoch [23/50], Train Loss: 0.0885, Train Acc: 97.04%, Val Loss: 0.1951, Val Acc: 94.48%
# Epoch [24/50], Train Loss: 0.0915, Train Acc: 96.85%, Val Loss: 0.1990, Val Acc: 94.22%
# Epoch [25/50], Train Loss: 0.0971, Train Acc: 96.84%, Val Loss: 0.1774, Val Acc: 94.70%
# Epoch [26/50], Train Loss: 0.1024, Train Acc: 96.49%, Val Loss: 0.1783, Val Acc: 94.63%
# Epoch [27/50], Train Loss: 0.0936, Train Acc: 96.89%, Val Loss: 0.2464, Val Acc: 92.78%
# Epoch [28/50], Train Loss: 0.0826, Train Acc: 97.13%, Val Loss: 0.1495, Val Acc: 95.59%
# Epoch [29/50], Train Loss: 0.0784, Train Acc: 97.26%, Val Loss: 0.1576, Val Acc: 95.22%
# Epoch [30/50], Train Loss: 0.0787, Train Acc: 97.34%, Val Loss: 0.1436, Val Acc: 95.67%
# Epoch [31/50], Train Loss: 0.0811, Train Acc: 97.28%, Val Loss: 0.1745, Val Acc: 95.41%
# Epoch [32/50], Train Loss: 0.0751, Train Acc: 97.55%, Val Loss: 0.1687, Val Acc: 95.33%
# Epoch [33/50], Train Loss: 0.0750, Train Acc: 97.44%, Val Loss: 0.1447, Val Acc: 96.00%
# Epoch [34/50], Train Loss: 0.0669, Train Acc: 97.81%, Val Loss: 0.1722, Val Acc: 94.85%
# Epoch [35/50], Train Loss: 0.0578, Train Acc: 97.98%, Val Loss: 0.1837, Val Acc: 95.15%
# Epoch [36/50], Train Loss: 0.0681, Train Acc: 97.77%, Val Loss: 0.2247, Val Acc: 94.48%
# Epoch [37/50], Train Loss: 0.0644, Train Acc: 97.77%, Val Loss: 0.1688, Val Acc: 95.78%
# Epoch [38/50], Train Loss: 0.0631, Train Acc: 97.91%, Val Loss: 0.2056, Val Acc: 94.70%
# Epoch [39/50], Train Loss: 0.0670, Train Acc: 97.75%, Val Loss: 0.1619, Val Acc: 95.63%
# Epoch [40/50], Train Loss: 0.0575, Train Acc: 98.12%, Val Loss: 0.1488, Val Acc: 95.78%
# Epoch [41/50], Train Loss: 0.0699, Train Acc: 97.80%, Val Loss: 0.2225, Val Acc: 94.04%
# Epoch [42/50], Train Loss: 0.0685, Train Acc: 97.85%, Val Loss: 0.2049, Val Acc: 94.22%
# Epoch [43/50], Train Loss: 0.0729, Train Acc: 97.63%, Val Loss: 0.1878, Val Acc: 95.56%
# Epoch [44/50], Train Loss: 0.0629, Train Acc: 97.93%, Val Loss: 0.1677, Val Acc: 96.15%
# Epoch [45/50], Train Loss: 0.0575, Train Acc: 98.11%, Val Loss: 0.1740, Val Acc: 95.67%
# Epoch [46/50], Train Loss: 0.0528, Train Acc: 98.27%, Val Loss: 0.2117, Val Acc: 95.15%
# Epoch [47/50], Train Loss: 0.0555, Train Acc: 98.08%, Val Loss: 0.1891, Val Acc: 95.26%
# Epoch [48/50], Train Loss: 0.0580, Train Acc: 98.15%, Val Loss: 0.1905, Val Acc: 95.41%
# Epoch [49/50], Train Loss: 0.0474, Train Acc: 98.45%, Val Loss: 0.1637, Val Acc: 96.22%
# Epoch [50/50], Train Loss: 0.0594, Train Acc: 98.07%, Val Loss: 0.1803, Val Acc: 95.67%
# Test Accuracy: 94.63%
