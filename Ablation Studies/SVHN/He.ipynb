# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, random_split
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

run_name = 'SVHN_He'
epochs = 50
batch_size = 128
learning_rate = 0.001

transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

full_train_data = datasets.SVHN(root='../../Final Benchmarks/SVHN/data', split='train', download=True, transform=transform)
test_data = datasets.SVHN(root='../../Final Benchmarks/SVHN/data', split='test', download=True, transform=transform)
train_size = int(0.9 * len(full_train_data))
val_size = len(full_train_data) - train_size
train_data, val_data = random_split(full_train_data, [train_size, val_size])

train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)

def custom_init(model):
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)


# Same 9-layer CNN
class CustomCNN(nn.Module):
    def __init__(self):
        super(CustomCNN, self).__init__()
        self.layers = nn.Sequential(
            nn.Conv2d(3, 64, 3, padding=1), nn.ReLU(),
            nn.Conv2d(64, 64, 3, padding=1), nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, 3, padding=1), nn.ReLU(),
            nn.Conv2d(128, 128, 3, padding=1), nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(128, 256, 3, padding=1), nn.ReLU(),
            nn.Conv2d(256, 256, 3, padding=1), nn.ReLU(),
            nn.AdaptiveAvgPool2d((4, 4))
        )

        self.fc = nn.Sequential(
            nn.Linear(256 * 4 * 4, 512), nn.ReLU(),
            nn.Linear(512, 10)
        )

    def forward(self, x):
        x = self.layers(x)
        x = torch.flatten(x, 1)
        x = self.fc(x)
        return x

model = CustomCNN().to(device)
custom_init(model)

optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.CrossEntropyLoss()
train_loss_list, train_acc_list = [], []
val_loss_list, val_acc_list = [], []

for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    correct_train, total_train = 0, 0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct_train / total_train
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    running_val_loss = 0.0
    correct_val, total_val = 0, 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    val_loss = running_val_loss / len(val_loader)
    val_acc = 100 * correct_val / total_val
    val_loss_list.append(val_loss)
    val_acc_list.append(val_acc)

    print(
        f"Epoch {epoch+1} | Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | "
        f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.2f}%"
    )

correct_test, total_test = 0, 0
model.eval()
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total_test += labels.size(0)
        correct_test += (predicted == labels).sum().item()

test_acc = 100 * correct_test / total_test
print(f"Test Accuracy: {test_acc:.2f}%")

# Save metrics to files labelled with dataset + init method
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(len(train_loss_list)):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Epoch 1 | Train Loss: 0.8984 | Train Acc: 70.11% | Val Loss: 0.3546 | Val Acc: 89.35%
# Epoch 2 | Train Loss: 0.2876 | Train Acc: 91.51% | Val Loss: 0.2823 | Val Acc: 92.07%
# Epoch 3 | Train Loss: 0.2130 | Train Acc: 93.78% | Val Loss: 0.2472 | Val Acc: 92.97%
# Epoch 4 | Train Loss: 0.1663 | Train Acc: 95.19% | Val Loss: 0.2937 | Val Acc: 92.22%
# Epoch 5 | Train Loss: 0.1288 | Train Acc: 96.27% | Val Loss: 0.2657 | Val Acc: 93.16%
# Epoch 6 | Train Loss: 0.0964 | Train Acc: 97.11% | Val Loss: 0.2766 | Val Acc: 92.94%
# Epoch 7 | Train Loss: 0.0726 | Train Acc: 97.69% | Val Loss: 0.2935 | Val Acc: 92.82%
# Epoch 8 | Train Loss: 0.0603 | Train Acc: 98.09% | Val Loss: 0.3471 | Val Acc: 92.85%
# Epoch 9 | Train Loss: 0.0538 | Train Acc: 98.23% | Val Loss: 0.3406 | Val Acc: 92.81%
# Epoch 10 | Train Loss: 0.0414 | Train Acc: 98.67% | Val Loss: 0.3975 | Val Acc: 91.88%
# Epoch 11 | Train Loss: 0.0437 | Train Acc: 98.58% | Val Loss: 0.4456 | Val Acc: 92.47%
# Epoch 12 | Train Loss: 0.0320 | Train Acc: 98.98% | Val Loss: 0.4101 | Val Acc: 93.13%
# Epoch 13 | Train Loss: 0.0308 | Train Acc: 99.01% | Val Loss: 0.4417 | Val Acc: 92.97%
# Epoch 14 | Train Loss: 0.0322 | Train Acc: 99.00% | Val Loss: 0.4877 | Val Acc: 92.89%
# Epoch 15 | Train Loss: 0.0299 | Train Acc: 99.07% | Val Loss: 0.5049 | Val Acc: 92.89%
# Epoch 16 | Train Loss: 0.0296 | Train Acc: 99.12% | Val Loss: 0.4133 | Val Acc: 92.78%
# Epoch 17 | Train Loss: 0.0273 | Train Acc: 99.21% | Val Loss: 0.4716 | Val Acc: 92.85%
# Epoch 18 | Train Loss: 0.0278 | Train Acc: 99.19% | Val Loss: 0.4870 | Val Acc: 93.08%
# Epoch 19 | Train Loss: 0.0220 | Train Acc: 99.29% | Val Loss: 0.4688 | Val Acc: 92.71%
# Epoch 20 | Train Loss: 0.0246 | Train Acc: 99.29% | Val Loss: 0.5306 | Val Acc: 92.27%
# Epoch 21 | Train Loss: 0.0248 | Train Acc: 99.22% | Val Loss: 0.5905 | Val Acc: 92.47%
# Epoch 22 | Train Loss: 0.0252 | Train Acc: 99.26% | Val Loss: 0.5323 | Val Acc: 92.92%
# Epoch 23 | Train Loss: 0.0182 | Train Acc: 99.46% | Val Loss: 0.5402 | Val Acc: 92.79%
# Epoch 24 | Train Loss: 0.0247 | Train Acc: 99.25% | Val Loss: 0.5237 | Val Acc: 92.94%
# Epoch 25 | Train Loss: 0.0165 | Train Acc: 99.51% | Val Loss: 0.5579 | Val Acc: 92.55%
# Epoch 26 | Train Loss: 0.0208 | Train Acc: 99.34% | Val Loss: 0.5480 | Val Acc: 92.79%
# Epoch 27 | Train Loss: 0.0241 | Train Acc: 99.30% | Val Loss: 0.5087 | Val Acc: 93.34%
# Epoch 28 | Train Loss: 0.0176 | Train Acc: 99.46% | Val Loss: 0.6635 | Val Acc: 92.59%
# Epoch 29 | Train Loss: 0.0232 | Train Acc: 99.29% | Val Loss: 0.5523 | Val Acc: 92.85%
# Epoch 30 | Train Loss: 0.0145 | Train Acc: 99.58% | Val Loss: 0.6032 | Val Acc: 93.20%
# Epoch 31 | Train Loss: 0.0190 | Train Acc: 99.47% | Val Loss: 0.5461 | Val Acc: 92.42%
# Epoch 32 | Train Loss: 0.0204 | Train Acc: 99.38% | Val Loss: 0.5889 | Val Acc: 92.92%
# Epoch 33 | Train Loss: 0.0187 | Train Acc: 99.46% | Val Loss: 0.6920 | Val Acc: 92.49%
# Epoch 34 | Train Loss: 0.0227 | Train Acc: 99.38% | Val Loss: 0.5925 | Val Acc: 93.08%
# Epoch 35 | Train Loss: 0.0202 | Train Acc: 99.48% | Val Loss: 0.5984 | Val Acc: 92.85%
# Epoch 36 | Train Loss: 0.0147 | Train Acc: 99.60% | Val Loss: 0.6349 | Val Acc: 92.94%
# Epoch 37 | Train Loss: 0.0130 | Train Acc: 99.62% | Val Loss: 0.6446 | Val Acc: 92.62%
# Epoch 38 | Train Loss: 0.0179 | Train Acc: 99.48% | Val Loss: 0.6726 | Val Acc: 93.04%
# Epoch 39 | Train Loss: 0.0213 | Train Acc: 99.38% | Val Loss: 0.6988 | Val Acc: 92.47%
# Epoch 40 | Train Loss: 0.0164 | Train Acc: 99.55% | Val Loss: 0.5978 | Val Acc: 93.20%
# Epoch 41 | Train Loss: 0.0098 | Train Acc: 99.70% | Val Loss: 0.6818 | Val Acc: 93.11%
# Epoch 42 | Train Loss: 0.0159 | Train Acc: 99.56% | Val Loss: 0.6605 | Val Acc: 92.75%
# Epoch 43 | Train Loss: 0.0216 | Train Acc: 99.41% | Val Loss: 0.7191 | Val Acc: 92.67%
# Epoch 44 | Train Loss: 0.0161 | Train Acc: 99.53% | Val Loss: 0.7168 | Val Acc: 92.89%
# Epoch 45 | Train Loss: 0.0167 | Train Acc: 99.53% | Val Loss: 0.7764 | Val Acc: 92.72%
# Epoch 46 | Train Loss: 0.0128 | Train Acc: 99.63% | Val Loss: 0.7518 | Val Acc: 92.92%
# Epoch 47 | Train Loss: 0.0207 | Train Acc: 99.45% | Val Loss: 0.7791 | Val Acc: 93.33%
# Epoch 48 | Train Loss: 0.0130 | Train Acc: 99.65% | Val Loss: 0.6462 | Val Acc: 92.83%
# Epoch 49 | Train Loss: 0.0182 | Train Acc: 99.52% | Val Loss: 0.7245 | Val Acc: 92.63%
# Epoch 50 | Train Loss: 0.0121 | Train Acc: 99.63% | Val Loss: 0.7506 | Val Acc: 93.17%
# Test Accuracy: 93.36%
