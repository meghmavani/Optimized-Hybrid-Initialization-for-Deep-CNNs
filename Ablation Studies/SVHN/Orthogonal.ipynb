# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, random_split
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

run_name = 'SVHN_Orthogonal'
epochs = 50
batch_size = 128
learning_rate = 0.001

transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

full_train_data = datasets.SVHN(root='../../Final Benchmarks/SVHN/data', split='train', download=True, transform=transform)
test_data = datasets.SVHN(root='../../Final Benchmarks/SVHN/data', split='test', download=True, transform=transform)
train_size = int(0.9 * len(full_train_data))
val_size = len(full_train_data) - train_size
train_data, val_data = random_split(full_train_data, [train_size, val_size])

train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)

def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            nn.init.orthogonal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)


# Same 9-layer CNN
class CustomCNN(nn.Module):
    def __init__(self):
        super(CustomCNN, self).__init__()
        self.layers = nn.Sequential(
            nn.Conv2d(3, 64, 3, padding=1), nn.ReLU(),
            nn.Conv2d(64, 64, 3, padding=1), nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, 3, padding=1), nn.ReLU(),
            nn.Conv2d(128, 128, 3, padding=1), nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(128, 256, 3, padding=1), nn.ReLU(),
            nn.Conv2d(256, 256, 3, padding=1), nn.ReLU(),
            nn.AdaptiveAvgPool2d((4, 4))
        )

        self.fc = nn.Sequential(
            nn.Linear(256 * 4 * 4, 512), nn.ReLU(),
            nn.Linear(512, 10)
        )

    def forward(self, x):
        x = self.layers(x)
        x = torch.flatten(x, 1)
        x = self.fc(x)
        return x

model = CustomCNN().to(device)
custom_init(model)

optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.CrossEntropyLoss()
train_loss_list, train_acc_list = [], []
val_loss_list, val_acc_list = [], []

for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    correct_train, total_train = 0, 0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct_train / total_train
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    running_val_loss = 0.0
    correct_val, total_val = 0, 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    val_loss = running_val_loss / len(val_loader)
    val_acc = 100 * correct_val / total_val
    val_loss_list.append(val_loss)
    val_acc_list.append(val_acc)

    print(
        f"Epoch {epoch+1} | Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | "
        f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.2f}%"
    )

correct_test, total_test = 0, 0
model.eval()
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total_test += labels.size(0)
        correct_test += (predicted == labels).sum().item()

test_acc = 100 * correct_test / total_test
print(f"Test Accuracy: {test_acc:.2f}%")

# Save metrics to files labelled with dataset + init method
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(len(train_loss_list)):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Epoch 1 | Train Loss: 0.9594 | Train Acc: 67.90% | Val Loss: 0.3728 | Val Acc: 88.63%
# Epoch 2 | Train Loss: 0.2883 | Train Acc: 91.44% | Val Loss: 0.2688 | Val Acc: 91.86%
# Epoch 3 | Train Loss: 0.2133 | Train Acc: 93.86% | Val Loss: 0.2616 | Val Acc: 93.33%
# Epoch 4 | Train Loss: 0.1665 | Train Acc: 95.25% | Val Loss: 0.2604 | Val Acc: 93.37%
# Epoch 5 | Train Loss: 0.1339 | Train Acc: 96.11% | Val Loss: 0.2288 | Val Acc: 93.63%
# Epoch 6 | Train Loss: 0.0984 | Train Acc: 97.01% | Val Loss: 0.2656 | Val Acc: 93.67%
# Epoch 7 | Train Loss: 0.0789 | Train Acc: 97.50% | Val Loss: 0.2671 | Val Acc: 93.60%
# Epoch 8 | Train Loss: 0.0605 | Train Acc: 98.08% | Val Loss: 0.3290 | Val Acc: 93.27%
# Epoch 9 | Train Loss: 0.0564 | Train Acc: 98.23% | Val Loss: 0.3092 | Val Acc: 93.16%
# Epoch 10 | Train Loss: 0.0484 | Train Acc: 98.38% | Val Loss: 0.4175 | Val Acc: 93.35%
# Epoch 11 | Train Loss: 0.0420 | Train Acc: 98.67% | Val Loss: 0.3564 | Val Acc: 93.80%
# Epoch 12 | Train Loss: 0.0359 | Train Acc: 98.87% | Val Loss: 0.4090 | Val Acc: 92.97%
# Epoch 13 | Train Loss: 0.0305 | Train Acc: 99.02% | Val Loss: 0.4395 | Val Acc: 92.74%
# Epoch 14 | Train Loss: 0.0348 | Train Acc: 98.86% | Val Loss: 0.3840 | Val Acc: 93.73%
# Epoch 15 | Train Loss: 0.0327 | Train Acc: 98.92% | Val Loss: 0.3911 | Val Acc: 93.07%
# Epoch 16 | Train Loss: 0.0299 | Train Acc: 99.09% | Val Loss: 0.4022 | Val Acc: 93.34%
# Epoch 17 | Train Loss: 0.0229 | Train Acc: 99.29% | Val Loss: 0.4773 | Val Acc: 93.68%
# Epoch 18 | Train Loss: 0.0282 | Train Acc: 99.18% | Val Loss: 0.5243 | Val Acc: 92.68%
# Epoch 19 | Train Loss: 0.0265 | Train Acc: 99.21% | Val Loss: 0.4811 | Val Acc: 93.54%
# Epoch 20 | Train Loss: 0.0264 | Train Acc: 99.22% | Val Loss: 0.5055 | Val Acc: 93.58%
# Epoch 21 | Train Loss: 0.0346 | Train Acc: 98.95% | Val Loss: 0.4382 | Val Acc: 93.34%
# Epoch 22 | Train Loss: 0.0182 | Train Acc: 99.42% | Val Loss: 0.5239 | Val Acc: 92.96%
# Epoch 23 | Train Loss: 0.0201 | Train Acc: 99.36% | Val Loss: 0.5185 | Val Acc: 93.31%
# Epoch 24 | Train Loss: 0.0240 | Train Acc: 99.28% | Val Loss: 0.5085 | Val Acc: 93.13%
# Epoch 25 | Train Loss: 0.0205 | Train Acc: 99.38% | Val Loss: 0.4713 | Val Acc: 93.07%
# Epoch 26 | Train Loss: 0.0220 | Train Acc: 99.36% | Val Loss: 0.5577 | Val Acc: 93.53%
# Epoch 27 | Train Loss: 0.0217 | Train Acc: 99.38% | Val Loss: 0.5426 | Val Acc: 93.23%
# Epoch 28 | Train Loss: 0.0246 | Train Acc: 99.29% | Val Loss: 0.5649 | Val Acc: 93.60%
# Epoch 29 | Train Loss: 0.0204 | Train Acc: 99.41% | Val Loss: 0.5469 | Val Acc: 93.30%
# Epoch 30 | Train Loss: 0.0158 | Train Acc: 99.53% | Val Loss: 0.5611 | Val Acc: 93.50%
# Epoch 31 | Train Loss: 0.0152 | Train Acc: 99.54% | Val Loss: 0.5663 | Val Acc: 93.31%
# Epoch 32 | Train Loss: 0.0213 | Train Acc: 99.41% | Val Loss: 0.5456 | Val Acc: 93.84%
# Epoch 33 | Train Loss: 0.0202 | Train Acc: 99.40% | Val Loss: 0.5455 | Val Acc: 92.89%
# Epoch 34 | Train Loss: 0.0205 | Train Acc: 99.41% | Val Loss: 0.5406 | Val Acc: 93.09%
# Epoch 35 | Train Loss: 0.0232 | Train Acc: 99.33% | Val Loss: 0.5259 | Val Acc: 93.46%
# Epoch 36 | Train Loss: 0.0136 | Train Acc: 99.62% | Val Loss: 0.6183 | Val Acc: 92.86%
# Epoch 37 | Train Loss: 0.0182 | Train Acc: 99.49% | Val Loss: 0.6600 | Val Acc: 93.00%
# Epoch 38 | Train Loss: 0.0210 | Train Acc: 99.39% | Val Loss: 0.5748 | Val Acc: 93.54%
# Epoch 39 | Train Loss: 0.0138 | Train Acc: 99.60% | Val Loss: 0.6065 | Val Acc: 93.39%
# Epoch 40 | Train Loss: 0.0138 | Train Acc: 99.63% | Val Loss: 0.5705 | Val Acc: 93.27%
# Epoch 41 | Train Loss: 0.0232 | Train Acc: 99.34% | Val Loss: 0.6590 | Val Acc: 93.13%
# Epoch 42 | Train Loss: 0.0169 | Train Acc: 99.50% | Val Loss: 0.5829 | Val Acc: 93.53%
# Epoch 43 | Train Loss: 0.0151 | Train Acc: 99.57% | Val Loss: 0.6558 | Val Acc: 93.61%
# Epoch 44 | Train Loss: 0.0144 | Train Acc: 99.59% | Val Loss: 0.5942 | Val Acc: 93.53%
# Epoch 45 | Train Loss: 0.0127 | Train Acc: 99.65% | Val Loss: 0.7336 | Val Acc: 93.16%
# Epoch 46 | Train Loss: 0.0175 | Train Acc: 99.55% | Val Loss: 0.5987 | Val Acc: 93.00%
# Epoch 47 | Train Loss: 0.0147 | Train Acc: 99.61% | Val Loss: 0.6418 | Val Acc: 93.54%
# Epoch 48 | Train Loss: 0.0146 | Train Acc: 99.61% | Val Loss: 0.6177 | Val Acc: 93.72%
# Epoch 49 | Train Loss: 0.0167 | Train Acc: 99.57% | Val Loss: 0.6477 | Val Acc: 93.09%
# Epoch 50 | Train Loss: 0.0167 | Train Acc: 99.55% | Val Loss: 0.5849 | Val Acc: 93.28%
# Test Accuracy: 93.02%
