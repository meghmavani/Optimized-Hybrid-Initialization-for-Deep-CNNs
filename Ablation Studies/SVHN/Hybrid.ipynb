# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, random_split
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

run_name = 'SVHN_Hybrid'
epochs = 50
batch_size = 128
learning_rate = 0.001

transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

full_train_data = datasets.SVHN(root='../../Final Benchmarks/SVHN/data', split='train', download=True, transform=transform)
test_data = datasets.SVHN(root='../../Final Benchmarks/SVHN/data', split='test', download=True, transform=transform)
train_size = int(0.9 * len(full_train_data))
val_size = len(full_train_data) - train_size
train_data, val_data = random_split(full_train_data, [train_size, val_size])

train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)

def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    layer_idx = 0
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            if layer_idx < 6:
                nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
            else:
                nn.init.orthogonal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)
            layer_idx += 1


# Same 9-layer CNN
class CustomCNN(nn.Module):
    def __init__(self):
        super(CustomCNN, self).__init__()
        self.layers = nn.Sequential(
            nn.Conv2d(3, 64, 3, padding=1), nn.ReLU(),
            nn.Conv2d(64, 64, 3, padding=1), nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, 3, padding=1), nn.ReLU(),
            nn.Conv2d(128, 128, 3, padding=1), nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(128, 256, 3, padding=1), nn.ReLU(),
            nn.Conv2d(256, 256, 3, padding=1), nn.ReLU(),
            nn.AdaptiveAvgPool2d((4, 4))
        )

        self.fc = nn.Sequential(
            nn.Linear(256 * 4 * 4, 512), nn.ReLU(),
            nn.Linear(512, 10)
        )

    def forward(self, x):
        x = self.layers(x)
        x = torch.flatten(x, 1)
        x = self.fc(x)
        return x

model = CustomCNN().to(device)
custom_init(model)

optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.CrossEntropyLoss()
train_loss_list, train_acc_list = [], []
val_loss_list, val_acc_list = [], []

for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    correct_train, total_train = 0, 0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct_train / total_train
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    running_val_loss = 0.0
    correct_val, total_val = 0, 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    val_loss = running_val_loss / len(val_loader)
    val_acc = 100 * correct_val / total_val
    val_loss_list.append(val_loss)
    val_acc_list.append(val_acc)

    print(
        f"Epoch {epoch+1} | Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | "
        f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.2f}%"
    )

correct_test, total_test = 0, 0
model.eval()
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total_test += labels.size(0)
        correct_test += (predicted == labels).sum().item()

test_acc = 100 * correct_test / total_test
print(f"Test Accuracy: {test_acc:.2f}%")

# Save metrics to files labelled with dataset + init method
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(len(train_loss_list)):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Epoch 1 | Train Loss: 0.9817 | Train Acc: 67.66% | Val Loss: 0.3627 | Val Acc: 89.11%
# Epoch 2 | Train Loss: 0.3042 | Train Acc: 91.09% | Val Loss: 0.2805 | Val Acc: 91.61%
# Epoch 3 | Train Loss: 0.2237 | Train Acc: 93.61% | Val Loss: 0.2341 | Val Acc: 93.22%
# Epoch 4 | Train Loss: 0.1754 | Train Acc: 95.04% | Val Loss: 0.2478 | Val Acc: 92.47%
# Epoch 5 | Train Loss: 0.1334 | Train Acc: 96.16% | Val Loss: 0.2444 | Val Acc: 93.50%
# Epoch 6 | Train Loss: 0.1017 | Train Acc: 97.06% | Val Loss: 0.2642 | Val Acc: 92.68%
# Epoch 7 | Train Loss: 0.0855 | Train Acc: 97.34% | Val Loss: 0.2851 | Val Acc: 93.05%
# Epoch 8 | Train Loss: 0.0652 | Train Acc: 97.99% | Val Loss: 0.3086 | Val Acc: 92.77%
# Epoch 9 | Train Loss: 0.0570 | Train Acc: 98.20% | Val Loss: 0.2964 | Val Acc: 93.08%
# Epoch 10 | Train Loss: 0.0449 | Train Acc: 98.48% | Val Loss: 0.3481 | Val Acc: 92.64%
# Epoch 11 | Train Loss: 0.0435 | Train Acc: 98.60% | Val Loss: 0.3560 | Val Acc: 93.24%
# Epoch 12 | Train Loss: 0.0386 | Train Acc: 98.75% | Val Loss: 0.3697 | Val Acc: 93.38%
# Epoch 13 | Train Loss: 0.0358 | Train Acc: 98.85% | Val Loss: 0.3985 | Val Acc: 93.11%
# Epoch 14 | Train Loss: 0.0357 | Train Acc: 98.85% | Val Loss: 0.3724 | Val Acc: 93.41%
# Epoch 15 | Train Loss: 0.0271 | Train Acc: 99.17% | Val Loss: 0.3950 | Val Acc: 92.79%
# Epoch 16 | Train Loss: 0.0290 | Train Acc: 99.06% | Val Loss: 0.4715 | Val Acc: 92.83%
# Epoch 17 | Train Loss: 0.0272 | Train Acc: 99.10% | Val Loss: 0.4741 | Val Acc: 92.92%
# Epoch 18 | Train Loss: 0.0293 | Train Acc: 99.11% | Val Loss: 0.4561 | Val Acc: 92.45%
# Epoch 19 | Train Loss: 0.0268 | Train Acc: 99.21% | Val Loss: 0.5580 | Val Acc: 92.49%
# Epoch 20 | Train Loss: 0.0253 | Train Acc: 99.20% | Val Loss: 0.4809 | Val Acc: 93.53%
# Epoch 21 | Train Loss: 0.0273 | Train Acc: 99.14% | Val Loss: 0.4820 | Val Acc: 92.89%
# Epoch 22 | Train Loss: 0.0185 | Train Acc: 99.41% | Val Loss: 0.4591 | Val Acc: 93.41%
# Epoch 23 | Train Loss: 0.0259 | Train Acc: 99.24% | Val Loss: 0.4644 | Val Acc: 92.86%
# Epoch 24 | Train Loss: 0.0233 | Train Acc: 99.29% | Val Loss: 0.5153 | Val Acc: 93.34%
# Epoch 25 | Train Loss: 0.0217 | Train Acc: 99.34% | Val Loss: 0.4896 | Val Acc: 93.15%
# Epoch 26 | Train Loss: 0.0187 | Train Acc: 99.45% | Val Loss: 0.5139 | Val Acc: 93.09%
# Epoch 27 | Train Loss: 0.0265 | Train Acc: 99.21% | Val Loss: 0.4573 | Val Acc: 92.68%
# Epoch 28 | Train Loss: 0.0196 | Train Acc: 99.44% | Val Loss: 0.5400 | Val Acc: 93.20%
# Epoch 29 | Train Loss: 0.0221 | Train Acc: 99.32% | Val Loss: 0.4653 | Val Acc: 93.56%
# Epoch 30 | Train Loss: 0.0205 | Train Acc: 99.39% | Val Loss: 0.4595 | Val Acc: 93.42%
# Epoch 31 | Train Loss: 0.0180 | Train Acc: 99.50% | Val Loss: 0.5934 | Val Acc: 92.78%
# Epoch 32 | Train Loss: 0.0232 | Train Acc: 99.32% | Val Loss: 0.5349 | Val Acc: 93.17%
# Epoch 33 | Train Loss: 0.0190 | Train Acc: 99.46% | Val Loss: 0.5720 | Val Acc: 93.23%
# Epoch 34 | Train Loss: 0.0148 | Train Acc: 99.56% | Val Loss: 0.5802 | Val Acc: 93.41%
# Epoch 35 | Train Loss: 0.0181 | Train Acc: 99.48% | Val Loss: 0.5779 | Val Acc: 93.07%
# Epoch 36 | Train Loss: 0.0215 | Train Acc: 99.40% | Val Loss: 0.5643 | Val Acc: 92.66%
# Epoch 37 | Train Loss: 0.0165 | Train Acc: 99.53% | Val Loss: 0.6050 | Val Acc: 92.89%
# Epoch 38 | Train Loss: 0.0186 | Train Acc: 99.46% | Val Loss: 0.5858 | Val Acc: 93.08%
# Epoch 39 | Train Loss: 0.0195 | Train Acc: 99.46% | Val Loss: 0.6262 | Val Acc: 93.35%
# Epoch 40 | Train Loss: 0.0204 | Train Acc: 99.49% | Val Loss: 0.5395 | Val Acc: 93.20%
# Epoch 41 | Train Loss: 0.0151 | Train Acc: 99.57% | Val Loss: 0.5837 | Val Acc: 93.00%
# Epoch 42 | Train Loss: 0.0188 | Train Acc: 99.45% | Val Loss: 0.5951 | Val Acc: 92.77%
# Epoch 43 | Train Loss: 0.0192 | Train Acc: 99.47% | Val Loss: 0.5506 | Val Acc: 93.01%
# Epoch 44 | Train Loss: 0.0162 | Train Acc: 99.56% | Val Loss: 0.6546 | Val Acc: 92.52%
# Epoch 45 | Train Loss: 0.0160 | Train Acc: 99.56% | Val Loss: 0.6067 | Val Acc: 93.00%
# Epoch 46 | Train Loss: 0.0147 | Train Acc: 99.59% | Val Loss: 0.6605 | Val Acc: 93.00%
# Epoch 47 | Train Loss: 0.0177 | Train Acc: 99.50% | Val Loss: 0.5892 | Val Acc: 93.34%
# Epoch 48 | Train Loss: 0.0163 | Train Acc: 99.58% | Val Loss: 0.7870 | Val Acc: 93.01%
# Epoch 49 | Train Loss: 0.0227 | Train Acc: 99.41% | Val Loss: 0.5472 | Val Acc: 93.26%
# Epoch 50 | Train Loss: 0.0115 | Train Acc: 99.66% | Val Loss: 0.6415 | Val Acc: 93.12%
# Test Accuracy: 93.75%
