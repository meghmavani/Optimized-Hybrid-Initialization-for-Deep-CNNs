# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader, random_split
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

run_name = 'SVHN_Xavier'
epochs = 50
batch_size = 128
learning_rate = 0.001

transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

full_train_data = datasets.SVHN(root='../../Final Benchmarks/SVHN/data', split='train', download=True, transform=transform)
test_data = datasets.SVHN(root='../../Final Benchmarks/SVHN/data', split='test', download=True, transform=transform)
train_size = int(0.9 * len(full_train_data))
val_size = len(full_train_data) - train_size
train_data, val_data = random_split(full_train_data, [train_size, val_size])

train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)

def custom_init(model):
    relu_gain = nn.init.calculate_gain('relu')
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            nn.init.xavier_normal_(m.weight, gain=relu_gain)
            if m.bias is not None:
                nn.init.constant_(m.bias, 0)


# Same 9-layer CNN
class CustomCNN(nn.Module):
    def __init__(self):
        super(CustomCNN, self).__init__()
        self.layers = nn.Sequential(
            nn.Conv2d(3, 64, 3, padding=1), nn.ReLU(),
            nn.Conv2d(64, 64, 3, padding=1), nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, 3, padding=1), nn.ReLU(),
            nn.Conv2d(128, 128, 3, padding=1), nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(128, 256, 3, padding=1), nn.ReLU(),
            nn.Conv2d(256, 256, 3, padding=1), nn.ReLU(),
            nn.AdaptiveAvgPool2d((4, 4))
        )

        self.fc = nn.Sequential(
            nn.Linear(256 * 4 * 4, 512), nn.ReLU(),
            nn.Linear(512, 10)
        )

    def forward(self, x):
        x = self.layers(x)
        x = torch.flatten(x, 1)
        x = self.fc(x)
        return x

model = CustomCNN().to(device)
custom_init(model)

optimizer = optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.CrossEntropyLoss()
train_loss_list, train_acc_list = [], []
val_loss_list, val_acc_list = [], []

for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    correct_train, total_train = 0, 0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    train_loss = running_loss / len(train_loader)
    train_acc = 100 * correct_train / total_train
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc)

    model.eval()
    running_val_loss = 0.0
    correct_val, total_val = 0, 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    val_loss = running_val_loss / len(val_loader)
    val_acc = 100 * correct_val / total_val
    val_loss_list.append(val_loss)
    val_acc_list.append(val_acc)

    print(
        f"Epoch {epoch+1} | Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | "
        f"Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.2f}%"
    )

correct_test, total_test = 0, 0
model.eval()
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total_test += labels.size(0)
        correct_test += (predicted == labels).sum().item()

test_acc = 100 * correct_test / total_test
print(f"Test Accuracy: {test_acc:.2f}%")

# Save metrics to files labelled with dataset + init method
with open(f'{run_name}_metrics.csv', 'w') as f:
    f.write('epoch,train_loss,train_acc,val_loss,val_acc\n')
    for i in range(len(train_loss_list)):
        f.write(f'{i+1},{train_loss_list[i]:.6f},{train_acc_list[i]:.4f},{val_loss_list[i]:.6f},{val_acc_list[i]:.4f}\n')

with open(f'{run_name}_test_accuracy.txt', 'w') as f:
    f.write(f'{run_name} Test Accuracy: {test_acc:.2f}%\n')

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.plot(train_loss_list, label='Train Loss')
plt.title('Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(train_acc_list, label='Train Accuracy')
plt.title('Train Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(val_loss_list, label='Validation Loss')
plt.title('Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(val_acc_list, label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()

plt.suptitle(run_name)
plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.savefig(f'{run_name}_curves.png', dpi=150)
plt.show()
# Out:
# Epoch 1 | Train Loss: 0.9400 | Train Acc: 68.36% | Val Loss: 0.3682 | Val Acc: 88.97%
# Epoch 2 | Train Loss: 0.2949 | Train Acc: 91.12% | Val Loss: 0.3229 | Val Acc: 90.94%
# Epoch 3 | Train Loss: 0.2204 | Train Acc: 93.58% | Val Loss: 0.2628 | Val Acc: 92.93%
# Epoch 4 | Train Loss: 0.1742 | Train Acc: 95.01% | Val Loss: 0.2418 | Val Acc: 93.27%
# Epoch 5 | Train Loss: 0.1334 | Train Acc: 96.12% | Val Loss: 0.2534 | Val Acc: 93.22%
# Epoch 6 | Train Loss: 0.1049 | Train Acc: 96.90% | Val Loss: 0.2864 | Val Acc: 93.12%
# Epoch 7 | Train Loss: 0.0805 | Train Acc: 97.44% | Val Loss: 0.3115 | Val Acc: 93.09%
# Epoch 8 | Train Loss: 0.0667 | Train Acc: 97.83% | Val Loss: 0.3548 | Val Acc: 93.04%
# Epoch 9 | Train Loss: 0.0544 | Train Acc: 98.28% | Val Loss: 0.3766 | Val Acc: 92.85%
# Epoch 10 | Train Loss: 0.0443 | Train Acc: 98.54% | Val Loss: 0.4218 | Val Acc: 92.82%
# Epoch 11 | Train Loss: 0.0372 | Train Acc: 98.79% | Val Loss: 0.4806 | Val Acc: 93.19%
# Epoch 12 | Train Loss: 0.0376 | Train Acc: 98.79% | Val Loss: 0.4459 | Val Acc: 92.62%
# Epoch 13 | Train Loss: 0.0373 | Train Acc: 98.80% | Val Loss: 0.4520 | Val Acc: 93.00%
# Epoch 14 | Train Loss: 0.0305 | Train Acc: 99.02% | Val Loss: 0.4661 | Val Acc: 93.04%
# Epoch 15 | Train Loss: 0.0338 | Train Acc: 98.93% | Val Loss: 0.4224 | Val Acc: 92.60%
# Epoch 16 | Train Loss: 0.0272 | Train Acc: 99.18% | Val Loss: 0.5097 | Val Acc: 93.02%
# Epoch 17 | Train Loss: 0.0273 | Train Acc: 99.14% | Val Loss: 0.6058 | Val Acc: 92.92%
# Epoch 18 | Train Loss: 0.0281 | Train Acc: 99.14% | Val Loss: 0.5611 | Val Acc: 92.81%
# Epoch 19 | Train Loss: 0.0231 | Train Acc: 99.29% | Val Loss: 0.5514 | Val Acc: 92.86%
# Epoch 20 | Train Loss: 0.0248 | Train Acc: 99.25% | Val Loss: 0.5195 | Val Acc: 92.53%
# Epoch 21 | Train Loss: 0.0250 | Train Acc: 99.24% | Val Loss: 0.5286 | Val Acc: 92.83%
# Epoch 22 | Train Loss: 0.0214 | Train Acc: 99.36% | Val Loss: 0.5927 | Val Acc: 92.47%
# Epoch 23 | Train Loss: 0.0251 | Train Acc: 99.21% | Val Loss: 0.5210 | Val Acc: 92.53%
# Epoch 24 | Train Loss: 0.0205 | Train Acc: 99.40% | Val Loss: 0.6703 | Val Acc: 92.86%
# Epoch 25 | Train Loss: 0.0260 | Train Acc: 99.28% | Val Loss: 0.6221 | Val Acc: 93.34%
# Epoch 26 | Train Loss: 0.0182 | Train Acc: 99.48% | Val Loss: 0.5490 | Val Acc: 92.92%
# Epoch 27 | Train Loss: 0.0191 | Train Acc: 99.39% | Val Loss: 0.7003 | Val Acc: 92.98%
# Epoch 28 | Train Loss: 0.0232 | Train Acc: 99.32% | Val Loss: 0.6313 | Val Acc: 93.01%
# Epoch 29 | Train Loss: 0.0187 | Train Acc: 99.45% | Val Loss: 0.5296 | Val Acc: 93.28%
# Epoch 30 | Train Loss: 0.0125 | Train Acc: 99.65% | Val Loss: 0.6378 | Val Acc: 93.26%
# Epoch 31 | Train Loss: 0.0185 | Train Acc: 99.47% | Val Loss: 0.6861 | Val Acc: 93.09%
# Epoch 32 | Train Loss: 0.0210 | Train Acc: 99.37% | Val Loss: 0.6579 | Val Acc: 93.07%
# Epoch 33 | Train Loss: 0.0177 | Train Acc: 99.48% | Val Loss: 0.6246 | Val Acc: 92.56%
# Epoch 34 | Train Loss: 0.0227 | Train Acc: 99.34% | Val Loss: 0.6608 | Val Acc: 93.07%
# Epoch 35 | Train Loss: 0.0163 | Train Acc: 99.54% | Val Loss: 0.6354 | Val Acc: 93.53%
# Epoch 36 | Train Loss: 0.0149 | Train Acc: 99.60% | Val Loss: 0.7359 | Val Acc: 92.63%
# Epoch 37 | Train Loss: 0.0180 | Train Acc: 99.46% | Val Loss: 0.6649 | Val Acc: 93.17%
# Epoch 38 | Train Loss: 0.0148 | Train Acc: 99.56% | Val Loss: 0.9534 | Val Acc: 92.83%
# Epoch 39 | Train Loss: 0.0250 | Train Acc: 99.37% | Val Loss: 0.7250 | Val Acc: 93.05%
# Epoch 40 | Train Loss: 0.0225 | Train Acc: 99.37% | Val Loss: 0.7068 | Val Acc: 93.00%
# Epoch 41 | Train Loss: 0.0114 | Train Acc: 99.69% | Val Loss: 0.7217 | Val Acc: 92.68%
# Epoch 42 | Train Loss: 0.0157 | Train Acc: 99.55% | Val Loss: 0.6888 | Val Acc: 93.26%
# Epoch 43 | Train Loss: 0.0159 | Train Acc: 99.56% | Val Loss: 0.7455 | Val Acc: 93.39%
# Epoch 44 | Train Loss: 0.0197 | Train Acc: 99.47% | Val Loss: 0.7764 | Val Acc: 92.66%
# Epoch 45 | Train Loss: 0.0157 | Train Acc: 99.57% | Val Loss: 0.7757 | Val Acc: 92.93%
# Epoch 46 | Train Loss: 0.0144 | Train Acc: 99.61% | Val Loss: 0.8427 | Val Acc: 92.44%
# Epoch 47 | Train Loss: 0.0162 | Train Acc: 99.58% | Val Loss: 0.7578 | Val Acc: 93.16%
# Epoch 48 | Train Loss: 0.0180 | Train Acc: 99.50% | Val Loss: 0.7828 | Val Acc: 93.02%
# Epoch 49 | Train Loss: 0.0134 | Train Acc: 99.65% | Val Loss: 0.8291 | Val Acc: 92.97%
# Epoch 50 | Train Loss: 0.0125 | Train Acc: 99.65% | Val Loss: 0.7626 | Val Acc: 93.28%
# Test Accuracy: 93.62%
